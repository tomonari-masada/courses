# %% [markdown]
# <a href="https://colab.research.google.com/github/tomonari-masada/courses/blob/master/NLP2020/02_elementary_Japanese_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 02 日本語のテキストデータの扱い方
#
# * 日本語は、言語の性質上、文が単語に分たれていない。
# * そのため、まず最初に文を単語へ分割する必要がある。
#  * 問：分割の単位は、単語である必要があるか?
# * この作業を**形態素解析**と言う。
# * ここでは、spaCyを介してsudachiというツールで形態素解析をおこなう。
#  * 形態素解析システムとしては、他には、MeCabやJUMANが有名。

# %% [markdown]
# ## 注
# * "ContextualVersionConflict ..."というエラーが出たら、上部メニューの「ランタイム」から「ランタイムを再起動」をクリックして、ランタイムを再起動してみてください。

# %% [markdown]
# ## spaCyの準備

# %% [markdown]
# ### spaCyを最新版にアップデートする。

# %%
! pip install -U spacy
# Out:
# Requirement already up-to-date: spacy in /usr/local/lib/python3.6/dist-packages (2.3.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.18.5)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (3.0.2)
# Requirement already satisfied, skipping upgrade: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.4.1)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (49.1.0)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.7.1)
# Requirement already satisfied, skipping upgrade: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied, skipping upgrade: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied, skipping upgrade: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied, skipping upgrade: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.7.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.1.0)

# %% [markdown]
# ### バージョンを確認する。

# %%
! python -m spacy validate
# Out:
# ✔ Loaded compatibility table
#
# ====================== Installed models (spaCy v2.3.2) ======================
# ℹ spaCy installation: /usr/local/lib/python3.6/dist-packages/spacy
#
# TYPE      NAME              MODEL             VERSION
# package   ja-core-news-sm   ja_core_news_sm   2.3.2   ✔
# package   en-core-web-sm    en_core_web_sm    2.3.1   ✔

# %% [markdown]
# ### 英語の統計モデルもアップデートしておく。
# * 今回は英語データは使わないが。

# %%
! python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en_core_web_sm==2.3.1 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz#egg=en_core_web_sm==2.3.1 in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from en_core_web_sm==2.3.1) (2.3.2)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.4.1)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.7.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.41.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (49.1.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.18.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
! python -m spacy validate
# Out:
# ✔ Loaded compatibility table
#
# ====================== Installed models (spaCy v2.3.2) ======================
# ℹ spaCy installation: /usr/local/lib/python3.6/dist-packages/spacy
#
# TYPE      NAME              MODEL             VERSION
# package   ja-core-news-sm   ja_core_news_sm   2.3.2   ✔
# package   en-core-web-sm    en_core_web_sm    2.3.1   ✔

# %% [markdown]
# ### spaCyの日本語の訓練済み統計モデルをダウンロードする
# * 「sm」で終わるものは、最も小さいモデル。
# * 「md」で終わるものが、中規模のモデル。
# * 「lg」で終わるものが、大規模なモデル。
# * 詳細は、以下を参照。
#  * https://explosion.ai/blog/spacy-v2-3

# %%
! python -m spacy download ja_core_news_sm
# Out:
# Requirement already satisfied: ja_core_news_sm==2.3.2 from https://github.com/explosion/spacy-models/releases/download/ja_core_news_sm-2.3.2/ja_core_news_sm-2.3.2.tar.gz#egg=ja_core_news_sm==2.3.2 in /usr/local/lib/python3.6/dist-packages (2.3.2)
# Requirement already satisfied: sudachidict-core>=20200330 in /usr/local/lib/python3.6/dist-packages (from ja_core_news_sm==2.3.2) (20200330)
# Requirement already satisfied: sudachipy>=0.4.5 in /usr/local/lib/python3.6/dist-packages (from ja_core_news_sm==2.3.2) (0.4.9)
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from ja_core_news_sm==2.3.2) (2.3.2)
# Requirement already satisfied: sortedcontainers~=2.1.0 in /usr/local/lib/python3.6/dist-packages (from sudachipy>=0.4.5->ja_core_news_sm==2.3.2) (2.1.0)
# Requirement already satisfied: dartsclone~=0.9.0 in /usr/local/lib/python3.6/dist-packages (from sudachipy>=0.4.5->ja_core_news_sm==2.3.2) (0.9.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (0.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (3.0.2)
# Requirement already satisfied: thinc==7.4.1 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (7.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (0.7.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (2.0.3)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (1.1.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (4.41.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (1.18.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (1.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (49.1.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (1.0.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.6/dist-packages (from dartsclone~=0.9.0->sudachipy>=0.4.5->ja_core_news_sm==2.3.2) (0.29.21)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (1.24.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->ja_core_news_sm==2.3.2) (3.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('ja_core_news_sm')

# %% [markdown]
# ### sudachiによる形態素解析を試してみる。
# * spaCyの日本語統計モデルをインストールすると、自動的にsudachiがインストールされる。
# * そこで、sudachipyコマンドを使って、コマンドラインで形態素解析を試してみる。

# %%
! echo "すもももももももものうち" | sudachipy
# Out:
# すもも	名詞,普通名詞,一般,*,*,*	李
# も	助詞,係助詞,*,*,*,*	も
# もも	名詞,普通名詞,一般,*,*,*	もも
# も	助詞,係助詞,*,*,*,*	も
# もも	名詞,普通名詞,一般,*,*,*	もも
# の	助詞,格助詞,*,*,*,*	の
# うち	名詞,普通名詞,副詞可能,*,*,*	内
# EOS

# %% [markdown]
# ## spaCyによる日本語テキスト処理

# %% [markdown]
# ### 日本語統計モデルをロードする。

# %%
from spacy.lang.ja import Japanese

# Load SudachiPy with split mode A (default)
nlp = Japanese()

# Load SudachiPy with split mode B
#cfg = {"split_mode": "B"}
#nlp = Japanese(meta={"tokenizer": {"config": cfg}})

# %% [markdown]
# ### 文書を作成してみる。

# %%
doc = nlp('これは、やっぱり相当冗長な日本語の文じゃないかなと思っていたのですが。')
print(doc.text)
# Out:
# これは、やっぱり相当冗長な日本語の文じゃないかなと思っていたのですが。

# %% [markdown]
# ### 分かち書きをする。
# * 分かち書きされた単語以外の情報も表示させている。
#  * tagに「形容動詞」は無く、その語幹が「形状詞」とされている。
#  * 「じゃない」の「ない」は、tagでは「形容詞」だが、posでは「AUX」である。

# %%
for token in doc:
  print(f'text:{token.text}, pos:{token.pos_}, tag:{token.tag_}, lemma:{token.lemma_}')
# Out:
# text:これ, pos:PRON, tag:代名詞, lemma:これ
# text:は, pos:ADP, tag:助詞-係助詞, lemma:は
# text:、, pos:PUNCT, tag:補助記号-読点, lemma:、
# text:やっぱり, pos:ADV, tag:副詞, lemma:やっぱり
# text:相当, pos:ADV, tag:副詞, lemma:相当
# text:冗長, pos:ADJ, tag:形状詞-一般, lemma:冗長
# text:な, pos:AUX, tag:助動詞, lemma:だ
# text:日本, pos:PROPN, tag:名詞-固有名詞-地名-国, lemma:日本
# text:語, pos:NOUN, tag:名詞-普通名詞-一般, lemma:語
# text:の, pos:ADP, tag:助詞-格助詞, lemma:の
# text:文, pos:NOUN, tag:名詞-普通名詞-一般, lemma:文
# text:じゃ, pos:AUX, tag:助動詞, lemma:だ
# text:ない, pos:AUX, tag:形容詞-非自立可能, lemma:ない
# text:か, pos:PART, tag:助詞-終助詞, lemma:か
# text:な, pos:PART, tag:助詞-終助詞, lemma:な
# text:と, pos:ADP, tag:助詞-格助詞, lemma:と
# text:思っ, pos:VERB, tag:動詞-一般, lemma:思う
# text:て, pos:SCONJ, tag:助詞-接続助詞, lemma:て
# text:い, pos:AUX, tag:動詞-非自立可能, lemma:いる
# text:た, pos:AUX, tag:助動詞, lemma:た
# text:の, pos:SCONJ, tag:助詞-準体助詞, lemma:の
# text:です, pos:AUX, tag:助動詞, lemma:です
# text:が, pos:SCONJ, tag:助詞-接続助詞, lemma:が
# text:。, pos:PUNCT, tag:補助記号-句点, lemma:。

# %% [markdown]
# # 課題2
#
# * Wikipediaの複数のエントリを、lemmaを半角スペースでつないだ、長い文字列へ変換する。
#  * ここでは、コンピュータ科学の様々な分野のエントリを題材として使う。
# * scikit-learnのCountVectorizerを使って、各エントリにおける単語の出現頻度からなる特徴ベクトルを得る。
# * 特徴ベクトルどうしの類似度を計算し、「人工知能」分野と最も似ている分野がどれかを求める。

# %% [markdown]
# ## 課題の手順(1)

# %% [markdown]
# ### エントリをダウンロードして形態素解析を適用する
#
# * 例えば、Wikipediaの「人工知能」エントリをダウンロードする。
#  * https://ja.wikipedia.org/wiki/%E4%BA%BA%E5%B7%A5%E7%9F%A5%E8%83%BD
# * そして、そこに含まれる段落（__`<p>`__タグで囲まれた範囲）を列挙する。
# * 各段落のテキストに形態素解析を適用する。
# * 形態素解析で得られたlemmaを半角スペースでつないで、エントリ全体をひとつの長い文字列にする。
#  * text、つまり、単語に分たれたそのままの文字列を半角スペースでつなぐのではない。
#  * lemma（原型に戻したもの）を半角スペースでつなぐこと。
#  * posやtagを見て、不要そうな単語を適当に削除してもよい。

# %%
# 「人工知能」エントリをダウンロードしてparserのインスタンスを作る。

from bs4 import BeautifulSoup
from urllib.request import urlopen

url = 'https://ja.wikipedia.org/wiki/%E4%BA%BA%E5%B7%A5%E7%9F%A5%E8%83%BD'
html = urlopen(url) 
soup = BeautifulSoup(html, 'html.parser')

# %%
# 段落のテキストを取得する。

lines = list()
for para in soup.find_all('p'):
  lines.append(para.text)

# %%
# Sudachiで形態素解析し、分かち書き後のlemmaを取得する。

tabu = ['SPACE', 'PUNCT', 'AUX', 'ADP', 'SYM', 'DET', 'SCONJ', 'PART']
tokens = list()
for line in lines:
  for token in nlp(line):
    pos = token.pos_
    if not pos in tabu:
      print(f'text:{token.text}, pos:{token.pos_}, tag:{token.tag_}, lemma:{token.lemma_}')
      tokens.append(token.lemma_)
# Out:
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:じん, pos:NOUN, tag:名詞-普通名詞-一般, lemma:じん
# text:こうち, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:こうち
# text:英, pos:NOUN, tag:名詞-普通名詞-一般, lemma:英
# text:artificial intelligence, pos:PROPN, tag:名詞-固有名詞-一般, lemma:artificial intelligence
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:エーアイ, pos:PROPN, tag:名詞-固有名詞-一般, lemma:エーアイ
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:computation, pos:NOUN, tag:名詞-普通名詞-一般, lemma:computation
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:概念, pos:NOUN, tag:名詞-普通名詞-一般, lemma:概念
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:computer, pos:NOUN, tag:名詞-普通名詞-一般, lemma:Computer
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:道具, pos:NOUN, tag:名詞-普通名詞-一般, lemma:道具
# text:用い, pos:VERB, tag:動詞-一般, lemma:用いる
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:研究, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:機, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:機
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:computer science, pos:PROPN, tag:名詞-固有名詞-一般, lemma:computer science
# text:一, pos:NUM, tag:名詞-数詞, lemma:一
# text:分野, pos:NOUN, tag:名詞-普通名詞-一般, lemma:分野
# text:指す, pos:VERB, tag:動詞-一般, lemma:指す
# text:語, pos:NOUN, tag:名詞-普通名詞-一般, lemma:語
# text:1, pos:NUM, tag:名詞-数詞, lemma:1
# text:言語, pos:NOUN, tag:名詞-普通名詞-一般, lemma:言語
# text:理解, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:理解
# text:推論, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:推論
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:解決, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:解決
# text:知的, pos:ADJ, tag:形状詞-一般, lemma:知的
# text:行動, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:行動
# text:人間, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人間
# text:代わっ, pos:VERB, tag:動詞-一般, lemma:代わる
# text:コンピューター, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピューター
# text:行わ, pos:VERB, tag:動詞-一般, lemma:行う
# text:技術, pos:NOUN, tag:名詞-普通名詞-一般, lemma:技術
# text:2, pos:NUM, tag:名詞-数詞, lemma:2
# text:また, pos:CCONJ, tag:接続詞, lemma:また
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:機, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:機
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:よる, pos:VERB, tag:動詞-一般, lemma:よる
# text:知的, pos:ADJ, tag:形状詞-一般, lemma:知的
# text:情報, pos:NOUN, tag:名詞-普通名詞-一般, lemma:情報
# text:処理, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:処理
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:設計, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:設計
# text:実現, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:実現
# text:関する, pos:VERB, tag:動詞-一般, lemma:関する
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:分野, pos:NOUN, tag:名詞-普通名詞-一般, lemma:分野
# text:さ, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:3, pos:NUM, tag:名詞-数詞, lemma:3
# text:日本, pos:PROPN, tag:名詞-固有名詞-地名-国, lemma:日本
# text:大, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:大
# text:百科, pos:NOUN, tag:名詞-普通名詞-一般, lemma:百科
# text:全書, pos:NOUN, tag:名詞-普通名詞-一般, lemma:全書
# text:ニッポニカ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ニッポニカ
# text:解説, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:解説
# text:情報, pos:NOUN, tag:名詞-普通名詞-一般, lemma:情報
# text:工学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:工学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:通信, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:通信
# text:工学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:工学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:佐藤, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:佐藤
# text:理史, pos:PROPN, tag:名詞-固有名詞-人名-名, lemma:理史
# text:次, pos:NOUN, tag:名詞-普通名詞-一般, lemma:次
# text:よう, pos:NOUN, tag:形状詞-助動詞語幹, lemma:よう
# text:述べ, pos:VERB, tag:動詞-一般, lemma:述べる
# text:1, pos:NUM, tag:名詞-数詞, lemma:1
# text:人間, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人間
# text:知的, pos:ADJ, tag:形状詞-一般, lemma:知的
# text:能力, pos:NOUN, tag:名詞-普通名詞-一般, lemma:能力
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:上, pos:NOUN, tag:接尾辞-名詞的-副詞可能, lemma:上
# text:実現, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:実現
# text:様々, pos:ADJ, tag:形状詞-一般, lemma:様々
# text:技術, pos:NOUN, tag:名詞-普通名詞-一般, lemma:技術
# text:ソフトウェア, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ソフトウェア
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:4, pos:NUM, tag:名詞-数詞, lemma:4
# text:応用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:応用
# text:例, pos:NOUN, tag:名詞-普通名詞-一般, lemma:例
# text:自然, pos:NOUN, tag:名詞-普通名詞-一般, lemma:自然
# text:言語, pos:NOUN, tag:名詞-普通名詞-一般, lemma:言語
# text:処理, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:処理
# text:機械, pos:NOUN, tag:名詞-普通名詞-一般, lemma:機械
# text:翻訳, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:翻訳
# text:かな, pos:NOUN, tag:名詞-普通名詞-一般, lemma:かな
# text:漢字, pos:NOUN, tag:名詞-普通名詞-一般, lemma:漢字
# text:変換, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:変換
# text:構文, pos:NOUN, tag:名詞-普通名詞-一般, lemma:構文
# text:解析, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:解析
# text:等, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:等
# text:5, pos:NUM, tag:名詞-数詞, lemma:5
# text:専門, pos:NOUN, tag:名詞-普通名詞-一般, lemma:専門
# text:家, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:家
# text:推論, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:推論
# text:判断, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:判断
# text:模倣, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:模倣
# text:エキスパート, pos:NOUN, tag:名詞-普通名詞-一般, lemma:エキスパート
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:画像, pos:NOUN, tag:名詞-普通名詞-一般, lemma:画像
# text:データ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:データ
# text:解析, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:解析
# text:特定, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:特定
# text:パターン, pos:NOUN, tag:名詞-普通名詞-一般, lemma:パターン
# text:検出, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:検出
# text:抽出, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:抽出
# text:画像, pos:NOUN, tag:名詞-普通名詞-一般, lemma:画像
# text:認識, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:認識
# text:等, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:等
# text:ある, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:4, pos:NUM, tag:名詞-数詞, lemma:4
# text:1956, pos:NUM, tag:名詞-数詞, lemma:1956
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:ダートマス, pos:PROPN, tag:名詞-固有名詞-一般, lemma:ダートマス
# text:会議, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:会議
# text:ジョン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ジョン
# text:マッカーシー, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:マッカーシー
# text:より, pos:VERB, tag:動詞-一般, lemma:よる
# text:命名, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:命名
# text:現在, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:現在
# text:記号, pos:NOUN, tag:名詞-普通名詞-一般, lemma:記号
# text:処理, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:処理
# text:用い, pos:VERB, tag:動詞-一般, lemma:用いる
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:記述, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:記述
# text:主体, pos:NOUN, tag:名詞-普通名詞-一般, lemma:主体
# text:する, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:情報, pos:NOUN, tag:名詞-普通名詞-一般, lemma:情報
# text:処理, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:処理
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:アプローチ, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:アプローチ
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:意味, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:意味
# text:あい, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:あい
# text:使わ, pos:VERB, tag:動詞-一般, lemma:使う
# text:家庭, pos:NOUN, tag:名詞-普通名詞-一般, lemma:家庭
# text:用, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:用
# text:電気, pos:NOUN, tag:名詞-普通名詞-一般, lemma:電気
# text:機械, pos:NOUN, tag:名詞-普通名詞-一般, lemma:機械
# text:器具, pos:NOUN, tag:名詞-普通名詞-一般, lemma:器具
# text:制御, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:制御
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:ゲーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ゲーム
# text:ソフト, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ソフト
# text:思考, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:思考
# text:ルーチン, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ルーチン
# text:こう, pos:ADV, tag:副詞, lemma:こう
# text:呼ば, pos:VERB, tag:動詞-一般, lemma:呼ぶ
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:ある, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:プログラミング, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:プログラミング
# text:言語, pos:NOUN, tag:名詞-普通名詞-一般, lemma:言語
# text:LISP, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:LISP
# text:よる, pos:VERB, tag:動詞-一般, lemma:よる
# text:ELIZA, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ELIZA
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:カウンセラー, pos:NOUN, tag:名詞-普通名詞-一般, lemma:カウンセラー
# text:模倣, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:模倣
# text:プログラム, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:プログラム
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:無脳, pos:NOUN, tag:名詞-普通名詞-一般, lemma:無脳
# text:しばしば, pos:ADV, tag:副詞, lemma:しばしば
# text:引き合い, pos:NOUN, tag:名詞-普通名詞-一般, lemma:引き合い
# text:出さ, pos:VERB, tag:動詞-非自立可能, lemma:出す
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:機, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:機
# text:人間, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人間
# text:専門, pos:NOUN, tag:名詞-普通名詞-一般, lemma:専門
# text:家, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:家
# text:役割, pos:NOUN, tag:名詞-普通名詞-一般, lemma:役割
# text:さ, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:エキスパート, pos:NOUN, tag:名詞-普通名詞-一般, lemma:エキスパート
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:呼ば, pos:VERB, tag:動詞-一般, lemma:呼ぶ
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:情報, pos:NOUN, tag:名詞-普通名詞-一般, lemma:情報
# text:処理, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:処理
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:実現, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:実現
# text:人間, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人間
# text:暗黙, pos:NOUN, tag:名詞-普通名詞-一般, lemma:暗黙
# text:持つ, pos:VERB, tag:動詞-一般, lemma:持つ
# text:常識, pos:NOUN, tag:名詞-普通名詞-一般, lemma:常識
# text:記述, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:記述
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:なり, pos:VERB, tag:動詞-非自立可能, lemma:なる
# text:実用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:実用
# text:利用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:利用
# text:困難, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:困難
# text:視, pos:NOUN, tag:接尾辞-名詞的-サ変可能, lemma:視
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:実現, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:実現
# text:アプローチ, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:アプローチ
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:ファジィ, pos:ADJ, tag:形状詞-一般, lemma:ファジィ
# text:理論, pos:NOUN, tag:名詞-普通名詞-一般, lemma:理論
# text:ニューラル, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ニューラル
# text:ネットワーク, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ネットワーク
# text:よう, pos:NOUN, tag:形状詞-助動詞語幹, lemma:よう
# text:アプローチ, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:アプローチ
# text:知ら, pos:VERB, tag:動詞-一般, lemma:知る
# text:従来, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:従来
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:GOFAI, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:gofai
# text:Good, pos:NOUN, tag:名詞-普通名詞-一般, lemma:good
# text:Old, pos:NOUN, tag:名詞-普通名詞-一般, lemma:Old
# text:Fashioned, pos:NOUN, tag:名詞-普通名詞-一般, lemma:fashioned
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:差, pos:NOUN, tag:名詞-普通名詞-一般, lemma:差
# text:記述, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:記述
# text:記号, pos:NOUN, tag:名詞-普通名詞-一般, lemma:記号
# text:明示, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:明示
# text:性, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:性
# text:ある, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:後, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:後
# text:サポート, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:サポート
# text:ベクター, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ベクター
# text:マシン, pos:NOUN, tag:名詞-普通名詞-一般, lemma:マシン
# text:注目, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:注目
# text:集め, pos:VERB, tag:動詞-一般, lemma:集める
# text:また, pos:CCONJ, tag:接続詞, lemma:また
# text:自ら, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:自ら
# text:経験, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:経験
# text:元, pos:NOUN, tag:名詞-普通名詞-一般, lemma:元
# text:学習, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:学習
# text:行う, pos:VERB, tag:動詞-一般, lemma:行う
# text:強化, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:強化
# text:学習, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:学習
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:手法, pos:NOUN, tag:名詞-普通名詞-一般, lemma:手法
# text:ある, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:宇宙, pos:NOUN, tag:名詞-普通名詞-一般, lemma:宇宙
# text:おい, pos:VERB, tag:動詞-一般, lemma:おく
# text:知性, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知性
# text:最も, pos:ADV, tag:副詞, lemma:最も
# text:強力, pos:ADJ, tag:形状詞-一般, lemma:強力
# text:形質, pos:NOUN, tag:名詞-普通名詞-一般, lemma:形質
# text:レイ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:レイ
# text:カーツ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:カーツ
# text:ワイル, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ワイル
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:言葉, pos:NOUN, tag:名詞-普通名詞-一般, lemma:言葉
# text:通り, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:通り
# text:知性, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知性
# text:機械, pos:NOUN, tag:名詞-普通名詞-一般, lemma:機械
# text:表現, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:表現
# text:実装, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:実装
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:極めて, pos:ADV, tag:副詞, lemma:極めて
# text:重要, pos:ADJ, tag:形状詞-一般, lemma:重要
# text:作業, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:作業
# text:2006, pos:NUM, tag:名詞-数詞, lemma:2006
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:ディープ, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ディープ
# text:ラーニング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ラーニング
# text:深層, pos:NOUN, tag:名詞-普通名詞-一般, lemma:深層
# text:学習, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:学習
# text:登場, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:登場
# text:2010, pos:NUM, tag:名詞-数詞, lemma:2010
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:代, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:代
# text:以降, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:以降
# text:ビッグ, pos:ADJ, tag:形状詞-一般, lemma:ビッグ
# text:データ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:データ
# text:登場, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:登場
# text:より, pos:VERB, tag:動詞-一般, lemma:よる
# text:一過, pos:NOUN, tag:名詞-普通名詞-一般, lemma:一過
# text:性, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:性
# text:流行, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:流行
# text:超え, pos:VERB, tag:動詞-一般, lemma:超える
# text:社会, pos:NOUN, tag:名詞-普通名詞-一般, lemma:社会
# text:浸透, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:浸透
# text:2016, pos:NUM, tag:名詞-数詞, lemma:2016
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:2017, pos:NUM, tag:名詞-数詞, lemma:2017
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:かけ, pos:VERB, tag:動詞-非自立可能, lemma:かける
# text:ディープ, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ディープ
# text:ラーニング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ラーニング
# text:導入, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:導入
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:完全, pos:ADJ, tag:形状詞-一般, lemma:完全
# text:情報, pos:NOUN, tag:名詞-普通名詞-一般, lemma:情報
# text:ゲーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ゲーム
# text:囲碁, pos:NOUN, tag:名詞-普通名詞-一般, lemma:囲碁
# text:トップ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:トップ
# text:棋士, pos:NOUN, tag:名詞-普通名詞-一般, lemma:棋士
# text:さらに, pos:ADV, tag:副詞, lemma:さらに
# text:不, pos:NOUN, tag:接頭辞, lemma:不
# text:完全, pos:ADJ, tag:形状詞-一般, lemma:完全
# text:情報, pos:NOUN, tag:名詞-普通名詞-一般, lemma:情報
# text:ゲーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ゲーム
# text:ポーカー, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ポーカー
# text:世界, pos:NOUN, tag:名詞-普通名詞-一般, lemma:世界
# text:トップ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:トップ
# text:クラス, pos:NOUN, tag:名詞-普通名詞-一般, lemma:クラス
# text:プレイヤー, pos:NOUN, tag:名詞-普通名詞-一般, lemma:プレイヤー
# text:破り, pos:VERB, tag:動詞-一般, lemma:破る
# text:6, pos:NUM, tag:名詞-数詞, lemma:6
# text:7, pos:NUM, tag:名詞-数詞, lemma:7
# text:麻雀, pos:NOUN, tag:名詞-普通名詞-一般, lemma:麻雀
# text:Microsoft, pos:PROPN, tag:名詞-固有名詞-一般, lemma:Microsoft
# text:Suphx, pos:NOUN, tag:名詞-普通名詞-一般, lemma:suphx
# text:Super, pos:NOUN, tag:名詞-普通名詞-一般, lemma:super
# text:Phoenix, pos:PROPN, tag:名詞-固有名詞-一般, lemma:Phoenix
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:初めて, pos:ADV, tag:副詞, lemma:初めて
# text:十, pos:NUM, tag:名詞-数詞, lemma:十
# text:段, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:段
# text:到達, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:到達
# text:8, pos:NUM, tag:名詞-数詞, lemma:8
# text:時代, pos:NOUN, tag:名詞-普通名詞-一般, lemma:時代
# text:最, pos:NOUN, tag:接頭辞, lemma:最
# text:先端, pos:NOUN, tag:名詞-普通名詞-一般, lemma:先端
# text:技術, pos:NOUN, tag:名詞-普通名詞-一般, lemma:技術
# text:なっ, pos:VERB, tag:動詞-非自立可能, lemma:なる
# text:9, pos:NUM, tag:名詞-数詞, lemma:9
# text:第, pos:NOUN, tag:接頭辞, lemma:第
# text:２, pos:NUM, tag:名詞-数詞, lemma:2
# text:次, pos:NOUN, tag:接尾辞-名詞的-助数詞, lemma:次
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:ブーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ブーム
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:機械, pos:NOUN, tag:名詞-普通名詞-一般, lemma:機械
# text:学習, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:学習
# text:呼ば, pos:VERB, tag:動詞-一般, lemma:呼ぶ
# text:以下, pos:NOUN, tag:名詞-普通名詞-一般, lemma:以下
# text:よう, pos:NOUN, tag:形状詞-助動詞語幹, lemma:よう
# text:もの, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:もの
# text:ある, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:一方, pos:CCONJ, tag:接続詞, lemma:一方
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:CI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:CI
# text:開発, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:開発
# text:学習, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:学習
# text:繰り, pos:VERB, tag:動詞-一般, lemma:繰る
# text:返す, pos:VERB, tag:動詞-一般, lemma:返す
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:基本, pos:NOUN, tag:名詞-普通名詞-一般, lemma:基本
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:例えば, pos:ADV, tag:副詞, lemma:例えば
# text:パラメータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:パラメータ
# text:調整, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:調整
# text:コネクショニズム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コネクショニズム
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:学習, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:学習
# text:経験, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:経験
# text:基づく, pos:VERB, tag:動詞-一般, lemma:基づく
# text:手法, pos:NOUN, tag:名詞-普通名詞-一般, lemma:手法
# text:非, pos:NOUN, tag:接頭辞, lemma:非
# text:記号, pos:NOUN, tag:名詞-普通名詞-一般, lemma:記号
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:美しく, pos:ADJ, tag:形容詞-一般, lemma:美しい
# text:ない, pos:ADJ, tag:形容詞-非自立可能, lemma:ない
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:注, pos:NOUN, tag:名詞-普通名詞-一般, lemma:注
# text:1, pos:NUM, tag:名詞-数詞, lemma:1
# text:ソフト, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ソフト
# text:コンピューティング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピューティング
# text:関係, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:関係
# text:手法, pos:NOUN, tag:名詞-普通名詞-一般, lemma:手法
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:以下, pos:NOUN, tag:名詞-普通名詞-一般, lemma:以下
# text:もの, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:もの
# text:ある, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:これ, pos:PRON, tag:代名詞, lemma:これ
# text:ら, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:ら
# text:統合, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:統合
# text:知的, pos:ADJ, tag:形状詞-一般, lemma:知的
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:作る, pos:VERB, tag:動詞-一般, lemma:作る
# text:試み, pos:NOUN, tag:名詞-普通名詞-一般, lemma:試み
# text:なさ, pos:VERB, tag:動詞-一般, lemma:なす
# text:ACT, pos:PROPN, tag:名詞-固有名詞-一般, lemma:ACT
# text:R, pos:NOUN, tag:名詞-普通名詞-一般, lemma:r
# text:エキスパート, pos:NOUN, tag:名詞-普通名詞-一般, lemma:エキスパート
# text:推論, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:推論
# text:ルール, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ルール
# text:統計, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:統計
# text:学習, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:学習
# text:元, pos:NOUN, tag:名詞-普通名詞-一般, lemma:元
# text:ニューラル, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ニューラル
# text:ネットワーク, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ネットワーク
# text:生成, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:生成
# text:規則, pos:NOUN, tag:名詞-普通名詞-一般, lemma:規則
# text:通し, pos:VERB, tag:動詞-非自立可能, lemma:通す
# text:生成, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:生成
# text:第, pos:NOUN, tag:接頭辞, lemma:第
# text:3, pos:NUM, tag:名詞-数詞, lemma:3
# text:次, pos:NOUN, tag:接尾辞-名詞的-助数詞, lemma:次
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:ブーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ブーム
# text:ディープ, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ディープ
# text:ラーニング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ラーニング
# text:画像, pos:NOUN, tag:名詞-普通名詞-一般, lemma:画像
# text:認識, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:認識
# text:テキスト, pos:NOUN, tag:名詞-普通名詞-一般, lemma:テキスト
# text:解析, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:解析
# text:音声, pos:NOUN, tag:名詞-普通名詞-一般, lemma:音声
# text:認識, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:認識
# text:様々, pos:ADJ, tag:形状詞-一般, lemma:様々
# text:領域, pos:NOUN, tag:名詞-普通名詞-一般, lemma:領域
# text:第, pos:NOUN, tag:接頭辞, lemma:第
# text:2, pos:NUM, tag:名詞-数詞, lemma:2
# text:次, pos:NOUN, tag:接尾辞-名詞的-助数詞, lemma:次
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:ブーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ブーム
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:上回る, pos:VERB, tag:動詞-一般, lemma:上回る
# text:精度, pos:NOUN, tag:名詞-普通名詞-一般, lemma:精度
# text:出し, pos:VERB, tag:動詞-非自立可能, lemma:出す
# text:ディープ, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ディープ
# text:ラーニング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ラーニング
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:盛ん, pos:ADJ, tag:形状詞-一般, lemma:盛ん
# text:行わ, pos:VERB, tag:動詞-一般, lemma:行う
# text:最近, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:最近
# text:DQN, pos:NOUN, tag:名詞-普通名詞-一般, lemma:DQN
# text:CNN, pos:PROPN, tag:名詞-固有名詞-一般, lemma:CNN
# text:RNN, pos:NOUN, tag:名詞-普通名詞-一般, lemma:rnn
# text:GAN, pos:NOUN, tag:名詞-普通名詞-一般, lemma:gan
# text:様々, pos:ADJ, tag:形状詞-一般, lemma:様々
# text:ディープ, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ディープ
# text:ラーニング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ラーニング
# text:派生, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:派生
# text:で, pos:VERB, tag:動詞-一般, lemma:でる
# text:各, pos:NOUN, tag:接頭辞, lemma:各
# text:分野, pos:NOUN, tag:名詞-普通名詞-一般, lemma:分野
# text:活躍, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:活躍
# text:特に, pos:ADV, tag:副詞, lemma:特に
# text:GAN, pos:NOUN, tag:名詞-普通名詞-一般, lemma:gan
# text:敵対, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:敵対
# text:生成, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:生成
# text:ネットワーク, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ネットワーク
# text:ディープ, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ディープ
# text:ラーニング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ラーニング
# text:認識, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:認識
# text:予測, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:予測
# text:分野, pos:NOUN, tag:名詞-普通名詞-一般, lemma:分野
# text:成果, pos:NOUN, tag:名詞-普通名詞-一般, lemma:成果
# text:だし, pos:VERB, tag:動詞-非自立可能, lemma:だす
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:加え, pos:VERB, tag:動詞-一般, lemma:加える
# text:画像, pos:NOUN, tag:名詞-普通名詞-一般, lemma:画像
# text:生成, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:生成
# text:技術, pos:NOUN, tag:名詞-普通名詞-一般, lemma:技術
# text:おい, pos:VERB, tag:動詞-一般, lemma:おく
# text:進化, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:進化
# text:見せ, pos:VERB, tag:動詞-非自立可能, lemma:見せる
# text:森, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:森
# text:正弥, pos:PROPN, tag:名詞-固有名詞-人名-名, lemma:正弥
# text:これ, pos:PRON, tag:代名詞, lemma:これ
# text:ら, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:ら
# text:成果, pos:NOUN, tag:名詞-普通名詞-一般, lemma:成果
# text:背景, pos:NOUN, tag:名詞-普通名詞-一般, lemma:背景
# text:従来, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:従来
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:応用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:応用
# text:分野, pos:NOUN, tag:名詞-普通名詞-一般, lemma:分野
# text:広がっ, pos:VERB, tag:動詞-一般, lemma:広がる
# text:Creative, pos:PROPN, tag:名詞-固有名詞-一般, lemma:Creative
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:コンテンツ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンテンツ
# text:生成, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:生成
# text:行っ, pos:VERB, tag:動詞-一般, lemma:行う
# text:応用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:応用
# text:始まっ, pos:VERB, tag:動詞-一般, lemma:始まる
# text:指摘, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:指摘
# text:10, pos:NUM, tag:名詞-数詞, lemma:10
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:構築, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:構築
# text:長い, pos:ADJ, tag:形容詞-一般, lemma:長い
# text:間, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:間
# text:試み, pos:VERB, tag:動詞-一般, lemma:試みる
# text:シンボルグラウンディング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:シンボルグラウンディング
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:フレーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:フレーム
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:解決, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:解決
# text:壁, pos:NOUN, tag:名詞-普通名詞-一般, lemma:壁
# text:なっ, pos:VERB, tag:動詞-非自立可能, lemma:なる
# text:17, pos:NUM, tag:名詞-数詞, lemma:17
# text:世紀, pos:NOUN, tag:名詞-普通名詞-一般, lemma:世紀
# text:初め, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:初め
# text:ルネ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ルネ
# text:デカルト, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:デカルト
# text:動物, pos:NOUN, tag:名詞-普通名詞-一般, lemma:動物
# text:身体, pos:NOUN, tag:名詞-普通名詞-一般, lemma:身体
# text:ただ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ただ
# text:複雑, pos:ADJ, tag:名詞-普通名詞-形状詞可能, lemma:複雑
# text:機械, pos:NOUN, tag:名詞-普通名詞-一般, lemma:機械
# text:提唱, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:提唱
# text:機械, pos:NOUN, tag:名詞-普通名詞-一般, lemma:機械
# text:論, pos:NOUN, tag:名詞-普通名詞-一般, lemma:論
# text:ブレーズ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ブレーズ
# text:パスカル, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:パスカル
# text:1642, pos:NUM, tag:名詞-数詞, lemma:1642
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:最初, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:最初
# text:機械, pos:NOUN, tag:名詞-普通名詞-一般, lemma:機械
# text:式, pos:NOUN, tag:名詞-普通名詞-一般, lemma:式
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:機, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:機
# text:製作, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:製作
# text:チャールズ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:チャールズ
# text:バベッジ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:バベッジ
# text:エイダ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:エイダ
# text:ラブレス, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ラブレス
# text:プログラム, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:プログラム
# text:可能, pos:ADJ, tag:形状詞-一般, lemma:可能
# text:機械, pos:NOUN, tag:名詞-普通名詞-一般, lemma:機械
# text:式, pos:NOUN, tag:名詞-普通名詞-一般, lemma:式
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:機, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:機
# text:開発, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:開発
# text:行っ, pos:VERB, tag:動詞-一般, lemma:行う
# text:バートランド, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:バートランド
# text:ラッセル, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ラッセル
# text:アルフレッド, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:アルフレッド
# text:ノース, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ノース
# text:ホワイトヘッド, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ホワイトヘッド
# text:数学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:数学
# text:原理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:原理
# text:出版, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:出版
# text:形式, pos:NOUN, tag:名詞-普通名詞-一般, lemma:形式
# text:論理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:論理
# text:革命, pos:NOUN, tag:名詞-普通名詞-一般, lemma:革命
# text:もたらし, pos:VERB, tag:動詞-一般, lemma:もたらす
# text:ウォーレン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ウォーレン
# text:マカロック, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:マカロック
# text:ウォルター, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ウォルター
# text:ピッツ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ピッツ
# text:神経, pos:NOUN, tag:名詞-普通名詞-一般, lemma:神経
# text:活動, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:活動
# text:内在, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:内在
# text:アイデア, pos:NOUN, tag:名詞-普通名詞-一般, lemma:アイデア
# text:論理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:論理
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:題する, pos:VERB, tag:動詞-一般, lemma:題する
# text:論文, pos:NOUN, tag:名詞-普通名詞-一般, lemma:論文
# text:1943, pos:NUM, tag:名詞-数詞, lemma:1943
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:発表, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:発表
# text:ニューラル, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ニューラル
# text:ネットワーク, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ネットワーク
# text:基礎, pos:NOUN, tag:名詞-普通名詞-一般, lemma:基礎
# text:築い, pos:VERB, tag:動詞-一般, lemma:築く
# text:1950, pos:NUM, tag:名詞-数詞, lemma:1950
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:代, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:代
# text:なる, pos:VERB, tag:動詞-非自立可能, lemma:なる
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:関し, pos:VERB, tag:動詞-一般, lemma:関する
# text:活発, pos:ADJ, tag:形状詞-一般, lemma:活発
# text:成果, pos:NOUN, tag:名詞-普通名詞-一般, lemma:成果
# text:出, pos:VERB, tag:動詞-一般, lemma:出る
# text:ジョン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ジョン
# text:マッカーシー, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:マッカーシー
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:関する, pos:VERB, tag:動詞-一般, lemma:関する
# text:最初, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:最初
# text:会議, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:会議
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:注, pos:NOUN, tag:名詞-普通名詞-一般, lemma:注
# text:2, pos:NUM, tag:名詞-数詞, lemma:2
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:用語, pos:NOUN, tag:名詞-普通名詞-一般, lemma:用語
# text:作り, pos:VERB, tag:動詞-一般, lemma:作る
# text:彼, pos:PRON, tag:代名詞, lemma:彼
# text:また, pos:ADV, tag:副詞, lemma:また
# text:プログラミング, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:プログラミング
# text:言語, pos:NOUN, tag:名詞-普通名詞-一般, lemma:言語
# text:LISP, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:LISP
# text:開発, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:開発
# text:知的, pos:ADJ, tag:形状詞-一般, lemma:知的
# text:ふるまい, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ふるまい
# text:関する, pos:VERB, tag:動詞-一般, lemma:関する
# text:テスト, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:テスト
# text:可能, pos:ADJ, tag:形状詞-一般, lemma:可能
# text:方法, pos:NOUN, tag:名詞-普通名詞-一般, lemma:方法
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:アラン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:アラン
# text:チューリング, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:チューリング
# text:チューリング, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:チューリング
# text:テスト, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:テスト
# text:導入, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:導入
# text:ジョセフ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ジョセフ
# text:ワイゼンバウム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ワイゼンバウム
# text:ELIZA, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ELIZA
# text:構築, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:構築
# text:これ, pos:PRON, tag:代名詞, lemma:これ
# text:来談, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:来談
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:中心, pos:NOUN, tag:名詞-普通名詞-一般, lemma:中心
# text:療法, pos:NOUN, tag:名詞-普通名詞-一般, lemma:療法
# text:行う, pos:VERB, tag:動詞-一般, lemma:行う
# text:お, pos:NOUN, tag:接頭辞, lemma:お
# text:しゃべり, pos:NOUN, tag:名詞-普通名詞-一般, lemma:しゃべり
# text:ロボット, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ロボット
# text:注, pos:NOUN, tag:名詞-普通名詞-一般, lemma:注
# text:3, pos:NUM, tag:名詞-数詞, lemma:3
# text:1956, pos:NUM, tag:名詞-数詞, lemma:1956
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:行わ, pos:VERB, tag:動詞-一般, lemma:行う
# text:ダートマス, pos:PROPN, tag:名詞-固有名詞-一般, lemma:ダートマス
# text:会議, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:会議
# text:開催, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:開催
# text:提案, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:提案
# text:書, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:書
# text:おい, pos:VERB, tag:動詞-一般, lemma:おく
# text:人類, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人類
# text:史, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:史
# text:上, pos:NOUN, tag:接尾辞-名詞的-副詞可能, lemma:上
# text:用語, pos:NOUN, tag:名詞-普通名詞-一般, lemma:用語
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:初めて, pos:ADV, tag:副詞, lemma:初めて
# text:使用, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:使用
# text:新た, pos:ADJ, tag:形状詞-一般, lemma:新た
# text:分野, pos:NOUN, tag:名詞-普通名詞-一般, lemma:分野
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:創立, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:創立
# text:1960, pos:NUM, tag:名詞-数詞, lemma:1960
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:代, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:代
# text:1970, pos:NUM, tag:名詞-数詞, lemma:1970
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:代, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:代
# text:間, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:間
# text:ジョエル, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ジョエル
# text:モーゼス, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:モーゼス
# text:Macsyma, pos:NOUN, tag:名詞-普通名詞-一般, lemma:macsyma
# text:マクシマ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:マクシマ
# text:プログラム, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:プログラム
# text:注, pos:NOUN, tag:名詞-普通名詞-一般, lemma:注
# text:4, pos:NUM, tag:名詞-数詞, lemma:4
# text:中, pos:NOUN, tag:接尾辞-名詞的-副詞可能, lemma:中
# text:積分, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:積分
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:記号, pos:NOUN, tag:名詞-普通名詞-一般, lemma:記号
# text:推論, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:推論
# text:パワー, pos:NOUN, tag:名詞-普通名詞-一般, lemma:パワー
# text:示し, pos:VERB, tag:動詞-一般, lemma:示す
# text:マービン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:マービン
# text:ミンスキー, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ミンスキー
# text:シーモア, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:シーモア
# text:パパート, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:パパート
# text:パーセプトロン, pos:NOUN, tag:名詞-普通名詞-一般, lemma:パーセプトロン
# text:出版, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:出版
# text:単純, pos:ADJ, tag:形状詞-一般, lemma:単純
# text:ニューラル, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ニューラル
# text:ネット, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ネット
# text:限界, pos:NOUN, tag:名詞-普通名詞-一般, lemma:限界
# text:示し, pos:VERB, tag:動詞-一般, lemma:示す
# text:アラン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:アラン
# text:カルメラウアー, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:カルメラウアー
# text:プログラミング, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:プログラミング
# text:言語, pos:NOUN, tag:名詞-普通名詞-一般, lemma:言語
# text:Prolog, pos:NOUN, tag:名詞-普通名詞-一般, lemma:prolog
# text:開発, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:開発
# text:テッド, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:テッド
# text:ショートリッフェ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ショートリッフェ
# text:医学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:医学
# text:診断, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:診断
# text:療法, pos:NOUN, tag:名詞-普通名詞-一般, lemma:療法
# text:おけ, pos:VERB, tag:動詞-一般, lemma:おく
# text:ルール, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ルール
# text:ベース, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ベース
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:構築, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:構築
# text:知識, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知識
# text:表現, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:表現
# text:推論, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:推論
# text:パワー, pos:NOUN, tag:名詞-普通名詞-一般, lemma:パワー
# text:示し, pos:VERB, tag:動詞-一般, lemma:示す
# text:これ, pos:PRON, tag:代名詞, lemma:これ
# text:最初, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:最初
# text:エキスパート, pos:NOUN, tag:名詞-普通名詞-一般, lemma:エキスパート
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:呼ば, pos:VERB, tag:動詞-一般, lemma:呼ぶ
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:ある, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:ハンス, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ハンス
# text:モラベック, pos:NOUN, tag:名詞-普通名詞-一般, lemma:モラベック
# text:障害, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:障害
# text:物, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:物
# text:ある, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:コース, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コース
# text:自律, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:自律
# text:走行, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:走行
# text:最初, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:最初
# text:コンピューター, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピューター
# text:制御, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:制御
# text:乗り物, pos:NOUN, tag:名詞-普通名詞-一般, lemma:乗り物
# text:開発, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:開発
# text:1980, pos:NUM, tag:名詞-数詞, lemma:1980
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:代, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:代
# text:ニューラル, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ニューラル
# text:ネットワーク, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ネットワーク
# text:バック, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:バック
# text:プロパゲーション, pos:NOUN, tag:名詞-普通名詞-一般, lemma:プロパゲーション
# text:アルゴリズム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:アルゴリズム
# text:よっ, pos:VERB, tag:動詞-一般, lemma:よる
# text:広く, pos:ADJ, tag:形容詞-一般, lemma:広い
# text:使わ, pos:VERB, tag:動詞-一般, lemma:使う
# text:また, pos:CCONJ, tag:接続詞, lemma:また
# text:時代, pos:NOUN, tag:名詞-普通名詞-一般, lemma:時代
# text:ロドニー, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ロドニー
# text:ブルックス, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ブルックス
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:身体, pos:NOUN, tag:名詞-普通名詞-一般, lemma:身体
# text:必須, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:必須
# text:学説, pos:NOUN, tag:名詞-普通名詞-一般, lemma:学説
# text:身体, pos:NOUN, tag:名詞-普通名詞-一般, lemma:身体
# text:性, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:性
# text:提唱, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:提唱
# text:1990, pos:NUM, tag:名詞-数詞, lemma:1990
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:代, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:代
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:多く, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:多く
# text:分野, pos:NOUN, tag:名詞-普通名詞-一般, lemma:分野
# text:様々, pos:ADJ, tag:形状詞-一般, lemma:様々
# text:アプリケーション, pos:NOUN, tag:名詞-普通名詞-一般, lemma:アプリケーション
# text:成果, pos:NOUN, tag:名詞-普通名詞-一般, lemma:成果
# text:上げ, pos:VERB, tag:動詞-非自立可能, lemma:上げる
# text:特に, pos:ADV, tag:副詞, lemma:特に
# text:ボード, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ボード
# text:ゲーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ゲーム
# text:目覚ましく, pos:ADJ, tag:形容詞-一般, lemma:目覚ましい
# text:1992, pos:NUM, tag:名詞-数詞, lemma:1992
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:IBM, pos:PROPN, tag:名詞-固有名詞-一般, lemma:IBM
# text:世界, pos:NOUN, tag:名詞-普通名詞-一般, lemma:世界
# text:チャンピオン, pos:NOUN, tag:名詞-普通名詞-一般, lemma:チャンピオン
# text:匹敵, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:匹敵
# text:バックギャモン, pos:NOUN, tag:名詞-普通名詞-一般, lemma:バックギャモン
# text:専用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:専用
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:TD, pos:NOUN, tag:名詞-普通名詞-一般, lemma:td
# text:ギャモン, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ギャモン
# text:開発, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:開発
# text:IBM, pos:PROPN, tag:名詞-固有名詞-一般, lemma:IBM
# text:チェス, pos:NOUN, tag:名詞-普通名詞-一般, lemma:チェス
# text:専用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:専用
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:ディープ, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ディープ
# text:ブルー, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:ブルー
# text:1997, pos:NUM, tag:名詞-数詞, lemma:1997
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:5, pos:NUM, tag:名詞-数詞, lemma:5
# text:月, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:月
# text:ガルリ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ガルリ
# text:カスパロフ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:カスパロフ
# text:打ち, pos:VERB, tag:動詞-一般, lemma:打つ
# text:負かし, pos:VERB, tag:動詞-一般, lemma:負かす
# text:同年, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:同年
# text:8, pos:NUM, tag:名詞-数詞, lemma:8
# text:月, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:月
# text:オセロ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:オセロ
# text:日本, pos:PROPN, tag:名詞-固有名詞-地名-国, lemma:日本
# text:電気, pos:NOUN, tag:名詞-普通名詞-一般, lemma:電気
# text:オセロ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:オセロ
# text:専用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:専用
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:ロジステロ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ロジステロ
# text:世界, pos:NOUN, tag:名詞-普通名詞-一般, lemma:世界
# text:チャンピオン, pos:NOUN, tag:名詞-普通名詞-一般, lemma:チャンピオン
# text:村上, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:村上
# text:健, pos:PROPN, tag:名詞-固有名詞-人名-名, lemma:健
# text:敗れ, pos:VERB, tag:動詞-一般, lemma:敗れる
# text:11, pos:NUM, tag:名詞-数詞, lemma:11
# text:国防, pos:NOUN, tag:名詞-普通名詞-一般, lemma:国防
# text:高等, pos:ADJ, tag:形状詞-一般, lemma:高等
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:計画, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計画
# text:局, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:局
# text:最初, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:最初
# text:湾岸, pos:NOUN, tag:名詞-普通名詞-一般, lemma:湾岸
# text:戦争, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:戦争
# text:おい, pos:VERB, tag:動詞-一般, lemma:おく
# text:ユニット, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ユニット
# text:スケジューリング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:スケジューリング
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:使い, pos:VERB, tag:動詞-一般, lemma:使う
# text:これ, pos:PRON, tag:代名詞, lemma:これ
# text:よっ, pos:VERB, tag:動詞-一般, lemma:よる
# text:省か, pos:VERB, tag:動詞-一般, lemma:省く
# text:コスト, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コスト
# text:1950, pos:NUM, tag:名詞-数詞, lemma:1950
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:代, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:代
# text:以来, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:以来
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:政府, pos:NOUN, tag:名詞-普通名詞-一般, lemma:政府
# text:投資, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:投資
# text:全額, pos:NOUN, tag:名詞-普通名詞-一般, lemma:全額
# text:上回っ, pos:VERB, tag:動詞-一般, lemma:上回る
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:明らか, pos:ADJ, tag:形状詞-一般, lemma:明らか
# text:日本, pos:PROPN, tag:名詞-固有名詞-地名-国, lemma:日本
# text:甘利, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:甘利
# text:俊一, pos:PROPN, tag:名詞-固有名詞-人名-名, lemma:俊一
# text:日本, pos:PROPN, tag:名詞-固有名詞-地名-国, lemma:日本
# text:学士, pos:NOUN, tag:名詞-普通名詞-一般, lemma:学士
# text:院, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:院
# text:会員, pos:NOUN, tag:名詞-普通名詞-一般, lemma:会員
# text:ら, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:ら
# text:精力, pos:NOUN, tag:名詞-普通名詞-一般, lemma:精力
# text:啓蒙, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:啓蒙
# text:優秀, pos:ADJ, tag:形状詞-一般, lemma:優秀
# text:成果, pos:NOUN, tag:名詞-普通名詞-一般, lemma:成果
# text:発生, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:発生
# text:論理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:論理
# text:ブラック, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ブラック
# text:ボックス, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ボックス
# text:性, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:性
# text:指摘, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:指摘
# text:1998, pos:NUM, tag:名詞-数詞, lemma:1998
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:非, pos:NOUN, tag:接頭辞, lemma:非
# text:構造, pos:NOUN, tag:名詞-普通名詞-一般, lemma:構造
# text:化, pos:NOUN, tag:接尾辞-名詞的-サ変可能, lemma:化
# text:データ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:データ
# text:形式, pos:NOUN, tag:名詞-普通名詞-一般, lemma:形式
# text:国際, pos:NOUN, tag:名詞-普通名詞-一般, lemma:国際
# text:規格, pos:NOUN, tag:名詞-普通名詞-一般, lemma:規格
# text:XML, pos:NOUN, tag:名詞-普通名詞-一般, lemma:XML
# text:提唱, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:提唱
# text:ここ, pos:PRON, tag:代名詞, lemma:ここ
# text:Web, pos:NOUN, tag:名詞-普通名詞-一般, lemma:web
# text:上, pos:NOUN, tag:接尾辞-名詞的-副詞可能, lemma:上
# text:非, pos:NOUN, tag:接頭辞, lemma:非
# text:構造, pos:NOUN, tag:名詞-普通名詞-一般, lemma:構造
# text:化, pos:NOUN, tag:接尾辞-名詞的-サ変可能, lemma:化
# text:データ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:データ
# text:対し, pos:VERB, tag:動詞-一般, lemma:対する
# text:アプリケーション, pos:NOUN, tag:名詞-普通名詞-一般, lemma:アプリケーション
# text:別, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:別
# text:適し, pos:VERB, tag:動詞-一般, lemma:適する
# text:意味, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:意味
# text:付け, pos:NOUN, tag:名詞-普通名詞-一般, lemma:付け
# text:適用, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:適用
# text:処理, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:処理
# text:行わ, pos:VERB, tag:動詞-一般, lemma:行う
# text:試み, pos:NOUN, tag:名詞-普通名詞-一般, lemma:試み
# text:開始, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:開始
# text:同年, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:同年
# text:W, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:W
# text:3, pos:NUM, tag:名詞-数詞, lemma:3
# text:C, pos:NOUN, tag:名詞-普通名詞-一般, lemma:c
# text:ティム, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ティム
# text:バーナーズ, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:バーナーズ
# text:リー, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:リー
# text:より, pos:VERB, tag:動詞-一般, lemma:よる
# text:Web, pos:NOUN, tag:名詞-普通名詞-一般, lemma:web
# text:知的, pos:ADJ, tag:形状詞-一般, lemma:知的
# text:処理, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:処理
# text:行わ, pos:VERB, tag:動詞-一般, lemma:行う
# text:セマンティック, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:セマンティック
# text:ウェブ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ウェブ
# text:提唱, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:提唱
# text:技術, pos:NOUN, tag:名詞-普通名詞-一般, lemma:技術
# text:Web, pos:NOUN, tag:名詞-普通名詞-一般, lemma:web
# text:上, pos:NOUN, tag:接尾辞-名詞的-副詞可能, lemma:上
# text:データ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:データ
# text:意味, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:意味
# text:付加, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:付加
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:知的, pos:ADJ, tag:形状詞-一般, lemma:知的
# text:処理, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:処理
# text:行わ, pos:VERB, tag:動詞-一般, lemma:行う
# text:方法, pos:NOUN, tag:名詞-普通名詞-一般, lemma:方法
# text:国際, pos:NOUN, tag:名詞-普通名詞-一般, lemma:国際
# text:規格, pos:NOUN, tag:名詞-普通名詞-一般, lemma:規格
# text:化, pos:NOUN, tag:接尾辞-名詞的-サ変可能, lemma:化
# text:もの, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:もの
# text:規格, pos:NOUN, tag:名詞-普通名詞-一般, lemma:規格
# text:知識, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知識
# text:工学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:工学
# text:おけ, pos:VERB, tag:動詞-一般, lemma:おく
# text:オントロジー, pos:NOUN, tag:名詞-普通名詞-一般, lemma:オントロジー
# text:表現, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:表現
# text:データ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:データ
# text:形式, pos:NOUN, tag:名詞-普通名詞-一般, lemma:形式
# text:OWL, pos:NOUN, tag:名詞-普通名詞-一般, lemma:owl
# text:含ま, pos:VERB, tag:動詞-一般, lemma:含む
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:かつて, pos:ADV, tag:副詞, lemma:かつて
# text:流行, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:流行
# text:エキスパート, pos:NOUN, tag:名詞-普通名詞-一般, lemma:エキスパート
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:亜種, pos:NOUN, tag:名詞-普通名詞-一般, lemma:亜種
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:分かる, pos:VERB, tag:動詞-一般, lemma:分かる
# text:2000, pos:NUM, tag:名詞-数詞, lemma:2000
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:代, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:代
# text:前半, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:前半
# text:規格, pos:NOUN, tag:名詞-普通名詞-一般, lemma:規格
# text:化, pos:NOUN, tag:接尾辞-名詞的-サ変可能, lemma:化
# text:完了, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:完了
# text:Web, pos:NOUN, tag:名詞-普通名詞-一般, lemma:web
# text:開発, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:開発
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:とっ, pos:VERB, tag:動詞-一般, lemma:とる
# text:開発, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:開発
# text:工数, pos:NOUN, tag:名詞-普通名詞-一般, lemma:工数
# text:見, pos:VERB, tag:動詞-非自立可能, lemma:見る
# text:メリット, pos:NOUN, tag:名詞-普通名詞-一般, lemma:メリット
# text:見出せ, pos:VERB, tag:動詞-一般, lemma:見出せる
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:現在, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:現在
# text:普及, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:普及
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:日本, pos:PROPN, tag:名詞-固有名詞-地名-国, lemma:日本
# text:おい, pos:VERB, tag:動詞-一般, lemma:おく
# text:エキスパート, pos:NOUN, tag:名詞-普通名詞-一般, lemma:エキスパート
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:流行, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:流行
# text:後, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:後
# text:ニューロ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ニューロ
# text:ファジィ, pos:ADJ, tag:形状詞-一般, lemma:ファジィ
# text:流行, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:流行
# text:しかし, pos:CCONJ, tag:接続詞, lemma:しかし
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:進む, pos:VERB, tag:動詞-一般, lemma:進む
# text:つれ, pos:VERB, tag:動詞-一般, lemma:つれる
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:リソース, pos:NOUN, tag:名詞-普通名詞-一般, lemma:リソース
# text:データ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:データ
# text:量, pos:NOUN, tag:名詞-普通名詞-一般, lemma:量
# text:不足, pos:NOUN, tag:名詞-普通名詞-サ変形状詞可能, lemma:不足
# text:シンボルグラウンディング, pos:NOUN, tag:名詞-普通名詞-一般, lemma:シンボルグラウンディング
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:フレーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:フレーム
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:直面, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:直面
# text:産業, pos:NOUN, tag:名詞-普通名詞-一般, lemma:産業
# text:在り, pos:VERB, tag:動詞-非自立可能, lemma:在る
# text:方, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:方
# text:激変, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:激変
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:至る, pos:VERB, tag:動詞-一般, lemma:至る
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:無く, pos:ADJ, tag:形容詞-非自立可能, lemma:無い
# text:ブーム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ブーム
# text:終焉, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:終焉
# text:1980, pos:NUM, tag:名詞-数詞, lemma:1980
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:代, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:代
# text:入っ, pos:VERB, tag:動詞-一般, lemma:入る
# text:大, pos:NOUN, tag:接頭辞, lemma:大
# text:企業, pos:NOUN, tag:名詞-普通名詞-一般, lemma:企業
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:所, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:所
# text:中心, pos:NOUN, tag:名詞-普通名詞-一般, lemma:中心
# text:知識, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知識
# text:工学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:工学
# text:基づく, pos:VERB, tag:動詞-一般, lemma:基づく
# text:エキスパート, pos:NOUN, tag:名詞-普通名詞-一般, lemma:エキスパート
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:多数, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:多数
# text:提案, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:提案
# text:エキスパート, pos:NOUN, tag:名詞-普通名詞-一般, lemma:エキスパート
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:専門, pos:NOUN, tag:名詞-普通名詞-一般, lemma:専門
# text:する, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:AI, pos:NOUN, tag:名詞-普通名詞-一般, lemma:AI
# text:ベンチャー, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ベンチャー
# text:次々, pos:ADV, tag:副詞, lemma:次々
# text:立ち, pos:VERB, tag:動詞-一般, lemma:立つ
# text:上がっ, pos:VERB, tag:動詞-一般, lemma:上がる
# text:流行, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:流行
# text:生まれ, pos:VERB, tag:動詞-一般, lemma:生まれる
# text:究極, pos:NOUN, tag:名詞-普通名詞-一般, lemma:究極
# text:プロジェクト, pos:NOUN, tag:名詞-普通名詞-一般, lemma:プロジェクト
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:第, pos:NOUN, tag:接頭辞, lemma:第
# text:五, pos:NUM, tag:名詞-数詞, lemma:五
# text:世代, pos:NOUN, tag:名詞-普通名詞-一般, lemma:世代
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:挙げ, pos:VERB, tag:動詞-非自立可能, lemma:挙げる
# text:1982, pos:NUM, tag:名詞-数詞, lemma:1982
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:1992, pos:NUM, tag:名詞-数詞, lemma:1992
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:日本, pos:PROPN, tag:名詞-固有名詞-地名-国, lemma:日本
# text:国家, pos:NOUN, tag:名詞-普通名詞-一般, lemma:国家
# text:プロジェクト, pos:NOUN, tag:名詞-普通名詞-一般, lemma:プロジェクト
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:570億, pos:NUM, tag:名詞-数詞, lemma:570億
# text:円, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:円
# text:費やし, pos:VERB, tag:動詞-一般, lemma:費やす
# text:第, pos:NOUN, tag:接頭辞, lemma:第
# text:五, pos:NUM, tag:名詞-数詞, lemma:五
# text:世代, pos:NOUN, tag:名詞-普通名詞-一般, lemma:世代
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:進める, pos:VERB, tag:動詞-一般, lemma:進める
# text:採用, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:採用
# text:知識, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知識
# text:工学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:工学
# text:手法, pos:NOUN, tag:名詞-普通名詞-一般, lemma:手法
# text:膨大, pos:NOUN, tag:名詞-普通名詞-サ変形状詞可能, lemma:膨大
# text:ルール, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ルール
# text:手, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:手
# text:入力, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:入力
# text:必要, pos:ADJ, tag:名詞-普通名詞-形状詞可能, lemma:必要
# text:専門, pos:NOUN, tag:名詞-普通名詞-一般, lemma:専門
# text:家, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:家
# text:間, pos:NOUN, tag:接尾辞-名詞的-副詞可能, lemma:間
# text:専門, pos:NOUN, tag:名詞-普通名詞-一般, lemma:専門
# text:知識, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知識
# text:解釈, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:解釈
# text:異なる, pos:VERB, tag:動詞-一般, lemma:異なる
# text:場合, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:場合
# text:統一, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:統一
# text:ルール, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ルール
# text:化, pos:NOUN, tag:接尾辞-名詞的-サ変可能, lemma:化
# text:行え, pos:VERB, tag:動詞-一般, lemma:行える
# text:等, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:等
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:あり, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:実用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:実用
# text:エキスパート, pos:NOUN, tag:名詞-普通名詞-一般, lemma:エキスパート
# text:システム, pos:NOUN, tag:名詞-普通名詞-一般, lemma:システム
# text:実現, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:実現
# text:至ら, pos:VERB, tag:動詞-一般, lemma:至る
# text:実現, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:実現
# text:成果, pos:NOUN, tag:名詞-普通名詞-一般, lemma:成果
# text:物, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:物
# text:Prolog, pos:NOUN, tag:名詞-普通名詞-一般, lemma:prolog
# text:命令, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:命令
# text:直接, pos:ADV, tag:副詞, lemma:直接
# text:CPU, pos:NOUN, tag:名詞-普通名詞-一般, lemma:CPU
# text:ハードウェア, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ハードウェア
# text:機構, pos:NOUN, tag:名詞-普通名詞-一般, lemma:機構
# text:解釈, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:解釈
# text:高速, pos:ADJ, tag:名詞-普通名詞-形状詞可能, lemma:高速
# text:実行, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:実行
# text:並列, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:並列
# text:型, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:型
# text:Prolog, pos:NOUN, tag:名詞-普通名詞-一般, lemma:prolog
# text:専用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:専用
# text:機, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:機
# text:商業, pos:NOUN, tag:名詞-普通名詞-一般, lemma:商業
# text:意味, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:意味
# ...
# text:脳内, pos:NOUN, tag:名詞-普通名詞-一般, lemma:脳内
# text:ニューロン, pos:NOUN, tag:名詞-普通名詞-一般, lemma:ニューロン
# text:カオス, pos:NOUN, tag:名詞-普通名詞-一般, lemma:カオス
# text:生み, pos:VERB, tag:動詞-一般, lemma:生む
# text:ため, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:ため
# text:状況, pos:NOUN, tag:名詞-普通名詞-一般, lemma:状況
# text:デジタル, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:デジタル
# text:記述, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:記述
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:極めて, pos:ADV, tag:副詞, lemma:極めて
# text:困難, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:困難
# text:考え, pos:VERB, tag:動詞-一般, lemma:考える
# text:143, pos:NUM, tag:名詞-数詞, lemma:143
# text:数学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:数学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:田中, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:田中
# text:一之, pos:PROPN, tag:名詞-固有名詞-人名-名, lemma:一之
# text:一般, pos:NOUN, tag:名詞-普通名詞-一般, lemma:一般
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:論理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:論理
# text:専門, pos:NOUN, tag:名詞-普通名詞-一般, lemma:専門
# text:家, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:家
# text:ない, pos:ADJ, tag:形容詞-非自立可能, lemma:ない
# text:述べ, pos:VERB, tag:動詞-一般, lemma:述べる
# text:144, pos:NUM, tag:名詞-数詞, lemma:144
# text:計算, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:計算
# text:機, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:機
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:コンピュータ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:コンピュータ
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:電子, pos:NOUN, tag:名詞-普通名詞-一般, lemma:電子
# text:工学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:工学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:トルケル, pos:NOUN, tag:名詞-普通名詞-一般, lemma:トルケル
# text:フラン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:フラン
# text:セーン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:セーン
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:たち, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:たち
# text:よる, pos:VERB, tag:動詞-一般, lemma:よる
# text:数学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:数学
# text:言及, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:言及
# text:多く, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:多く
# text:ひどい, pos:ADJ, tag:形容詞-一般, lemma:ひどい
# text:誤解, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:誤解
# text:自由, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:自由
# text:連想, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:連想
# text:基づい, pos:VERB, tag:動詞-一般, lemma:基づく
# text:批判, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:批判
# text:145, pos:NUM, tag:名詞-数詞, lemma:145
# text:田中, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:田中
# text:よる, pos:VERB, tag:動詞-一般, lemma:よる
# text:ゲーデル, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ゲーデル
# text:不, pos:NOUN, tag:接頭辞, lemma:不
# text:完全, pos:ADJ, tag:形状詞-一般, lemma:完全
# text:性, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:性
# text:定理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:定理
# text:つい, pos:VERB, tag:動詞-一般, lemma:つく
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:書い, pos:VERB, tag:動詞-一般, lemma:書く
# text:本, pos:NOUN, tag:名詞-普通名詞-一般, lemma:本
# text:フラン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:フラン
# text:セーン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:セーン
# text:本, pos:NOUN, tag:名詞-普通名詞-一般, lemma:本
# text:頃, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:頃
# text:書店, pos:NOUN, tag:名詞-普通名詞-一般, lemma:書店
# text:販売, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:販売
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:本, pos:NOUN, tag:名詞-普通名詞-一般, lemma:本
# text:専門, pos:NOUN, tag:名詞-普通名詞-一般, lemma:専門
# text:誌, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:誌
# text:よっ, pos:VERB, tag:動詞-一般, lemma:よる
# text:酷評, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:酷評
# text:144, pos:NUM, tag:名詞-数詞, lemma:144
# text:本, pos:NOUN, tag:名詞-普通名詞-一般, lemma:本
# text:全体, pos:NOUN, tag:名詞-普通名詞-一般, lemma:全体
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:読み, pos:VERB, tag:動詞-一般, lemma:読む
# text:一般, pos:NOUN, tag:名詞-普通名詞-一般, lemma:一般
# text:読者, pos:NOUN, tag:名詞-普通名詞-一般, lemma:読者
# text:評判, pos:NOUN, tag:名詞-普通名詞-一般, lemma:評判
# text:高かっ, pos:ADJ, tag:形容詞-一般, lemma:高い
# text:ゲーデル, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ゲーデル
# text:証明, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:証明
# text:核, pos:NOUN, tag:名詞-普通名詞-一般, lemma:核
# text:不動, pos:NOUN, tag:名詞-普通名詞-一般, lemma:不動
# text:点, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:点
# text:定理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:定理
# text:つい, pos:VERB, tag:動詞-一般, lemma:つく
# text:根本, pos:NOUN, tag:名詞-普通名詞-一般, lemma:根本
# text:勘違い, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:勘違い
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:まま, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:まま
# text:説明, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:説明
# text:144, pos:NUM, tag:名詞-数詞, lemma:144
# text:同様, pos:ADJ, tag:形状詞-一般, lemma:同様
# text:間違い, pos:NOUN, tag:名詞-普通名詞-一般, lemma:間違い
# text:他, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:他
# text:入門, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:入門
# text:書, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:書
# text:見, pos:VERB, tag:動詞-非自立可能, lemma:見る
# text:144, pos:NUM, tag:名詞-数詞, lemma:144
# text:フラン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:フラン
# text:セーン, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:セーン
# text:よれ, pos:VERB, tag:動詞-一般, lemma:よる
# text:不, pos:NOUN, tag:接頭辞, lemma:不
# text:完全, pos:ADJ, tag:形状詞-一般, lemma:完全
# text:性, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:性
# text:定理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:定理
# text:関する, pos:VERB, tag:動詞-一般, lemma:関する
# text:誤解, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:誤解
# text:誤用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:誤用
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:はじめ, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:はじめ
# text:一般, pos:NOUN, tag:名詞-普通名詞-一般, lemma:一般
# text:起こっ, pos:VERB, tag:動詞-一般, lemma:起こる
# text:145, pos:NUM, tag:名詞-数詞, lemma:145
# text:宗教, pos:NOUN, tag:名詞-普通名詞-一般, lemma:宗教
# text:神学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:神学
# text:乱用, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:乱用
# text:146, pos:NUM, tag:名詞-数詞, lemma:146
# text:147, pos:NUM, tag:名詞-数詞, lemma:147
# text:1931, pos:NUM, tag:名詞-数詞, lemma:1931
# text:年, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:年
# text:ゲーデル, pos:PROPN, tag:名詞-固有名詞-人名-一般, lemma:ゲーデル
# text:示し, pos:VERB, tag:動詞-一般, lemma:示す
# text:特定, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:特定
# text:形式, pos:NOUN, tag:名詞-普通名詞-一般, lemma:形式
# text:体系, pos:NOUN, tag:名詞-普通名詞-一般, lemma:体系
# text:P, pos:NOUN, tag:名詞-普通名詞-一般, lemma:p
# text:displaystyle, pos:NOUN, tag:名詞-普通名詞-一般, lemma:displaystyle
# text:P, pos:NOUN, tag:名詞-普通名詞-一般, lemma:p
# text:おい, pos:VERB, tag:動詞-一般, lemma:おく
# text:決定, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:決定
# text:不能, pos:ADJ, tag:名詞-普通名詞-形状詞可能, lemma:不能
# text:命題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:命題
# text:存在, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:存在
# text:一般, pos:NOUN, tag:名詞-普通名詞-一般, lemma:一般
# text:意味, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:意味
# text:不, pos:NOUN, tag:接頭辞, lemma:不
# text:完全, pos:ADJ, tag:形状詞-一般, lemma:完全
# text:性, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:性
# text:つい, pos:VERB, tag:動詞-一般, lemma:つく
# text:定理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:定理
# text:ない, pos:ADJ, tag:形容詞-非自立可能, lemma:ない
# text:148, pos:NUM, tag:名詞-数詞, lemma:148
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:語る, pos:VERB, tag:動詞-一般, lemma:語る
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:よる, pos:VERB, tag:動詞-一般, lemma:よる
# text:学問, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:学問
# text:扱う, pos:VERB, tag:動詞-一般, lemma:扱う
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:整理, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:整理
# text:分化, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:分化
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:それぞれ, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:それぞれ
# text:異なる, pos:VERB, tag:動詞-一般, lemma:異なる
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:研究, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:149, pos:NUM, tag:名詞-数詞, lemma:149
# text:これ, pos:PRON, tag:代名詞, lemma:これ
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:分野, pos:NOUN, tag:名詞-普通名詞-一般, lemma:分野
# text:細分, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:細分
# text:化, pos:NOUN, tag:接尾辞-名詞的-サ変可能, lemma:化
# text:もの, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:もの
# text:立派, pos:ADJ, tag:形状詞-一般, lemma:立派
# text:進歩, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:進歩
# text:宇宙, pos:NOUN, tag:名詞-普通名詞-一般, lemma:宇宙
# text:物理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:物理
# text:学, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:須藤, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:須藤
# text:言う, pos:VERB, tag:動詞-一般, lemma:言う
# text:149, pos:NUM, tag:名詞-数詞, lemma:149
# text:一方, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:一方
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:倫理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:倫理
# text:学, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:伊勢田, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:伊勢田
# text:哲治, pos:PROPN, tag:名詞-固有名詞-人名-名, lemma:哲治
# text:様々, pos:ADJ, tag:形状詞-一般, lemma:様々
# text:要素, pos:NOUN, tag:名詞-普通名詞-一般, lemma:要素
# text:含ん, pos:VERB, tag:動詞-一般, lemma:含む
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:統一, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:統一
# text:扱う, pos:VERB, tag:動詞-一般, lemma:扱う
# text:かつて, pos:ADV, tag:副詞, lemma:かつて
# text:天文, pos:NOUN, tag:名詞-普通名詞-一般, lemma:天文
# text:学, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:学
# text:つい, pos:VERB, tag:動詞-一般, lemma:つく
# text:言及, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:言及
# text:149, pos:NUM, tag:名詞-数詞, lemma:149
# text:後, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:後
# text:天文, pos:NOUN, tag:名詞-普通名詞-一般, lemma:天文
# text:学, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:学
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:扱わ, pos:VERB, tag:動詞-一般, lemma:扱う
# text:今, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:今
# text:物理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:物理
# text:学, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:学
# text:そう, pos:ADV, tag:副詞, lemma:そう
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:扱わ, pos:VERB, tag:動詞-一般, lemma:扱う
# text:述べ, pos:VERB, tag:動詞-一般, lemma:述べる
# text:伊勢田, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:伊勢田
# text:対し, pos:VERB, tag:動詞-一般, lemma:対する
# text:須藤, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:須藤
# text:通り, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:通り
# text:それ, pos:PRON, tag:代名詞, lemma:それ
# text:自体, pos:NOUN, tag:名詞-普通名詞-一般, lemma:自体
# text:何, pos:PRON, tag:代名詞, lemma:何
# text:問題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:問題
# text:ある, pos:VERB, tag:動詞-非自立可能, lemma:ある
# text:返し, pos:VERB, tag:動詞-一般, lemma:返す
# text:149, pos:NUM, tag:名詞-数詞, lemma:149
# text:須藤, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:須藤
# text:次, pos:NOUN, tag:名詞-普通名詞-一般, lemma:次
# text:よう, pos:NOUN, tag:形状詞-助動詞語幹, lemma:よう
# text:述べ, pos:VERB, tag:動詞-一般, lemma:述べる
# text:135, pos:NUM, tag:名詞-数詞, lemma:135
# text:私, pos:PRON, tag:代名詞, lemma:私
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:物理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:物理
# text:学, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:対し, pos:VERB, tag:動詞-一般, lemma:対する
# text:何, pos:PRON, tag:代名詞, lemma:何
# text:ら, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:ら
# text:助言, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:助言
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:聞い, pos:VERB, tag:動詞-一般, lemma:聞く
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:ない, pos:ADJ, tag:形容詞-非自立可能, lemma:ない
# text:おそらく, pos:ADV, tag:副詞, lemma:おそらく
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:一般, pos:NOUN, tag:名詞-普通名詞-一般, lemma:一般
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:ほとんど, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:ほとんど
# text:没, pos:NOUN, tag:接頭辞, lemma:没
# text:交渉, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:交渉
# text:言っ, pos:VERB, tag:動詞-一般, lemma:言う
# text:差し, pos:VERB, tag:動詞-一般, lemma:差す
# text:支え, pos:VERB, tag:動詞-一般, lemma:支える
# text:状況, pos:NOUN, tag:名詞-普通名詞-一般, lemma:状況
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:科学, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:科学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:価値, pos:NOUN, tag:名詞-普通名詞-一般, lemma:価値
# text:観, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:観
# text:溝, pos:NOUN, tag:名詞-普通名詞-一般, lemma:溝
# text:深い, pos:ADJ, tag:形容詞-一般, lemma:深い
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:確実, pos:ADJ, tag:形状詞-一般, lemma:確実
# text:須藤, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:須藤
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:論じ, pos:VERB, tag:動詞-一般, lemma:論ずる
# text:原因, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:原因
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:言葉, pos:NOUN, tag:名詞-普通名詞-一般, lemma:言葉
# text:取り, pos:VERB, tag:動詞-一般, lemma:取る
# text:原因, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:原因
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:言葉, pos:NOUN, tag:名詞-普通名詞-一般, lemma:言葉
# text:具体, pos:NOUN, tag:名詞-普通名詞-一般, lemma:具体
# text:定義, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:定義
# text:限り, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:限り
# text:それ, pos:PRON, tag:代名詞, lemma:それ
# text:以上, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:以上
# text:議論, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:議論
# text:不, pos:NOUN, tag:接頭辞, lemma:不
# text:可能, pos:ADJ, tag:形状詞-一般, lemma:可能
# text:151, pos:NUM, tag:名詞-数詞, lemma:151
# text:述べ, pos:VERB, tag:動詞-一般, lemma:述べる
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:興味, pos:NOUN, tag:名詞-普通名詞-一般, lemma:興味
# text:持っ, pos:VERB, tag:動詞-一般, lemma:持つ
# text:因果, pos:NOUN, tag:名詞-普通名詞-形状詞可能, lemma:因果
# text:定義, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:定義
# text:物理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:物理
# text:学, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:違う, pos:VERB, tag:動詞-一般, lemma:違う
# text:こと, pos:NOUN, tag:名詞-普通名詞-一般, lemma:こと
# text:確か, pos:ADJ, tag:形状詞-一般, lemma:確か
# text:し, pos:VERB, tag:動詞-非自立可能, lemma:する
# text:152, pos:NUM, tag:名詞-数詞, lemma:152
# text:伊勢田, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:伊勢田
# text:思っ, pos:VERB, tag:動詞-一般, lemma:思う
# text:以上, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:以上
# text:物理, pos:NOUN, tag:名詞-普通名詞-一般, lemma:物理
# text:学, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:哲学, pos:NOUN, tag:名詞-普通名詞-一般, lemma:哲学
# text:者, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:者
# text:もの, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:もの
# text:見え, pos:VERB, tag:動詞-一般, lemma:見える
# text:方, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:方
# text:違い, pos:NOUN, tag:名詞-普通名詞-一般, lemma:違い
# text:いう, pos:VERB, tag:動詞-一般, lemma:いう
# text:大きい, pos:ADJ, tag:形容詞-一般, lemma:大きい
# text:しれ, pos:VERB, tag:動詞-一般, lemma:しれる
# text:述べ, pos:VERB, tag:動詞-一般, lemma:述べる
# text:153, pos:NUM, tag:名詞-数詞, lemma:153
# text:対談, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:対談
# text:須藤, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:須藤
# text:これ, pos:PRON, tag:代名詞, lemma:これ
# text:けっこう, pos:ADJ, tag:形状詞-一般, lemma:けっこう
# text:長, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:長
# text:時間, pos:NOUN, tag:名詞-普通名詞-助数詞可能, lemma:時間
# text:議論, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:議論
# text:行っ, pos:VERB, tag:動詞-一般, lemma:行う
# text:おかげ, pos:NOUN, tag:名詞-普通名詞-一般, lemma:おかげ
# text:意見, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:意見
# text:違い, pos:NOUN, tag:名詞-普通名詞-一般, lemma:違い
# text:明らか, pos:ADJ, tag:形状詞-一般, lemma:明らか
# text:思い, pos:VERB, tag:動詞-一般, lemma:思う
# text:果たして, pos:ADV, tag:副詞, lemma:果たして
# text:何, pos:PRON, tag:代名詞, lemma:何
# text:決着, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:決着
# text:つく, pos:VERB, tag:動詞-非自立可能, lemma:つく
# text:発言, pos:VERB, tag:名詞-普通名詞-サ変可能, lemma:発言
# text:伊勢田, pos:PROPN, tag:名詞-固有名詞-人名-姓, lemma:伊勢田
# text:決着, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:決着
# text:つか, pos:VERB, tag:動詞-非自立可能, lemma:つく
# text:答え, pos:VERB, tag:動詞-一般, lemma:答える
# text:154, pos:NUM, tag:名詞-数詞, lemma:154
# text:学術, pos:NOUN, tag:名詞-普通名詞-一般, lemma:学術
# text:書, pos:NOUN, tag:接尾辞-名詞的-一般, lemma:書
# text:辞, pos:NOUN, tag:名詞-普通名詞-一般, lemma:辞
# text:事典, pos:NOUN, tag:名詞-普通名詞-一般, lemma:事典
# text:報道, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:報道
# text:活用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:活用
# text:事例, pos:NOUN, tag:名詞-普通名詞-一般, lemma:事例
# text:研究, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:研究
# text:課題, pos:NOUN, tag:名詞-普通名詞-一般, lemma:課題
# text:関連, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:関連
# text:分野, pos:NOUN, tag:名詞-普通名詞-一般, lemma:分野
# text:他, pos:NOUN, tag:名詞-普通名詞-副詞可能, lemma:他
# text:関連, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:関連
# text:項目, pos:NOUN, tag:名詞-普通名詞-一般, lemma:項目
# text:応用, pos:NOUN, tag:名詞-普通名詞-サ変可能, lemma:応用
# text:人工, pos:NOUN, tag:名詞-普通名詞-一般, lemma:人工
# text:知能, pos:NOUN, tag:名詞-普通名詞-一般, lemma:知能
# text:未来, pos:NOUN, tag:名詞-普通名詞-一般, lemma:未来
# text:関わる, pos:VERB, tag:動詞-一般, lemma:関わる
# text:項目, pos:NOUN, tag:名詞-普通名詞-一般, lemma:項目

# %%
# すべてのlemmaを半角スペースでつないで、長い文字列にする。

doc_AI = ' '.join(tokens)
print(doc_AI)
# Out:
# 人工 知能 じん こうち 英 artificial intelligence AI エーアイ 計算 computation いう 概念 コンピュータ Computer いう 道具 用いる 知能 研究 計算 機 科学 computer science 一 分野 指す 語 1 言語 理解 推論 問題 解決 知的 行動 人間 代わる コンピューター 行う 技術 2 また 計算 機 コンピュータ よる 知的 情報 処理 システム 設計 実現 関する 研究 分野 する 3 日本 大 百科 全書 ニッポニカ 解説 情報 工学 者 通信 工学 者 佐藤 理史 次 よう 述べる 1 人間 知的 能力 コンピュータ 上 実現 様々 技術 ソフトウェア コンピュータ システム 4 応用 例 自然 言語 処理 機械 翻訳 かな 漢字 変換 構文 解析 等 5 専門 家 推論 判断 模倣 エキスパート システム 画像 データ 解析 特定 パターン 検出 抽出 画像 認識 等 ある 4 1956 年 ダートマス 会議 ジョン マッカーシー よる 命名 現在 記号 処理 用いる 知能 記述 主体 する 情報 処理 研究 アプローチ いう 意味 あい 使う 家庭 用 電気 機械 器具 制御 システム ゲーム ソフト 思考 ルーチン こう 呼ぶ こと ある プログラミング 言語 LISP よる ELIZA いう カウンセラー 模倣 プログラム 人工 無脳 しばしば 引き合い 出す 計算 機 人間 専門 家 役割 する いう エキスパート システム 呼ぶ 研究 情報 処理 システム 実現 人間 暗黙 持つ 常識 記述 問題 なる 実用 利用 困難 視 人工 知能 実現 アプローチ する ファジィ 理論 ニューラル ネットワーク よう アプローチ 知る 従来 人工 知能 gofai good Old fashioned AI 差 記述 記号 明示 性 ある 後 サポート ベクター マシン 注目 集める また 自ら 経験 元 学習 行う 強化 学習 いう 手法 ある 宇宙 おく 知性 最も 強力 形質 レイ カーツ ワイル いう 言葉 通り 知性 機械 表現 実装 いう こと 極めて 重要 作業 2006 年 ディープ ラーニング 深層 学習 登場 2010 年 代 以降 ビッグ データ 登場 よる 一過 性 流行 超える 社会 浸透 2016 年 2017 年 かける ディープ ラーニング 導入 AI 完全 情報 ゲーム 囲碁 トップ 棋士 さらに 不 完全 情報 ゲーム ポーカー 世界 トップ クラス プレイヤー 破る 6 7 麻雀 Microsoft suphx super Phoenix AI する 初めて 十 段 到達 8 時代 最 先端 技術 なる 9 第 2 次 人工 知能 ブーム 人工 知能 機械 学習 呼ぶ 以下 よう もの ある 一方 計算 知能 CI 開発 学習 繰る 返す こと 基本 する 例えば パラメータ 調整 コネクショニズム システム 学習 経験 基づく 手法 非 記号 AI 美しい ない AI 注 1 ソフト コンピューティング 関係 手法 する 以下 もの ある これ ら 統合 知的 システム 作る 試み なす ACT r エキスパート 推論 ルール 統計 学習 元 ニューラル ネットワーク 生成 規則 通す 生成 第 3 次 人工 知能 ブーム ディープ ラーニング 画像 認識 テキスト 解析 音声 認識 様々 領域 第 2 次 人工 知能 ブーム 人工 知能 上回る 精度 出す ディープ ラーニング 研究 盛ん 行う 最近 DQN CNN rnn gan 様々 ディープ ラーニング 派生 でる 各 分野 活躍 特に gan 敵対 生成 ネットワーク ディープ ラーニング 認識 予測 分野 成果 だす こと 加える 画像 生成 技術 おく 進化 見せる 森 正弥 これ ら 成果 背景 従来 人工 知能 応用 分野 広がる Creative AI いう コンテンツ 生成 行う 応用 始まる 指摘 10 AI 構築 長い 間 試みる シンボルグラウンディング 問題 フレーム 問題 解決 壁 なる 17 世紀 初め ルネ デカルト 動物 身体 ただ 複雑 機械 提唱 機械 論 ブレーズ パスカル 1642 年 最初 機械 式 計算 機 製作 チャールズ バベッジ エイダ ラブレス プログラム 可能 機械 式 計算 機 開発 行う バートランド ラッセル アルフレッド ノース ホワイトヘッド 数学 原理 出版 形式 論理 革命 もたらす ウォーレン マカロック ウォルター ピッツ 神経 活動 内在 アイデア 論理 計算 題する 論文 1943 年 発表 ニューラル ネットワーク 基礎 築く 1950 年 代 なる AI 関する 活発 成果 出る ジョン マッカーシー AI 関する 最初 会議 人工 知能 注 2 いう 用語 作る 彼 また プログラミング 言語 LISP 開発 知的 ふるまい 関する テスト 可能 方法 する アラン チューリング チューリング テスト 導入 ジョセフ ワイゼンバウム ELIZA 構築 これ 来談 者 中心 療法 行う お しゃべり ロボット 注 3 1956 年 行う ダートマス 会議 開催 提案 書 おく 人類 史 上 用語 する 初めて 使用 新た 分野 する 創立 1960 年 代 1970 年 代 間 ジョエル モーゼス macsyma マクシマ プログラム 注 4 中 積分 問題 記号 推論 パワー 示す マービン ミンスキー シーモア パパート パーセプトロン 出版 単純 ニューラル ネット 限界 示す アラン カルメラウアー プログラミング 言語 prolog 開発 テッド ショートリッフェ 医学 診断 療法 おく ルール ベース システム 構築 知識 表現 推論 パワー 示す これ 最初 エキスパート システム 呼ぶ こと ある ハンス モラベック 障害 物 ある コース 自律 走行 最初 コンピューター 制御 乗り物 開発 1980 年 代 ニューラル ネットワーク バック プロパゲーション アルゴリズム よる 広い 使う また 時代 ロドニー ブルックス 知能 身体 必須 学説 身体 性 提唱 1990 年 代 AI 多く 分野 様々 アプリケーション 成果 上げる 特に ボード ゲーム 目覚ましい 1992 年 IBM 世界 チャンピオン 匹敵 バックギャモン 専用 コンピュータ td ギャモン 開発 IBM チェス 専用 コンピュータ ディープ ブルー 1997 年 5 月 ガルリ カスパロフ 打つ 負かす 同年 8 月 オセロ 日本 電気 オセロ 専用 コンピュータ ロジステロ 世界 チャンピオン 村上 健 敗れる 11 国防 高等 研究 計画 局 最初 湾岸 戦争 おく ユニット スケジューリング AI 使う これ よる 省く コスト 1950 年 代 以来 AI 研究 政府 投資 全額 上回る こと 明らか 日本 甘利 俊一 日本 学士 院 会員 ら 精力 啓蒙 優秀 成果 発生 論理 ブラック ボックス 性 指摘 1998 年 非 構造 化 データ 形式 国際 規格 XML 提唱 ここ web 上 非 構造 化 データ 対する アプリケーション 別 適する 意味 付け 適用 処理 行う 試み 開始 同年 W 3 c ティム バーナーズ リー よる web 知的 処理 行う セマンティック ウェブ 提唱 技術 web 上 データ 意味 付加 コンピュータ 知的 処理 行う 方法 国際 規格 化 もの 規格 知識 工学 おく オントロジー 表現 データ 形式 owl 含む こと かつて 流行 エキスパート システム 亜種 こと 分かる 2000 年 代 前半 規格 化 完了 web 開発 者 とる 開発 工数 見る メリット 見出せる こと 現在 普及 する 日本 おく エキスパート システム 流行 後 ニューロ ファジィ 流行 しかし 研究 進む つれる 計算 リソース データ 量 不足 シンボルグラウンディング 問題 フレーム 問題 直面 産業 在る 方 激変 AI 至る こと 無い ブーム 終焉 1980 年 代 入る 大 企業 研究 所 中心 知識 工学 基づく エキスパート システム 多数 提案 エキスパート システム 専門 する AI ベンチャー 次々 立つ 上がる 流行 生まれる 究極 プロジェクト する 第 五 世代 コンピュータ 挙げる 1982 年 1992 年 日本 国家 プロジェクト する 570億 円 費やす 第 五 世代 コンピュータ 研究 進める 採用 知識 工学 手法 膨大 ルール 手 入力 必要 専門 家 間 専門 知識 解釈 異なる 場合 統一 ルール 化 行える 等 問題 ある 実用 エキスパート システム 実現 至る 実現 成果 物 prolog 命令 直接 CPU ハードウェア 機構 解釈 高速 実行 並列 型 prolog 専用 機 商業 意味 応用 先 全く 見つかる 1980 年 代 後半 1990 年 代 中頃 かける 従来 電子 制御 手法 する 用いる on OFF 制御 pid 制御 現代 制御 問題 克服 ため 知的 制御 盛ん 研究 知識 工学 ルール 用いる ファジィ 制御 データ 特徴 学習 分類 ニューラル ネットワーク 2 つ  ...

# %% [markdown]
# ### 上記の操作をまとめておこなう関数を定義しておく。
# * 後で、各エントリについて、この関数を呼び出す。

# %%
def morph(soup):

  lines = list()
  for para in soup.find_all('p'):
    lines.append(para.text)

  tabu = ['SPACE', 'PUNCT', 'AUX', 'ADP', 'SYM', 'DET', 'SCONJ', 'PART']
  tokens = list()
  for line in lines:
    for token in nlp(line):
      pos = token.pos_
      if not pos in tabu:
        tokens.append(token.lemma_)

  return ' '.join(tokens)

# %% [markdown]
# ## 課題の手順(2)

# %% [markdown]
# ### 「コンピュータ科学」の様々な分野に関するエントリについて、この作業をしてみる。
# *  「人工知能」エントリの下部にある「コンピュータ科学」の分野一覧から、aタグのhref属性にあるURLを抜き出す。
# * ただし、__`/wiki/`__という文字列で始まっているURLであり、かつ、テンプレートの状態でないものだけを抜き出す。

# %%
# 「人工知能」エントリの下部にある「コンピュータ科学」の分野一覧から、aタグのhref属性にあるURLを抜き出す。

target_str = '表話編歴コンピュータ科学'
prefix = '/wiki/'

urls = dict()
for table in soup.find_all('table'):
  if table.text[:len(target_str)] != target_str: continue
  for td in table.find_all('td'):
    for a in td.find_all('a'):
      if not a.text: continue
      try:
        if a.text.find('英語版') == -1:
          href = a['href']
          if href[:len(prefix)] == prefix and href.find('/Template:') == -1 and href.find('/Category:') == -1:
            urls[a.text] = 'https://ja.wikipedia.org' + href
      except:
        continue

for k in urls:
  print(k, urls[k])
# Out:
# コンピュータ科学 https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E7%A7%91%E5%AD%A6
# ハードウェア https://ja.wikipedia.org/wiki/%E3%83%8F%E3%83%BC%E3%83%89%E3%82%A6%E3%82%A7%E3%82%A2
# プリント基板 https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%AA%E3%83%B3%E3%83%88%E5%9F%BA%E6%9D%BF
# 周辺機器 https://ja.wikipedia.org/wiki/%E5%91%A8%E8%BE%BA%E6%A9%9F%E5%99%A8
# 集積回路 https://ja.wikipedia.org/wiki/%E9%9B%86%E7%A9%8D%E5%9B%9E%E8%B7%AF
# Systems on Chip (SoCs) https://ja.wikipedia.org/wiki/System-on-a-chip
# エネルギー消費 (グリーン・コンピューティング) https://ja.wikipedia.org/wiki/%E3%82%B0%E3%83%AA%E3%83%BC%E3%83%B3IT
# EDA https://ja.wikipedia.org/wiki/EDA
# ハードウェアアクセラレーション https://ja.wikipedia.org/wiki/%E3%83%8F%E3%83%BC%E3%83%89%E3%82%A6%E3%82%A7%E3%82%A2%E3%82%A2%E3%82%AF%E3%82%BB%E3%83%A9%E3%83%AC%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3
# コンピュータ・アーキテクチャ https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%83%BB%E3%82%A2%E3%83%BC%E3%82%AD%E3%83%86%E3%82%AF%E3%83%81%E3%83%A3
# 組み込みシステム https://ja.wikipedia.org/wiki/%E7%B5%84%E3%81%BF%E8%BE%BC%E3%81%BF%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0
# リアルタイムシステム https://ja.wikipedia.org/wiki/%E3%83%AA%E3%82%A2%E3%83%AB%E3%82%BF%E3%82%A4%E3%83%A0%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0
# ディペンダビリティ https://ja.wikipedia.org/wiki/%E3%83%87%E3%82%A3%E3%83%9A%E3%83%B3%E3%83%80%E3%83%93%E3%83%AA%E3%83%86%E3%82%A3
# ネットワーク https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%83%8D%E3%83%83%E3%83%88%E3%83%AF%E3%83%BC%E3%82%AF
# 通信プロトコル https://ja.wikipedia.org/wiki/%E9%80%9A%E4%BF%A1%E3%83%97%E3%83%AD%E3%83%88%E3%82%B3%E3%83%AB
# インタプリタ https://ja.wikipedia.org/wiki/%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%97%E3%83%AA%E3%82%BF
# ミドルウェア https://ja.wikipedia.org/wiki/%E3%83%9F%E3%83%89%E3%83%AB%E3%82%A6%E3%82%A7%E3%82%A2
# 仮想マシン https://ja.wikipedia.org/wiki/%E4%BB%AE%E6%83%B3%E3%83%9E%E3%82%B7%E3%83%B3
# オペレーティングシステム https://ja.wikipedia.org/wiki/%E3%82%AA%E3%83%9A%E3%83%AC%E3%83%BC%E3%83%86%E3%82%A3%E3%83%B3%E3%82%B0%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0
# ソフトウェア品質 https://ja.wikipedia.org/wiki/%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E5%93%81%E8%B3%AA
# ツール https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E3%83%84%E3%83%BC%E3%83%AB
# プログラミングパラダイム https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E3%83%91%E3%83%A9%E3%83%80%E3%82%A4%E3%83%A0
# プログラミング言語 https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E8%A8%80%E8%AA%9E
# コンパイラ https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%91%E3%82%A4%E3%83%A9
# ドメイン固有言語 https://ja.wikipedia.org/wiki/%E3%83%89%E3%83%A1%E3%82%A4%E3%83%B3%E5%9B%BA%E6%9C%89%E8%A8%80%E8%AA%9E
# モデリング言語 https://ja.wikipedia.org/wiki/%E3%83%A2%E3%83%87%E3%83%AA%E3%83%B3%E3%82%B0%E8%A8%80%E8%AA%9E
# ソフトウェアフレームワーク https://ja.wikipedia.org/wiki/%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E3%83%95%E3%83%AC%E3%83%BC%E3%83%A0%E3%83%AF%E3%83%BC%E3%82%AF
# 統合開発環境 https://ja.wikipedia.org/wiki/%E7%B5%B1%E5%90%88%E9%96%8B%E7%99%BA%E7%92%B0%E5%A2%83
# ソフトウェア構成管理 https://ja.wikipedia.org/wiki/%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E6%A7%8B%E6%88%90%E7%AE%A1%E7%90%86
# ソフトウェアライブラリ https://ja.wikipedia.org/wiki/%E3%83%A9%E3%82%A4%E3%83%96%E3%83%A9%E3%83%AA
# ソフトウェアリポジトリ https://ja.wikipedia.org/wiki/%E3%83%AA%E3%83%9D%E3%82%B8%E3%83%88%E3%83%AA
# ソフトウェア開発 https://ja.wikipedia.org/wiki/%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E9%96%8B%E7%99%BA
# ソフトウェア開発プロセス https://ja.wikipedia.org/wiki/%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E9%96%8B%E7%99%BA%E3%83%97%E3%83%AD%E3%82%BB%E3%82%B9
# 要求分析 https://ja.wikipedia.org/wiki/%E8%A6%81%E6%B1%82%E5%88%86%E6%9E%90
# ソフトウェア設計 https://ja.wikipedia.org/wiki/%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E8%A8%AD%E8%A8%88
# ソフトウェアデプロイメント https://ja.wikipedia.org/wiki/%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E3%83%87%E3%83%97%E3%83%AD%E3%82%A4%E3%83%A1%E3%83%B3%E3%83%88
# ソフトウェアメンテナンス https://ja.wikipedia.org/wiki/%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2%E3%83%A1%E3%83%B3%E3%83%86%E3%83%8A%E3%83%B3%E3%82%B9
# オープンソースモデル https://ja.wikipedia.org/wiki/%E3%82%AA%E3%83%BC%E3%83%97%E3%83%B3%E3%82%BD%E3%83%BC%E3%82%B9%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2
# 計算理論 https://ja.wikipedia.org/wiki/%E8%A8%88%E7%AE%97%E7%90%86%E8%AB%96
# 計算モデル https://ja.wikipedia.org/wiki/%E8%A8%88%E7%AE%97%E3%83%A2%E3%83%87%E3%83%AB
# 形式言語 https://ja.wikipedia.org/wiki/%E5%BD%A2%E5%BC%8F%E8%A8%80%E8%AA%9E
# オートマトン理論 https://ja.wikipedia.org/wiki/%E3%82%AA%E3%83%BC%E3%83%88%E3%83%9E%E3%83%88%E3%83%B3%E7%90%86%E8%AB%96
# 計算可能性理論 https://ja.wikipedia.org/wiki/%E8%A8%88%E7%AE%97%E5%8F%AF%E8%83%BD%E6%80%A7%E7%90%86%E8%AB%96
# 計算複雑性理論 https://ja.wikipedia.org/wiki/%E8%A8%88%E7%AE%97%E8%A4%87%E9%9B%91%E6%80%A7%E7%90%86%E8%AB%96
# 意味論 https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%A0%E6%84%8F%E5%91%B3%E8%AB%96
# アルゴリズム https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%AB%E3%82%B4%E3%83%AA%E3%82%BA%E3%83%A0
# アルゴリズム解析 https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%AB%E3%82%B4%E3%83%AA%E3%82%BA%E3%83%A0%E8%A7%A3%E6%9E%90
# 乱択アルゴリズム https://ja.wikipedia.org/wiki/%E4%B9%B1%E6%8A%9E%E3%82%A2%E3%83%AB%E3%82%B4%E3%83%AA%E3%82%BA%E3%83%A0
# 計算幾何学 https://ja.wikipedia.org/wiki/%E8%A8%88%E7%AE%97%E5%B9%BE%E4%BD%95%E5%AD%A6
# 離散数学 https://ja.wikipedia.org/wiki/%E9%9B%A2%E6%95%A3%E6%95%B0%E5%AD%A6
# 確率 https://ja.wikipedia.org/wiki/%E7%A2%BA%E7%8E%87
# 統計学 https://ja.wikipedia.org/wiki/%E7%B5%B1%E8%A8%88%E5%AD%A6
# 数学ソフトウェア https://ja.wikipedia.org/wiki/%E6%95%B0%E5%AD%A6%E3%82%BD%E3%83%95%E3%83%88%E3%82%A6%E3%82%A7%E3%82%A2
# 情報理論 https://ja.wikipedia.org/wiki/%E6%83%85%E5%A0%B1%E7%90%86%E8%AB%96
# 解析学 https://ja.wikipedia.org/wiki/%E8%A7%A3%E6%9E%90%E5%AD%A6
# 数値解析 https://ja.wikipedia.org/wiki/%E6%95%B0%E5%80%A4%E8%A7%A3%E6%9E%90
# 情報システム https://ja.wikipedia.org/wiki/%E6%83%85%E5%A0%B1%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0
# データベース管理システム https://ja.wikipedia.org/wiki/%E3%83%87%E3%83%BC%E3%82%BF%E3%83%99%E3%83%BC%E3%82%B9
# 情報ストレージシステム https://ja.wikipedia.org/wiki/%E8%A8%98%E6%86%B6%E8%A3%85%E7%BD%AE
# 企業情報システム https://ja.wikipedia.org/wiki/%E4%BC%81%E6%A5%AD%E6%83%85%E5%A0%B1%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0
# 地理情報システム https://ja.wikipedia.org/wiki/%E5%9C%B0%E7%90%86%E6%83%85%E5%A0%B1%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0
# 意思決定支援システム https://ja.wikipedia.org/wiki/%E6%84%8F%E6%80%9D%E6%B1%BA%E5%AE%9A%E6%94%AF%E6%8F%B4%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0
# プロセス制御システム https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%AD%E3%82%BB%E3%82%B9%E5%88%B6%E5%BE%A1
# データマイニング https://ja.wikipedia.org/wiki/%E3%83%87%E3%83%BC%E3%82%BF%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0
# 電子図書館 https://ja.wikipedia.org/wiki/%E9%9B%BB%E5%AD%90%E5%9B%B3%E6%9B%B8%E9%A4%A8
# コンピューティング・プラットフォーム https://ja.wikipedia.org/wiki/%E3%83%97%E3%83%A9%E3%83%83%E3%83%88%E3%83%95%E3%82%A9%E3%83%BC%E3%83%A0_(%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%83%86%E3%82%A3%E3%83%B3%E3%82%B0)
# World Wide Web https://ja.wikipedia.org/wiki/World_Wide_Web
# 情報検索 https://ja.wikipedia.org/wiki/%E6%83%85%E5%A0%B1%E6%A4%9C%E7%B4%A2
# セキュリティ https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%82%BB%E3%82%AD%E3%83%A5%E3%83%AA%E3%83%86%E3%82%A3
# 暗号理論 https://ja.wikipedia.org/wiki/%E6%9A%97%E5%8F%B7%E7%90%86%E8%AB%96
# 形式手法 https://ja.wikipedia.org/wiki/%E5%BD%A2%E5%BC%8F%E6%89%8B%E6%B3%95
# 侵入検知システム https://ja.wikipedia.org/wiki/%E4%BE%B5%E5%85%A5%E6%A4%9C%E7%9F%A5%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0
# ネットワーク・セキュリティ https://ja.wikipedia.org/wiki/%E3%83%8D%E3%83%83%E3%83%88%E3%83%AF%E3%83%BC%E3%82%AF%E3%83%BB%E3%82%BB%E3%82%AD%E3%83%A5%E3%83%AA%E3%83%86%E3%82%A3
# 情報セキュリティ https://ja.wikipedia.org/wiki/%E6%83%85%E5%A0%B1%E3%82%BB%E3%82%AD%E3%83%A5%E3%83%AA%E3%83%86%E3%82%A3
# ヒューマンコンピュータインタラクション https://ja.wikipedia.org/wiki/%E3%83%92%E3%83%A5%E3%83%BC%E3%83%9E%E3%83%B3%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%A9%E3%82%AF%E3%82%B7%E3%83%A7%E3%83%B3
# インタラクションデザイン https://ja.wikipedia.org/wiki/%E3%82%A4%E3%83%B3%E3%82%BF%E3%83%A9%E3%82%AF%E3%82%B7%E3%83%A7%E3%83%B3%E3%83%87%E3%82%B6%E3%82%A4%E3%83%B3
# ユビキタスコンピューティング https://ja.wikipedia.org/wiki/%E3%83%A6%E3%83%93%E3%82%AD%E3%82%BF%E3%82%B9%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%83%86%E3%82%A3%E3%83%B3%E3%82%B0
# 可視化 https://ja.wikipedia.org/wiki/%E5%8F%AF%E8%A6%96%E5%8C%96
# アクセシビリティ https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%82%A2%E3%82%AF%E3%82%BB%E3%82%B7%E3%83%93%E3%83%AA%E3%83%86%E3%82%A3
# 並行性 https://ja.wikipedia.org/wiki/%E4%B8%A6%E8%A1%8C%E6%80%A7
# 並行コンピューティング https://ja.wikipedia.org/wiki/%E4%B8%A6%E8%A1%8C%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%83%86%E3%82%A3%E3%83%B3%E3%82%B0
# 並列コンピューティング https://ja.wikipedia.org/wiki/%E4%B8%A6%E5%88%97%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%83%86%E3%82%A3%E3%83%B3%E3%82%B0
# 分散コンピューティング https://ja.wikipedia.org/wiki/%E5%88%86%E6%95%A3%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%83%86%E3%82%A3%E3%83%B3%E3%82%B0
# マルチスレッディング https://ja.wikipedia.org/wiki/%E3%83%8F%E3%83%BC%E3%83%89%E3%82%A6%E3%82%A7%E3%82%A2%E3%83%9E%E3%83%AB%E3%83%81%E3%82%B9%E3%83%AC%E3%83%83%E3%83%87%E3%82%A3%E3%83%B3%E3%82%B0
# マルチプロセッシング https://ja.wikipedia.org/wiki/%E3%83%9E%E3%83%AB%E3%83%81%E3%83%97%E3%83%AD%E3%82%BB%E3%83%83%E3%82%B7%E3%83%B3%E3%82%B0
# 自然言語処理 https://ja.wikipedia.org/wiki/%E8%87%AA%E7%84%B6%E8%A8%80%E8%AA%9E%E5%87%A6%E7%90%86
# 知識表現と推論 https://ja.wikipedia.org/wiki/%E7%9F%A5%E8%AD%98%E8%A1%A8%E7%8F%BE
# コンピュータビジョン https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%83%93%E3%82%B8%E3%83%A7%E3%83%B3
# 自動計画とスケジューリング https://ja.wikipedia.org/wiki/%E8%87%AA%E5%8B%95%E8%A8%88%E7%94%BB
# 検索手法 https://ja.wikipedia.org/wiki/%E6%95%B0%E7%90%86%E6%9C%80%E9%81%A9%E5%8C%96
# 制御手法 https://ja.wikipedia.org/wiki/%E5%88%B6%E5%BE%A1%E7%90%86%E8%AB%96
# 機械学習 https://ja.wikipedia.org/wiki/%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92
# 教師あり学習 https://ja.wikipedia.org/wiki/%E6%95%99%E5%B8%AB%E3%81%82%E3%82%8A%E5%AD%A6%E7%BF%92
# 教師なし学習 https://ja.wikipedia.org/wiki/%E6%95%99%E5%B8%AB%E3%81%AA%E3%81%97%E5%AD%A6%E7%BF%92
# 強化学習 https://ja.wikipedia.org/wiki/%E5%BC%B7%E5%8C%96%E5%AD%A6%E7%BF%92
# 交差検証 https://ja.wikipedia.org/wiki/%E4%BA%A4%E5%B7%AE%E6%A4%9C%E8%A8%BC
# グラフィックス https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%82%B0%E3%83%A9%E3%83%95%E3%82%A3%E3%83%83%E3%82%AF%E3%82%B9
# アニメーション https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%82%A2%E3%83%8B%E3%83%A1%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3
# レンダリング https://ja.wikipedia.org/wiki/%E3%83%AC%E3%83%B3%E3%83%80%E3%83%AA%E3%83%B3%E3%82%B0_(%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF)
# 画像編集 https://ja.wikipedia.org/wiki/%E5%86%99%E7%9C%9F%E7%B7%A8%E9%9B%86
# GPU https://ja.wikipedia.org/wiki/GPU
# 複合現実 https://ja.wikipedia.org/wiki/%E8%A4%87%E5%90%88%E7%8F%BE%E5%AE%9F
# バーチャル・リアリティ https://ja.wikipedia.org/wiki/%E3%83%90%E3%83%BC%E3%83%81%E3%83%A3%E3%83%AB%E3%83%BB%E3%83%AA%E3%82%A2%E3%83%AA%E3%83%86%E3%82%A3
# 画像圧縮 https://ja.wikipedia.org/wiki/%E7%94%BB%E5%83%8F%E5%9C%A7%E7%B8%AE
# ソリッドモデリング https://ja.wikipedia.org/wiki/%E3%82%BD%E3%83%AA%E3%83%83%E3%83%89%E3%83%A2%E3%83%87%E3%83%AA%E3%83%B3%E3%82%B0
# 電子商取引 https://ja.wikipedia.org/wiki/%E9%9B%BB%E5%AD%90%E5%95%86%E5%8F%96%E5%BC%95
# 企業アプリケーション https://ja.wikipedia.org/wiki/%E4%BC%81%E6%A5%AD%E3%82%A2%E3%83%97%E3%83%AA%E3%82%B1%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3
# 計算物理学 https://ja.wikipedia.org/wiki/%E8%A8%88%E7%AE%97%E7%89%A9%E7%90%86%E5%AD%A6
# 計算化学 https://ja.wikipedia.org/wiki/%E8%A8%88%E7%AE%97%E5%8C%96%E5%AD%A6
# 計算生物学 https://ja.wikipedia.org/wiki/%E8%A8%88%E7%AE%97%E7%94%9F%E7%89%A9%E5%AD%A6
# 計算社会科学 https://ja.wikipedia.org/wiki/%E8%A8%88%E7%AE%97%E7%A4%BE%E4%BC%9A%E7%A7%91%E5%AD%A6
# 健康情報学 https://ja.wikipedia.org/wiki/%E5%81%A5%E5%BA%B7%E6%83%85%E5%A0%B1%E5%AD%A6
# デジタルアート https://ja.wikipedia.org/wiki/%E3%83%87%E3%82%B8%E3%82%BF%E3%83%AB%E3%82%A2%E3%83%BC%E3%83%88
# 電子出版 https://ja.wikipedia.org/wiki/%E9%9B%BB%E5%AD%90%E5%87%BA%E7%89%88
# サイバー戦争 https://ja.wikipedia.org/wiki/%E3%82%B5%E3%82%A4%E3%83%90%E3%83%BC%E6%88%A6%E4%BA%89
# 電子投票 https://ja.wikipedia.org/wiki/%E9%9B%BB%E5%AD%90%E6%8A%95%E7%A5%A8
# コンピュータゲーム https://ja.wikipedia.org/wiki/%E3%82%B3%E3%83%B3%E3%83%94%E3%83%A5%E3%83%BC%E3%82%BF%E3%82%B2%E3%83%BC%E3%83%A0
# ワードプロセッサー https://ja.wikipedia.org/wiki/%E3%83%AF%E3%83%BC%E3%83%89%E3%83%97%E3%83%AD%E3%82%BB%E3%83%83%E3%82%B5%E3%83%BC
# オペレーションズ・リサーチ https://ja.wikipedia.org/wiki/%E3%82%AA%E3%83%9A%E3%83%AC%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3%E3%82%BA%E3%83%BB%E3%83%AA%E3%82%B5%E3%83%BC%E3%83%81
# 教育工学 https://ja.wikipedia.org/wiki/%E6%95%99%E8%82%B2%E5%B7%A5%E5%AD%A6
# 文書管理システム https://ja.wikipedia.org/wiki/%E6%96%87%E6%9B%B8%E7%AE%A1%E7%90%86%E3%82%B7%E3%82%B9%E3%83%86%E3%83%A0

# %%
# 各エントリをダウンロードしてparserのインスタンスを作り、辞書として保存。

soups = dict()
for k in urls:
  html = urlopen(urls[k]) 
  soups[k] = BeautifulSoup(html, 'html.parser')

# %%
# 先ほど定義した関数morph()を使って各エントリを形態素解析し、lemmaが半角スペースで区切られた文字列へ変換する。

genre = list()
corpus = list()
for k in soups:
  genre.append(k)
  doc = morph(soups[k])
  corpus.append(doc)
  print(k, doc)
# Out:
# コンピュータ科学 計算 機 科学 けい さん かがく 英 computer science コンピュータ 科学 情報 計算 理論 基礎 及び コンピュータ 上 実装 応用 関する 研究 分野 1 2 3 コンピュータ 科学 様々 分野 ある コンピュータ グラフィックス よう 応用 力点 ある 領域 ある 理論 計算 機 科学 呼ぶ 分野 よう 数学 性格 強い 分野 ある 計算 科学 科学 技術 計算 いう 計算 需要 応える ため 分野 それ 実現 手段 研究 高 性能 計算 また 一見 わかる 分類 する 計算 機 工学 ハードウェア プログラミング ソフトウェア いう 分類 ある 再 構成 可能 コンピューティング よう 両方 言える 分野 ある 単純 分類 できる もの ない そろばん アバカス 一種 アナログ 計算 機 言える 機械 いう 計算 手助け もの 古代 存在 計算 機械 今日 言う 機械 する 最初 機械 式 計算 機 ヴィルヘルム シッカート よる 1623 年 作る 4 チャールズ バベッジ ヴィクトリア 朝 時代 プログラム 可能 解析 機関 設計 5 1890 年 ハーマン ホレリス 発明 パンチ カード システム 米国 勢 調査 初めて 使用 6 1920 年 代 以前 Computer いう 言葉 仕事 する 計算 行う 人 計算 手 指す しかし 時代 現代 通じる 計算 理論 計算 模型 考案 クルト ゲーデル アロンゾ チャーチ アラン チューリング 後 計算 機 科学 呼ぶ 分野 先駆 者 計算 可能 性 すなわち 特別 前提 知識 技能 なし 紙 鉛筆 命令 書 もの 計算 興味 抱く 研究 一部 人間 付き物 間違い する こと ない 自動 計算 行う 計算 機械 開発 いう 欲求 基づく もの 重要 洞察 あらゆる 計算 作業 理論 上 全て 実行 可能 汎用 計算 システム 構築 こと 意味 それ 専用 機械 汎用 計算 機 概念 一般 化 汎用 計算 機 いう 概念 創造 現代 計算 機 科学 生む 1940 年 代 入る より 新しい かつ 強力 計算 機 開発 つれる Computer いう 言葉 人間 ない そう いう 機械 指す 言葉 なる 1940 年 代 1950 年 代 かける 次々 電子 式 コンピュータ 建造 1950 年 代 末 基本 考える 方 する 現代 引く 継ぐ 仕組み プログラム 内蔵 方式 完成 前述 米国 国勢 調査 おく パンチ カード システム 有用 事例 ある 科学 技術 おく 数 計算 数値 解析 計算 ない もっと 一般 事務 処理 いう データ 処理 こう いう 機械 有用 いう こと 以前 明らか わけ そう いう 狭義 計算 広い 意味 指す 語 する 1960 年 頃 注釈 1 主に 学術 方面 INFORMATION processing 情報 処理 いう 熟語 使う 機械 翻訳 パターン 認識 よう 数値 計算 ない 応用 研究 始まる また 主に 産業 方面 data processing データ 処理 いう 熟語 ある edp いう 3 文字 語 ある コンピューティング いう 語 意味 それ ら 含む 広い 意味 する 計算 機 科学 それ ら 扱う 科学 いう こと なる 1960 年 代 計算 機 科学 独立 学問 分野 する 確立 大学 計算 機 科学 科 設立 学位 認定 行う 7 実用 コンピュータ 利用 可能 様々 応用 下位 領域 形成 2000 年 前後 IT いう 語 流行 一部 大学 コンピュータ 科学 専攻 する 部門 ある まず 近年 コンピュータ 科学 計算 装置 コンピュータ 普及 もの する すべて 人 とる 基本 技術 する 計算 論 思考 computational thinking いう もの 考える 詳細 文献 8 参照 後述 国際 学会 取る まとめる カリキュラム 重視 各論 カリキュラム する 離散 構造 プログラミング 計算 理論 アルゴリズム 解析 形式 手法 並行 性 理論 データベース コンピュータ グラフィックス システム 解析 ある また スタンフォード computer science Department CS バークレイ MIT electrical engineering AND computer science EECS いう 一般 分野 トップ クラス 目す 大学 いく つ 電気 電子 工学 日本 語 使う 分ける 英語 electrical engineering まとめる こと 多い 名前 付ける コンピュータ 科学 専攻 ため カリキュラム 案 する 国際 学会 acm とる まとめる もの ある 1968 年 curriculum 68 以来 定期 情勢 合わせる 2015 年 現在 最新 版 CS 2013 computer science 2013 curriculum guidelines for undergraduate Programs In computer science 日本 情報 処理 学会 これ 合わせる カリキュラム 標準 発表 2015 年 現在 最新 版 j 07 9 他 コンピュータ 科学 以外 専攻 おく プログラミング 教える それ ら もっぱら コンピュータ 科学 一部 する 物理 化学 あるいは 計算 言語 学 いう 分野 おく コンピュータ 道具 する 使う ため もの する 教える なお コンピュータ 科学 いう 用語 つく 情報 処理 学会 カリキュラム j 97 大学 理工 系 学 部 情報 系 学科 ため コンピュータ サイエンス 教育 カリキュラム j 97 10 コンピュータ サイエンス 情報 工学 情報 科学 計算 機 科学 計算 機 工学 総称 する それぞれ 語 特に 定義 与える わけ ない ため 語 てんで 使う 実態 反映 もの 思う 学問 する 歴史 浅い 計算 機 科学 科学 社会 数々 根源 貢献 する 計算 機 科学 関係 深い 学問 分野 する 経済 学 数学 物理 学 言語 学 挙げる こと できる 一部 人々 誰 計算 機 科学 数学 関連 深い みなす いう 7 初期 計算 機 科学 クルト ゲーデル アラン チューリング 数学 業績 強い 影響 受ける 数理 論理 学 圏 論 領域 理論 代数 学 いう 領域 計算 機 科学 数学 間 アイデア やり取り 領域 なる 計算 機 科学 ソフトウェア 工学 関係 論争 的 ソフトウェア 工学 いう 言葉 表す もの 何 計算 機 科学 範囲 どう 定める 長年 議論 対象 なる 一部 人々 誰 ソフトウェア 工学 計算 機 科学 一部 信ずる 他 人々 計算 機 科学 計算 全般 扱う 学問 対する ソフトウェア 工学 実用 目的 コンピュータ 処理 設計 もの 異なる 学問 分野 考える 方 例 する デイビッド パーナス いる 13 他 人々 誰 ソフトウェア 全く 工学 扱う こと できる 考える
# ハードウェア ハードウェア 英語 hardware システム 物理 構成 要素 指す 一般 用語 日本 語 機械 装置 設備 こと 指す ソフトウェア 対比 語 単に ハード 呼ぶ ハードウェア hardware 本来 金物 類 金属 製品 意味 英語 1 歴史 木製 対比 語 転ずる コンピューター 分野 ソフトウェア 対比 語 する どちら 先 とも はっきり する 個々 物理 機械 部品 CPU ハード ディスク ケース それ ら 集合 体 ハードウェア 呼ぶ コンピュータ 　 ソフト ない 　 ただ 箱 いう 川柳 箱 部分 ハードウェア 相当 転ずる 空港 施設 企業 都市 軍事 国家 分野 物理 設備 施設 車両 ハードウェア 直接 目 見える 規則 運用 教育 人間 面 ソフトウェア 呼ぶ こと ある なお 近年 コンテンツ 語 使う もの つく 以前 ソフトウェア 呼ぶ コンピュータ おく ハードウェア 電子 回路 いう コンピュータ 物理 部分 指す また 上 実行 コンピュータ プログラム 指す 論理 部分 言える ソフトウェア 対比 ある 日本 コンピュータ 関係 技術 者 使う 俗語 これ 指す 金物 いう もの ある 俗語 ある 前述 よう 英語 原義 反映 英語 圏 技術 者 用語 似る ニュアンス bare METAL 2 iron age 3 いう フレーズ ある
# プリント基板 プリント 基板 プリント きばる 短縮 形 pwb PCB 基板 一種 以下 ふた つ まとめる 指す 総称 オーストリア 人 発明 家 パウル アイスラー Paul eisler 考案 配線 手法 日本 おく 1936 年 昭和 11 年 成立 日本 初 プリント 配線 板 特許 起源 なる 1 2 集積 回路 抵抗 器 コンデンサー 等 多数 電子 部品 表面 固定 部品 間 配線 接続 こと 電子 回路 構成 板 状 また フィルム 状 部品 狭義 部品 含む 基板 指す 広義 基板 電子 部品 実装 状態 含む 主に 基材 対する 絶縁 性 ある 樹脂 含浸 基板 上 銅箔 導電 体 回路 パターン 配線 構成 プリンテッドエレクトロニクス 一種 スクリーン 印刷 フレキソ 印刷 グラビア 印刷 インク ジェット オフセット 印刷 様々 印刷 技術 駆使 用語 JIS 規格 おく JIS c 5603 以下 よう 定義 また 参照 元 IEC 制定 IEC 60194 同様 これ よる プリント 配線 板 もしくは プリント 板 電子 部品 はんだ 付け 配線 状態 もの ベアボード プリント 回路 板 もしくは プリント 回路 実装 品 電子 部品 はんだ 付け 電子 回路 する 動作 もの 定義 こと なる 実際 プリント 配線 板 こと プリント 基板 また 単に 基板 呼ぶ 生板 生 基板 なま きばる 呼称 ある これ 俗称 別名 プリント 回路 板 こと ユニット ボード モジュール パッケージ アッシー 別名 あてる こと 多い また JIS 用語 示す とおり 日本 語 おく 漢字 表記 基板 基盤 誤り 同様 英文 頭 文字 とる pwb 基板 単体 PCB 基板 部品 実装 物 指す こと なる 明確 使い分け する 場合 有る 一方 混同 使用 もしくは 部品 実装 有無 関わる 一方 使用 例 有る PCB 有害 物質 ポリ 塩化 ビフェニル 略語 PCB 混同 受ける こと 有る 3 また プリント 基板 関する 標準 規格 IPC Association connecting electronics industries jpca 日本 電子 回路 工業 会 kpca 韓国 電子 回路 産業 協会 tpca 台湾 cpca 中国 ある 世界 全体 プリント 基板 メーカー 2014 年 時点 約 2500 社 うち 中国 メーカー 1200 社 以上 次いで 韓国 台湾 日本 メーカー ほとんど シェア 占める 中国 世界 最大 プリント 基板 生産 地 なる 2012 年 プリント 基板 世界 市場 約 4兆 円 プリント 基板 材料 約 2兆 円 および 実装 関連 製 品 装置 約 2兆 円 規模 なる 4 プリント 基板 次 よう 3 つ 分類 フレキシブル 基板 薄い 柔軟 性 ある こと 機器 組む 際 自由 度 高い 小型 電子 機器 使う コネクタ 間 配線 ため フィルム 状 配線 材 機能 ケーブル フレキシブル 基板 呼ぶ こと ある 単に プリント 基板 呼ぶ 場合 リジッド 基板 指す こと ほとんど 次 リジッド 基板 より 詳細 分類 記す 正式 フレキシブル 配線 基板 flexible pwb 呼ぶ 薄い ポリイミド ポリエステル フィルム 出来る 基材 上 薄い 銅箔 配線 パターン 持つ 表面 保護 ため 絶縁 フィルム 被覆 配線 基板 業界 俗 別名 セミ 羽 自由 折る 曲げる こと 出来る 薄い 柔軟 外形 中抜き 自由 形 比較 容易 加工 ため 小型 外形 複雑 わり 多く 部品 詰める 必要 ある 製品 使用 多い また 複数 リジット 基板 間 接続 ハーネス ケーブル 代わり 使う こと ある 最後 2 点 よる まま ヒート シンク 使える 発熱 部品 実装 困難 なる 場合 ある 基板 柔軟 性 利用 筐体 放熱 器 代わり する 方法 ある これ ら 問題 点 解決 硬い 基板 柔らかい 基板 両方 長所 得る リジッド フレキシブル 混成 基板 ある 5 プリント 基板 設計 他 回路 相互 接続 部品 配置 機能 電気 ノイズ 完成 品 大まか 寸法 考慮 誤差 公差 解析 行う これ ら 要件 従う 回路 図 ネット リスト netlist 作成 次 使用 材料 部品 記す bom 部品 表 作る 材料 選択 動作 環境 耐用 年数 考慮 インピーダンス 整合 考慮 実装 電子 部品 選択 スペック 入手 性 予算 サイズ 考慮 ほか ドリル ファイル 製造 ため データ 盛る 基板 設計 者 製造 業 者 間 やりとり データ ガーバー データ 呼ぶ ガーバー ファイル 出力 quadcept eagle CAD eda ツール 用いる 市販 CAD ツール 設計 データ デザイン ルール 設計 規則 違反 検証 ため デザイン ルール チェック DRC design rule checking 機能 有する en comparison of eda Software 参照 製造 性 考慮 設計 dfm Design for manufacturability 動作 温度 範囲 おく 熱 解析 おく cae 有限 要素 解析 fem シミュレーション 活用 ダッソー システムズ 社 abaqus プロセス 設計 試作 検証 繰る 返す 最適 化 図る フロー はんだ 端子 狭 ピッチ 化 IC 実装 困難 欠点 ある リード 部品 同時 はんだ 付け ため リフロー フロー 工程 適宜 組む 合わせる 用いる 工程 適する 基板 設計 行なう 1990 年 代 以降 高 密度 実装 技術 主流 表面 実装 用 部品 surface mounting device SMD 呼ぶ 代表 SMD する チップ 部品 IC LSI sop qfp bga パッケージ ある 全面 銅箔 張る 基板 不要 部分 取る 除く 回路 残す 方法 絶縁 体 基板 回路 パターン 後 付ける 加える 方法 銅 パターン 形成 ない 部分 レジスト めっき レジスト 形成 レジスト ない 部分 電解 また 無 電解 めっき 施す こと パターン 形成 アディティブ 法 フルアディティブ 法 パートリーアディティブ 法 セミアディティブ 法 ある 日立 化成 日立 化成 エレクトロニクス イビデン フルアディティブ 法 採用 なお これ ら 企業 サブトラクティブ 法 よる 製造 行く プリント 基板 生産 性 考慮 1 m 四方 1.2 m 四方 程度 1 枚 大きい 基板 複数 基板 まとめる 面 付け 製造 こと 多い あらかじめ 基板 各 基板 間 NC ドリル V カット 切れ目 入れる 完成 後 折る それぞれ 分離 5 デジタル 回路 低速 動作 プリント 基板 特性 あまり 配慮 必要 いる 高速 動作 必要 高速 デジタル 回路 プリント 配線 パターン 理想 銅線 ない こと 理解 銅 配線 パターン 作る インピーダンス 配慮 必要 なる シグナル インテグリティ 　 具体 信号 立ち上がり 立つ 下り 1 ns 以下 配線 長 5 CM 以上 場合 交流 影響 出る 可能 性 考慮 必要 ある 分布 定数 回路 回路 欠陥 ほか はん レジスト 欠陥 よる 様々 導通 絶縁 不 具合 もたらす 分野 詳細 電子 回路 工学 集積 回路 工学 failure modes of electronics 参照
# 周辺機器 周辺 機器 しゅうへん きく また ペリフェラル 英 peripheral コンピュータ ゲーム 機 電子 製品 本体 対する ケーブル 等 接続 使用 機器 ハードウェア 等 こと 何 周辺 機器 する 製品 よる 時代 メーカー モデル よる 変わる なお 本体 周辺 機器 間 データ 制御 信号 状態 ステータス 相互 やり取り 転送 言う パーソナル コンピュータ 周辺 機器 外付け キーボード マウス プリンター 外付け 補助 記憶 装置 ドライブ ある 周辺 機器 いう 呼称 外部 接続 製品 指す こと 多い コンピュータ 内部 装着 もの PC パーツ 呼ぶ しかし 何 周辺 機器 何 コンピュータ 本体 一部 常 明確 決める 物 ない 税法 特に 法人 税法 及び 固定 資産 税 定める 地方 税 法 おく 周辺 機器 コンピュータ 本体 一体 する 取る 扱う こと 原則 なる 場合 対象 物件 金額 大きい なる ため 固定 資産 する 損金 使用 期間 わたる 減価 償却 よる こと なる 本体 各 周辺 機器 各々 独立 もの 認定 個々 金額 低い なる ため 課税 年度 おく 損金 処理 可能 性 ある 企業 側 する 税務 上 後者 有利 周辺 機器 個別 単独 目的 購入 もの 主張 税務 当局 側 本体 ない 機能 こと 理由 一体 性 認める 固定 資産 する こと 一般 ゲーム 機 特殊 接続 インターフェース 採用 こと 多い ため 周辺 機器 ほとんど 特定 ゲーム 機 本体 専用 設計 ゲーム コントローラ 特定 ゲーム ソフト 特化 設計 場合 ある 携帯 電話 スマートフォン デジタル オーディオ プレーヤー 携帯 ゲーム 機 等 利便 性 向上 周辺 機器 多数 販売 市場 規模 形成 機械 ない 製品 機能 ファッション 性 重視 もの 多い まとめる アクセサリー 呼ぶ 場合 多い 汎用 タイプ 品 除く 特定 製品 専用 設計 とりわけ アップル iPod iPhone シリーズ 対象 する もの 需要 高い
# 集積回路 集積 回路 しゅう せき かいろ 英 integrated circuit IC 半 導体 表面 微細 かつ 複雑 電子 回路 形成 上 封入 電子 部品 製造 おく フォトリソグラフィ いう 光学 技術 利用 こと よる 微細 素子 配線 ひと つ 組む 立てる こと ない 大量 生産 こと できる ため 現在 コンピュータ デジタル 機器 支える 主要 技術 一 つ なる 20 世紀 中頃 トランジスタ 発明 次ぐ 考案 以降 製造 技術 進歩 よる 急速 微細 化 性能 向上 集積 回路 シリコン 単 結晶 代表 半 導体 チップ 注釈 1 表面 不純 物 拡散 こと よる トランジスタ する 動作 構造 形成 アルミ 蒸着 エッチング よる 配線 形成 こと よる 複雑 機能 果たす 電子 回路 作る 電子 部品 注釈 2 多く 場合 複数 端子 持つ 比較 小型 注釈 3 パッケージ 封入 内部 端子 チップ 配線 モールド 状態 部品 製品 なる 実際 集積 回路 考案 レーダー 科学 者 ジェフリー ダマー 英語 版 1909 年 生まれ 彼 イギリス 国防 省 王立 レーダー 施設 働く 1952 年 5 月 7 日 ワシントン d c で アイデア 公表 しかし ダマー 1956 年 回路 作る こと 失敗 各 企業 集積 回路 実現 目指す RCA マイクロ モジュール ウェスティングハウス エレクトリック モレキュラーエレクトロニクス テキサス インスツルメンツ ソリッドステート サーキット 開発 1 初期 集積 回路 概念 モノリシック IC いう 後 ハイブリッド IC 近い もの 概念 したがう 基板 真空 蒸着 抵抗 素子 コンデンサ 形成 トランジスタ 組む 合わせる 薄膜 集積 回路 現在 プリンテッドエレクトロニクス 相当 印刷 技術 よる 抵抗 配線 コンデンサ 1 枚 セラミック 基板 上 集積 厚い 膜 集積 回路 開発 1 また 1958 年 ウェスティングハウス molectronics いう 名称 集積 回路 概念 発表 2 1960 年 2 月 semiconductor Product 誌 掲載 記事 触発 電気 試験 所 同年 12 月 見方 次第 マルチ チップ 構造 ハイブリッド IC いえる ゲルマニウム ペレット 3 個 約 1 CM 角 樹脂 容器 平行 配列 集積 回路 試作 成功 3 4 1961 年 2 月 ウェスティングハウス 技術 提携 三菱 電機 11 種類 モレクトロン 発表 1 日本 最初 モノリシック 集積 回路 東京 大学 日本 電気 共同 開発 する 5 著名 集積 回路 特許 アメリカ 合衆 国 別々 2 つ 企業 2人 研究 者 よる 異なる 発明 それぞれ 発行 テキサス インスツルメンツ ジャック キルビー 特許 miniaturized Electronic circuits 1959 年 2 月 出願 1964 年 6 月 特許 なる アメリカ 合衆 国 特許 第 3,138,743 号 フェア チャイルド セミ コンダクター ロバート ノイス 特許 semiconductor device － AND － Lead Structure 1959 年 7 月 出願 1961 年 4 月 特許 なる アメリカ 合衆 国 特許 第 2,981,877 号 しかし キルビー 特許 紛争 呼ぶ ちなみ キルビー 特許 対する ノイス 特許 プレーナー 特許 呼ぶ こと ある 多く 議論 発生 こと なる 技術 内容 ほぼ 無 関係 業界 権益 争い する 特許 優先 権 委員 会 おく どちら 特許 集積 回路 特許 する 有効 法的 認定 争い 勃発 技術 判断 目的 ない あくまで 法的 どちら 有効 認める こと 目的 キルビー 特許 出願 10 年 10 か月 経る 決着 ノイス 勝利 確定 しかし 法的 勝利 実際 ほとんど 意味 ない ライセンス ビジネス 1966 年 テキサス インスツルメンツ フェア チャイルド セミ コンダクター 含む 十 数 社 エレクトロニクス 企業 集積 回路 ライセンス 供与 つく 合意 達する 技術 法律 ビジネス いう もの つく 教訓 事例 なる また さらに 日本 20 年 紆余 曲折 経る 1989 年 特許 なる こと 莫大 額 請求 等 伴う 紛争 なる サブマリン 特許 制度 タチ 悪い 際立つ いう 役割 担う 結果 なる キルビー ノイス 後 とも 国民 栄誉 賞 受ける 同時 全米 発明 家 栄誉 殿堂 入り する SSI MSI LSI いう 集積 素子 数 よる IC 分類 定義 6 もの MSI IC よう 言う もの 今日 ほぼ 使う 比較 小 規模 もの 単に IC 比較 大 規模 もの 単に LSI する 現在 IC LSI 同義 語 する 使う こと 多い 初期 集積 回路 ごく わずか トランジスタ 集積 もの これ SSI Small Scale Integration する 後 MSI Middle Scale Integration LSI large Scale Integration いう 語 同時 作る 思う おそらく レトロニム 航空 宇宙 分野 プロジェクト 珍重 それ よる 発展 ミニットマンミサイル アポロ 計画 慣性 航法 用 計算 機 する 軽量 デジタル コンピュータ 必要 する アポロ 誘導 コンピュータ 集積 回路 技術 進化 寄与 ミニットマンミサイル 量産 化 技術 向上 寄与 これ ら 計画 1960 年 1963 年 生産 IC ほぼ 全て 買う 取る これ よる 製造 技術 向上 ため 製品 価格 40 分 1 なる それ 以外 需要 生まれる こと なる 民生 品 する 大量 IC 需要 発生 電卓 コンピュータ メインフレーム IC 採用 System 360 単体 トランジスタ モジュール 集積 ハイブリッド 集積 回路 IBM slt 呼ぶ とどまる モノリシック 集積 回路 採用 System 370 1960 年 代 最初 製品 あらわれる 汎用 ロジック IC やがて 多 品種 大量 作る コンピュータ よう それ ら 大量 使用 製品 あるいは 家電 大量 生産 機器 使う 1970 年 代 マイクロプロセッサ 現れる 集積 度 高い MSI LSI 普通 生産 うち 分類 曖昧 マイクロプロセッサ 比較 複雑 もの LSI 汎用 ロジック IC 比較 単純 もの IC 大雑把 呼ぶ 分ける 程度 分類 なる もと 分類 LSI 全て 入る わけ 1980 年 代 開発 大 規模 集積 回路 vlsi VERY large Scale Integration する これ よる これ 多数 IC 作る コンピュータ 匹敵 規模 マイクロプロセッサ 製作 1986 年 最初 1 mbitram 登場 これ 100万 トランジスタ 集積 もの 1993 年 最初 Pentium 約 310万 個 トランジスタ 集積 また 設計 ルール 化 それ 以前 比較 設計 容易 また カーバー ミード リン コンウェイ 超 LSI システム 入門 7 よる vlsi マッチ 設計 手法 提案 これ Mead conway Revolution en Mead conway REVOLUTION 呼ぶ こと ある 影響 もたらす たとえば 1950 年 代 大学 最 先端 コンピュータ 実際 建造 いう こと さかん わけ 1970 年 頃 以降 コスト 点 現実 なくなる それ CAD 等 助け よる パターン 設計 チップ 化 いう 手法 大学 最 先端 実際 研究 また 可能 いう 変化 齎す 一 例 たとえば 初期 RISC する IBM 801 バークレイ RISC sparc 影響 大きい スタンフォード 系 mips まず 挙がる 後者 2 つ 影響 ある vlsi 続く 新た ulsi Ultra － large Scale Integration いう 語 作る 集積 素子 数 100万 以上 とも 1000万 以上 ともす 集積 度 集積 回路 今日 普通 vlsi する wsi wafer Scale Integration 複数 コンピュータ システム 等 全体 ウェハー 上 作る 個別 ダイ 切る 離す ウェハー 大きい まま 使用 いう 構想 注釈 4 現状 1 品もの コスト 非常 高額 良い いう 特殊 用途 特殊 要求 基づく 生産 装置 採用 たとえば 人工 衛星 天体 観測 望遠 鏡 光学 受像 素子 つなぐ 合わせる 作る 歪み 隙間 生ずる 1 枚 ウェハー 全面 使用 物 作る System － on a chip SOC 従来 別々 ダイ 構成 もの 統合 こと 独立 動作 システム 全体 ひと つ 集積 回路 上 実現 もの 例えば マイクロプロセッサ メモリ 周辺 機器 インターフェース 1 つ チップ 集積 もの 集積 回路 技術 進歩 一 例 以前 撮像 管 呼ぶ 真空 管 映像 撮影 撮像 素子 電荷 結合 素子 CCD 技術 開発 進む 固体 撮像 素子 する CCD イメージ センサ 作る 家庭 用 ビデオ カメラ 大幅 小型 化 まず 貢献 CMOS イメージ センサ 作 ...
# Systems on Chip (SoCs) System － on a chip SOC SOC 集積 回路 1 個 チップ 上 プロセッサコア はじめ 一般 マイクロ コントローラ 持つ 機能 他 応用 目的 機能 集積 連携 システム する 機能 設計 集積 回路 製 品 大 容量 DRAM アナログ 回路 混載 さまざま 難しい リスク ある デメリット ある 後述 ため DRAM 別 チップ 集積 同一 パッケージ 収める sip 形態 とる 製品 ある 1970 年 代 中頃 マイクロプロセッサ 集積 度 まだ 高い ない CPU する 機能 近年 コア 呼ぶ 持つ メモリ パラレル I o uart ペリフェラル 別 チップ 別 パッケージ もの 利用 プリント 基板 それ ら 実装 あるいは バック プレーン 接続 個別 基板 よる システム 構成 1980 年 代 頃 集積 度 向上 ある マイクロプロセッサ 周辺 機能 1 チップ まとめる ワンチップマイコン マイクロ コントローラ 呼ぶ 製品 現れる また 顧客 個々 要求 応ずる 特定 専用 回路 マイクロ コントローラ 付加 こと 汎用 性 下がる 用途 対する 最適 化 製品 作る 半 導体 メーカー する チップ 単価 高い できる 高 付加 価値 商品 する セット メーカー チップ 使用 装置 メーカ 装置 全体 コスト ダウン つながる する 出荷 数 多い 装置 採用 製品 ASIC カスタム チップ 呼ぶ CPU 機能 外付け ペリフェラル 専用 回路 1 チップ 化 もの 含む 集積 化 流れ 続く 以下 理由 さらに 流れ 加速 これ ら 要件 満たす 設計 手法 および 設計 手法 よる 製造 半 導体 製品 SOC 呼ぶ 1 チップ 集積 SOC ASIC 全般 複数 単 機能 LSI 基板 実装 場合 比較 以下 示す SOC いう 言葉 使う 時期 定か ない 1994 年 1 いう 情報 ある 当時 ASIC マイコン マイクロ コントローラ 略称 いう 呼ぶ 方 陳腐 化 高 付加 価値 印象 与える 新た 呼ぶ 方 する 注目 IP コア 用いる こと 前提 する 設計 方法 主流 なる 頃 SOC いう 言葉 使う 場面 増える 当初 System on a chip SOC 注釈 2 他 System on silicon SOS 呼ぶ 次第 SOC 落ちる 着く また SOC 近い 意味 合い 言葉 する システム LSI いう 言葉 存在 システム 全体 回路 全体 1 チップ 載せる いう 意味 SOC 上記 デジタル 回路 以外 大 容量 メモリ アナログ 回路 同時 搭載 もの 指す 場合 ある 従来 マイクロ コントローラー 比較 小 規模 数 キロバイト 数百 キロバイト 程度 SRAM ROM マスク ROM フラッシュ メモリ 含む 搭載 数 メガバイト 超える 容量 実現 難しい 外付け メモリ 用いる 必要 ある メモリ 大 容量 化 SRAM DRAM 適する ため 論理 回路 DRAM 混載 過去 試みる 半 導体 製造 プロセス 異なる ため 実現 難しい 1998 年 前後 DRAM 混載 プロセス 実現 2 が 後述 問題 点 ある すべて 用途 おく 最適 限る また アナログ 回路 論理 回路 異なる 半 導体 製造 プロセス 必要 こと 多い 大 規模 ロジック LSI 汎用 アナログ 回路 混載 こと 難しい SOC 呼ぶ 前 マイクロ コントローラー 製 品 a d コンバーター d a コンバーター pll 一部 回路 実現 電源 用 大 出力 トランジスタ 高 精度 オペアンプ 高 周波 扱う RF 回路 混載 難しい デジタル 回路 アナログ 回路 混載 こと 指す mixedsignal いう 言葉 存在 2007 年 現在 SOC 言う 場合 必ず DRAM アナログ 回路 含む 限る SOC 長所 短所 ある 以下 よう 点 短所 する DRAM アナログ 回路 混載 場合 以下 点 問題 なる これ ら 技術 課題 リスク ある 半 導体 製造 プロセス 技術 改善 もとより メソドロジー 設計 開発 手法 改善 これ ら 考慮 上 柔軟 仕様 DFT dfm 技術 発展 よる 克服 これ ら つく まったく ノウハウ 持つ 場合 依然 する リスク 大きい また これ ら 経緯 大 規模 集積 回路 製造 方法 対する 別 手法 求める 上記 問題 解決 手段 する sip 注目 sip 200 x 年代 前半 実用 化 3 SOC 弱点 補う 形 なる 2007 年 現在 SOC sip よる 完全 否定 わけ ない 開発 製造 順調 進む 量産 効果 よる コスト 低減 効果 大きい 状況 よる 使う 分ける SOC sip 組む 合わせる 用いる
# エネルギー消費 (グリーン・コンピューティング) グリーン It グリーン アイティー 英 green computing 地球 環境 配慮 思想 情報 通信 技術 適用 思想 こと 思想 辞書 はっきり する 定義 ない 思想 発祥 アメリカ 環境 保護 庁 EPA IT 機器 導入 運用 廃棄 至る 含める 環境 負荷 減らす ため 包括 考える 方 一般 定義 する 特に 環境 取り組み プラス イメージ なる 21 世紀 初頭 以降 企業 活動 おく 企業 イメージ 向上 場合 よる コスト 削減 つながる ため 投資 余裕 ある 先進 国 大手 企業 中心 なる 広い 導入 グリーン It 思想 取る かつ 同じく アメリカ 環境 保護 庁 EPA 設ける 基準 満たす 機器 エナジー スター ロゴ マーク 表記 こと 許す 情報 機器 限る 冷蔵 庫 家電 適用 基準 さまざま 要素 含む デスクトップ パソコン スリープ 機能 付加 義務 うえ とき システム 全体 消費 電力 30 W 以下 抑える 1 挙げる こと 出来る 機器 製造 運用 あたる 部品 梱包 出来る リサイクル 可能 もの 使用 製造 工程 廃棄 時 消費 エネルギー 有害 物質 ほとんど 出る 更に 運用 時 使用 電力 量 必要 最低 限 抑える いう 考え 基礎 なる 具体 部品 プラスチック 部分 リサイクル 可能 もの する こと 土 返す こと 出来る グリーンプラ 利用 機器 内部 構造 熱 循環 良い もの する 廃熱 処理 効率 よい する こと 廃熱 電力 抑える こと サーバ 機器 配置 工夫 熱 こもる こと 空調 電力 抑える いう こと あげる
# EDA eda
# ハードウェアアクセラレーション コンピューティング おく ハードウェア アクセラレーション 英 hardware acceleration なん ら 機能 通常 汎用 プロセッサ CPU 上 動作 ソフトウェア コンピュータ プログラム よる 実装 処理 レイテンシ スループット 遅い 消費 電力 大きい いう 問題 ある 場合 ハードウェア 実装 よる 支援 実行 速度 加速 アクセラレーション システム 全体 性能 効率 向上 技術 ハードウェア アクセラレーション パフォーマンス 改善 ため 使用 様々 技術 うち ひと つ 特に 並列 処理 点 専用 設計 ハードウェア 効果 発揮 通常 CPU よる ソフトウェア 実行 CPU 備える プリミティブ 命令 並び 処理 実現 命令 逐次 ひと つ 実行 一方 ハードウェア よる アクセラレーション 特定 処理 ため 専用 ハードウェア 設計 ハードウェア 内 回路 並列 性 生かす 演算 並列 行う こと 逐次 命令 実行 場合 はるか 高速 演算 実行 しかし 専用 設計 ハードウェア する 処理 実現 場合 CPU 備える プリミティブ 命令 組み合わせ よる ソフトウェア する 処理 実現 場合 比べる 柔軟 性 減少 また ハードウェア 設計 及び 製造 ソフトウェア 比べる 桁違い コスト 必要 実行 性能 柔軟 性 コスト トレード オフ ハードウェア よる アクセラレーション ソフトウェア 中 特定 パターン 演算 集中 処理 パフォーマンス 上 重要 部分 つく 利用 ハードウェア アクセラレーション 機能 ユニット MPEG 2 動作 予測 よう 機能 ブロック さまざま 粒度 わたる 一般 粒度 大きい できる 実行 性能 向上 一方 用途 固定 化 柔軟 性 低下 傾向 ある 処理 高速 化 支援 ハードウェア 総称 アクセラレータ 呼ぶ 代表 もの BIT block Transfer 機能 3 次元 コンピュータ グラフィックス 描画 動画 再生 支援 機能 含む リアル タイム グラフィックス 処理 特化 GPU かつて グラフィック アクセラレータ 呼ぶ 数値 演算 コプロセッサ 呼ぶ fpu 音声 デジタル 信号 処理 特化 dsp ベクトル プロセッサ fpga 等 拡張 ボード 実装 もの ある 専用 計算 機 コスト 点 一般 処理 つく 通常 コンピュータ 流用 ため アクセラレータ 形態 とる こと ある また 以前 パーソナル コンピュータ おく アップグレード ため CPU 換装 一般 ない こと ある オーバー ドライブ プロセッサ 等 よる CPU 高速 化 ため プロセッサ CPU アクセラレータ 等 称する こと ある 1 また 近年 いつ グラフィックス GPU 機能 分離 一方 SSE simd 型 拡張 命令 する CPU 自身 アクセラレータ 機能 持つ 命令 積極 備える なる アクセラレータ 搭載 コンピュータ ハードウェア アクセラレーション 利用 ソフトウェア 実行 こと できる 代替 する ソフトウェア よる 実装 フォール バック ソリューション する 用意 こと ある 開発 工数 テスト 工数 増加 また アクセラレータ 命令 仕様 演算 精度 違い 演算 結果 CPU よる ソフトウェア 処理 異なる 場合 問題 なる また アクセラレータ 操作 処理 記述 際 本来 アプリケーション ソフトウェア 実現 ため 本質 ない ハードウェア 関する 予備 知識 必要 なる 通例 ハードウェア 抽象 化 標準 化 directx opengl opencl いう アクセラレーション 用 API 介する こと ハードウェア 詳細 実装 隠蔽 こと 多い ハードウェア および デバイス ドライバー 層 これ ら API サポート 必要 ある なお 通例 CPU 外部 ハードウェア メモリ 空間 異なる こと 外部 ハードウェア 処理 委譲 際 データ メイン メモリ 外部 メモリ 転送 必要 ある 逆 外部 ハードウェア 処理 結果 取得 際 データ 外部 メモリ メイン メモリ 転送 リード バック 必要 ある ため プログラム 煩雑 なる AMD apu おく hsa よう CPU 補助 プロセッサ メモリ 空間 統合 こと ソフトウェア 開発 負担 低減 解決 策 提案
# コンピュータ・アーキテクチャ コンピュータ アーキテクチャ 英 Computer architecture コンピュータ 特に ハードウェア おく 基本 設計 設計 思想 意味 アーキテクチャ 建築 単に 建築 物 以外 設計 様式 いう 意味 ある それ 転ずる コンピュータ 分野 おく 使う 設計 思想 意訳 こと ある 技術 者 研究 者 用語 する 企業 ごと 用語 違い よる 方式 いう 語 使う こと ある 1964 年 System 360 最初 使う 用語 際 意味 する 入出力 インタフェース 含む コンピュータ システム ハードウェア 全体 周辺 機器 自体 含む ユーザー プログラマ OS 設計 プログラマ 含む 見る インタフェース 定義 具体 使用 レジスタ 構成 命令 セット 入出力 チャネル コントロール ワード 実装 含む アーキテクチャ 同一 コンピュータ 間 上位 互換 アーキテクチャ 持つ コンピュータ 移行 上位 互換 周辺 機器 移行 ソフトウェア 互換 性 原則 する 保証 また ハードウェア 内部 設計 実装 定義 アーキテクチャ 守る 限り 技術 進歩 応ずる 自由 更新 結果 コンピュータ ファミリー シリーズ 形成 可能 なる 現在 言う レイヤー 定義 仮想 化 一種 ある また システム アーキテクチャ エンタープライズ アーキテクチャ ソフトウェア アーキテクチャ Arm アーキテクチャ 用語 増える コンピュータ アーキテクチャ 少ない 次 3 つ 分類 1 前者 2 つ プロセッサ アーキテクチャ システム 設計 コンピュータ おく プロセッサ 以外 つく 含む もともと System 360 厳密 定義 アーキテクチャ だいたい isa 含む マイクロ アーキテクチャ 含む システム 設計 いくら 相当 もの 含む これ 当時 大型 コンピュータ 現在 マイクロプロセッサ ベース コンピュータ 実装 技術 変化 ビジネス モデル 変化 ため よる コンピュータ 周辺 機器 含む 全体 レイヤ 分ける かた 構成 法 変化 よる プロセッサ CPU 設計 CPU 設計 おく アーキテクチャ 観点 工程 説明 isa マイクロ アーキテクチャ 決定 実際 ハードウェア 設計 設計 工程 一般 実装 呼ぶ 実装 アーキテクチャ 定義 通常 含む ハードウェア 設計 含む 実装 さらに 以下 3 段階 分ける プロセッサ ない コンピュータ システム 全体 設計 アーキテクチャ つく 述べる コンピュータ 設計 おく 制約 条件 目標 考慮 部分 最適 化 決定 コンピュータ アーキテクチャ 一般 標準 規格 コスト メモリ 容量 レイテンシ スループット トレード オフ 決まる 場合 よる 機能 大きい 重い 信頼 性 拡張 性 電力 消費 量 いう 要素 考慮 典型 手法 する ボトル ネック 最も 性能 悪化 注意 深い 見る 極める 理想 コンピュータ 各部 性能 向上 それ かかる コスト 比例 考える コスト かかる 部品 全体 性能 決定 考える 一般 システム 要件 市場 状況 よる 設計 前 製造 コスト 決定 コンピュータ 性能 クロック 周波 数 MHz GHz よく 表す これ CPU クロック 一 秒間 何 サイクル 示す もの しかし クロック 周波 数 高い マシン 必ず 性能 高い 言える 近年 クロック 高速 化 頭打ち なる 製造 業 者 別 指標 性能 示す プロセッサ 搭載 キャッシュ 容量 性能 示す いう 手法 ある クロック 周波 数 自動車 最高 速度 する キャッシュ 容量 車線 数 対応 自動車 どんな 速い 渋滞 なる 速い 走る こと できる CPU 高速 動作 キャッシュ 多い プロセッサ 実際 高速 動作 最近 CPU スーパースケーラ 方式 1 クロック サイクル 複数 命令 実行 これ よる プログラム 実行 性能 大幅 改善 他 性能 影響 要素 する 実行 ユニット する もの 何 個 持つ バス 速度 利用 可能 メモリ 容量 プログラム する 実行 する 命令 種類 順序 ある 速度 考える 際 レイテンシ スループット 重要 レイテンシ ある 処理 開始 完了 時間 スループット 単位 時間 当たり 処理 仕事 量 割る レイテンシ ハードウェア イベント 例えば ディスク ドライブ 読み書き 完了 通知 割る 対する システム 応答 かかる 時間 性能 設計 上 様々 選択 よる 影響 例えば キャッシュ メモリ 追加 レイテンシ 悪化 スループット 向上 制御 用 コンピュータ 割る レイテンシ 短縮 求める コンピュータ リアル タイム 環境 運用 所定 時間 以内 処理 行う 問題 発生 例えば コンピュータ 制御 アンチ ロック ブレーキ ブレーキ 踏む 即座 制動 かける コンピュータ 性能 他 測定 法 よる 測定 用途 よる 様々 測定 法 ある システム 用途 よる ボトル ネック なる 部分 異なる CPU バウンド 例えば 数値 計算 I o バウンド web サーバ メモリ バウンド ビデオ 編集 分ける サーバ 携帯 機器 電力 消費 量 重要 観点 ベンチ マーク 一連 評価 プログラム 実行 それ かかる 時間 計る こと 上述 あらゆる 観点 考慮 性能 測定 もの しかし ベンチ マーク 役 立つ 場合 ある ベンチ マーク 異なる 示す 性能 異なる 例えば ある アプリケーション 高速 実行 別 アプリケーション 遅い しれる さらに システム 設計 段階 特定 ベンチ マーク 結果 向上 ため ハードウェア ソフトウェア ベンチ マーク 高速 化 機能 加える こと ある 機能 ベンチ マーク 類似 アプリケーション 役 立つ こと 多い 電力 消費 最近 コンピュータ 設計 重要 性 増す 電力 消費 抑える 性能 低下 コスト 増大 こと 多い チップ 単位 面積 当たり トランジスタ 数 増大 したがう 電力 効率 重要 観点 なる Intel Core 2 最近 プロセッサ 電力 効率 向上 重要 設計 上 観点 する また 組み込み 用 プロセッサ 電力 効率 性能 共 最 重要 観点 なる コンピュータ 関連 アーキテクチャ いう 用語 使用 1959 年 IBM 研究 所 所属 ライル r ジョンソン 3 フレデリック ブルックス 遡る ジョンソン stretch こと IBM 7030 つく 研究 報告 書く 彼 コンピュータ つく 詳細 省く 水準 記述 する もの それ 使う マシン 構成 4 ない システム アーキテクチャ 5 称する 後 stretch 設計 者 1人 ブルックス ある 本 6 コンピュータ アーキテクチャ 他 アーキテクチャ 同様 構造 利用 者 ニーズ 決定 技法 それ ら ニーズ 合う 経済 技術 可能 限り 最適 設計 行う こと 書く ブルックス System 360 開発 役割 果たす そこ アーキテクチャ いう 用語 ユーザー 知る 必要 ある 詳細 いう 定義 なる 後 コンピュータ 業 界 アーキテクチャ いう 用語 様々 使う 論文 初めて アーキテクチャ いう 用語 使う 1964 年 IBM System 360 関する もの 7 論文 アーキテクチャ プログラマ 見える システム 属性 群 すなわち 概念 構造 機能 挙動 データ フロー 制御 構成 論理 設計 物理 実装 異なる 定義 定義 おく プログラマ 見る コンピュータ 機能 挙動 鍵 なる アーキテクチャ 含む 概念 構造 機能 挙動 理解 ため 補助 もの ユース ケース 範囲 拡大 可能 プロセッサ 内部 処理 方法 メモリ アクセス 方法 マイクロ アーキテクチャ コンピュータ アーキテクチャ する もっと 後 こと
# 組み込みシステム 組み込み システム くむ システム 英 embedded System 特定 機能 実現 ため 家電 製品 機械 等 組む コンピュータ システム こと 組み込み システム 特定 機能 実現 ため 機械 装置 等 組む コンピュータ システム PC 等 汎用 システム 対比 特定 機能 実現 目的 組む 産業 用 機器 医療 用 機器 家庭 用 機器 等 制御 必要 する 多く 製品 用いる 小型 軽量 省 電力 安定 動作 誤 動作 防止 要求 専用 設計 もの 多い 組み込み 用途 以外 既存 製品 ダウンサイジング もしくは 既存 回路 ないし コンポーネント 流用 組み立て 行う 製品 化 もの 近年 増える これ コンピューター 各種 電子 回路 小型 化 信頼 性 向上 よる 特定 組み込み 用途 要求 満たす ため 例 する 動作 可能 状態 小型 PC 基盤 PC ほぼ 働き する PCI 拡張 ボード 型 コンピューター シングル ボード コンピュータ 又 ワンボード 汎用 マイコン 回路 専用 設計 ソフトウエア 導入 制御 必要 する 機械 組む 制御 回路 する 使う 場合 組み込み システム 登場 以前 装置 制御 制御 理論 基づく 伝達 関数 用いる pid 制御 よる 主に 電気 電子 回路 もたらす 現象 電気 量 機械 機構 組み合わせ 等 よる 直接 実現 これ ら 制御 機能 主に 専用 設計 コンピューター システム ソフトウェア よる 行う こと 装置 正確 状態 監視 判断 複雑 命令 組み合わせ 等 実現 とも 機能 追加 変更 容易 行う こと できる 組み込み システム 中 例えば 携帯 電話 デジタル 家電 自動車 多 機能 システム 複数 ハードウェア 複数 ソフトウェア 組む 合わせる もの なる 多く 開発 人員 開発 期間 要する 大 規模 組み込み システム 呼ぶ こと ある 近年 おく マイクロプロセッサ 価格 低下 能力 向上 よる 組む システム 導入 広がる 機能 追加 変更 ソフトウェア 書く 換える こと 可能 なる ため 電気 電子 回路 変更 最小 限 押さえる コスト おさえる こと 広 範囲 製品 搭載 コンピュータ 用語 辞典 組み込み システム 特定 機能 実現 ため 機械 機器 組む コンピュータ システム いう 説明 する 1 特定 機能 実現 ため 必要 十 分 条件 満たす 選択 交換 不 可能 ハードウェア プログラム ソフトウェア 構成 コンピュータ システム 2 定義 こと ある ハードウェア 構成 汎用 もの 独自 もの 両方 組む 合わせる もの ある ソフトウェア 同様 汎用 もの 独自 もの 両方 組む 合わせる もの ある 開発 言語 する c 言語 用いる こと 多い メモリ 容量 実行 速度 等 制約 厳しい 用途 アセンブリ 言語 用いる メモリ 容量 等 資源 十分 確保 システム OS 搭載 もの 多い ハードウェア ソフトウェア 別々 設計 こと ある ハードウェア ソフトウェア 機能 お 互い 考慮 設計 協調 設計 コデザイン Co － Design 言う 設計 手法 ある 組み込み システム 発達 以前 装置 制御 アナログ 回路 プログラム 制御 よる デジタル 回路 からくり 機械 機構 いう ハードウェア よる 構成 新た 機能 追加 変更 場合 電子 回路 機構 もの 変更 必要 ある コスト 時間 かかる いう 問題 ある 1980 年 代 以降 マイクロプロセッサ 発達 よる コンピュータ 用いる 制御 方式 導入 こと 電子 機器 回路 変更 ソフトウェア 部分 変更 こと 機能 追加 可能 機能 追加 必要 コスト 削減 ため ほとんど 電化 製 品 組む システム 搭載 それ よる 製品 付加 価値 なる 新 機能 比較 容易 追加 高 機能 化 多 機能 化 進む 家庭 用 産業 用 問う 電子 制御 必要 する 製品 おく 一般 用いる 以下 一 例 挙げる 他 多数 組み込み システム 搭載 機器 ハードウェア 構成 パターン する 以下 よう もの ある 3 製品 目的 製品 販売 マーケット 性質 応ずる 上記 パターン 選択 4 より 具体 以下 よう 要素 考慮 ハードウェア 構成 検討 形状 特殊 サイズ 特別 小さい 製品 汎用 ハードウェア 内蔵 こと できる こと ある 場合 専用 ハード 新た 開発 量産 品 少量 生産 品 いう 独自 ハードウェア 開発 コスト 回路 設計 費 基板 設計 費 等 かかる いう 事実 ある 量産 品 場合 全体 コスト 中 それ 含める 良い 少量 生産 品 場合 そう できる いう ハードル ある いう こと 厳密 適切 選択 なる 原価 計算 踏まえる 行う 必要 でる 5 以下 もの 挙げる 独自 開発 ソフトウェア 構成 方法 汎用 ソフトウェア 独自 ソフトウェア 組む 合わせる 構成 方法 存在 6 組み込み システム 開発 職 確立 職種 する 認知 日本 おく 組み込み ソフトウェア 技術 者 数 2004 年 14.9万 人 2005 年 17.5万 人 2006 年 19.3万 人 2007 年 23.5万 人 推計 経済 産業 省 よる 推計 7
# リアルタイムシステム リアル タイム システム real-time system ジョブ 実行 命令 時 処理 設定 時間 通り 動作 こと 着目 制御 工学 おく 概念 一 つ リアル タイム 処理 呼ぶ リアル タイム 性 高める ため 順番 ジョブ 処理 スケジューリング 重要 なる 各 ジョブ タスク 重要 度 スケジューリング 基準 なる こと 多い 重要 度 時間 共 変化 動的 スケジューリング 変化 静的 スケジューリング 大別 また スケジューリング 結果 各 ジョブ 程度 実行 議論 対象 なる
# ディペンダビリティ ディペンダビリティ 英 dependability 一般 信頼 性 とどまる たとえ 一部 壊れる 残り 部分 うまい 働く いう 自立 自己 修復 動作 さす 概念 大 規模 集積 回路 コンピュータ システム 使う 言葉 従来 歩留まり 高める 欠陥 作る 検査 よる 欠陥 品 外 出す こと これ 信頼 性 する ディペンダブル 技術 欠陥 ある へこたれる 技術 いう こと なる マルチコア マルチ チップ 高 性能 並列 組込み システム 構築 冗長 性 持つ ソフトウェア 分散 共有 メモリ 機構 よる 実現 例 ある
# ネットワーク コンピュータ ネットワーク 英 Computer Network 複数 コンピュータ 接続 技術 また 接続 システム 全体 コンピュータ システム おく 通信 インフラ 自体 あるいは 通信 インフラ よる 実現 接続 通信 総体 コンピュータ ネットワーク 言える コンピュータ ネットワーク 分類 法 ひと つ 規模 よる 分類 手法 ある LAN Local Area Network WAN WIDE AREA Network MAN metropolitan area network ある 任意 2 ノード 間 最悪 遅延 規模 依存 ため 遅延 重要 システム 規模 考慮 作り込み 調整 よる Quality of Service QoS 達成 Controller AREA Network QoS ハード リアル タイム 性 要求 いう 点 特殊 自動車 船舶 いう ヴィークル 類 内部 産業 用 ロボット 群 対象 する ネットワーク Personal AREA Network PAN 個人 持つ コンピュータ 機器 間 通信 行う ネットワーク 例えば プリンター ファクシミリ 電話 PDA 走査 スキャン 接続 PAN 典型 大きい せいぜい 直径 9 メートル 以内 PAN 物理 接続 USB 1 firewire 使う 無線 PAN wpan ある irda Bluetooth 接続 使う 個人 家 オフィス ビル 狭い 範囲 カバー ネットワーク 現在 ほとんど LAN イーサネット 技術 基づく 右図 典型 図書 館 コンピュータ ネットワーク 図書 館 有線 無線 LAN ある 各種 機器 プリンター サーバ 相互 接続 共 インターネット 接続 図書 館 員 用 コンピュータ 黄緑 部分 カラー プリンター 使える 貸す 記録 アクセス 学術 ネットワーク インターネット アクセス 利用 者 用 コンピュータ インターネット 図書 目録 アクセス ワーク グループ 毎 ローカル プリンター 接続 これ ら プリンタ 他 ワーク グループ アクセス 接続 線 色 サブネット 表す 各 相互 接続 機器 異なる サブネット 接続 ため ネットワーク 層 第 3 層 動作 必要 ある 図書 館 員 向け VoIP ネットワーク 構築 LAN WAN WIDE AREA Network 比較 データ 転送 レート 高い 地理 カバー 範囲 狭い イーサネット 現在 10 ギガビット イーサネット 存在 IEEE 100 ギガビット 40 ギガビット 標準 化 検討 低速 通信 路 複数 束ねる 高速 転送 レート 通信 路 する 方式 する 逆 マルチプレクサ ある 例えば 1 ギガビット インタフェース 4 つ 束ねる 4 ギガビット する campus AREA Network can 複数 LAN 相互 接続 ネットワーク 大学 キャンパス 工場 軍 基地 いう 地理 まとまる 領域 カバー 遠隔 地 ある LAN 相互 接続 can ない MAN metropolitan area network 一種 見る こと できる 典型 MAN カバー 範囲 狭い 言える 地理 連続 地域 カバー ネットワーク 論じる 際 使う 用語 かつて ルーター レイヤ 2 スイッチ 安価 大学 キャンパス レイヤ 2 スイッチ ネットワーク 組む ちょうど よい 規模 しかし 接続 ノード 数 増える ため 現在 ルーター ブリッジ 複数 混在 ネットワーク なる キャンパス スイッチ 呼ぶ ネットワーク 機器 各種 イーサネット 規格 対応 傾向 ある WAN インタフェース 混在 こと 少ない LAN can 同士 相互 接続 ネットワーク 1 つ 都市 全域 広い 範囲 カバー こと ない MAN 構築 各種 ルーター スイッチ ハブ 使う 広い 範囲 カバー ネットワーク 通信 業 者 提供 インフラ 使う こと 多い WAN 技術 大半 OSI 参照 モデル 下位 3 層 物理 層 データ リンク 層 ネットワーク 層 機能 Global AREA Network gan いく つ 団体 定義 する 概念 まだ 広い 認知 定義 存在 一般 gan 多数 無線 LAN アクセス ポイント 通信 衛星 使う 移動 体 通信 広 範囲 行う こと 意味 場合 課題 なる 利用 者 ある アクセス ポイント 別 アクセス ポイント 通信 範囲 移動 とき シームレス 通信 継続 方法 IEEE Project 802 それ よる 地球 規模 連続 無線 LAN 環境 構築 する 2 インマルサット 衛星 使う broadband Global AREA Network bgan する IEEE 検討 物理 層 データ リンク 層 Mobile IP ネットワーク 層 技術 IETF 開発 こちら ネットワーク 媒体 問う 移動 コネクション 維持 技術 インター ネットワーク OSI 参照 モデル 第 3 層 ネットワーク 層 動作 機器 ルーター ネットワーク 相互 接続 こと あるいは 相互 接続 ネットワーク 指す また 企業 団体 政府 ネットワーク 間 相互 接続 指す 場合 ある 現在 インター ネットワーク Internet Protocol 使う インター ネットワーク 誰 管理 誰 参加 いう 観点 次 3 つ 分類 イントラネット エクストラネット インターネット 接続 持つ どう 決まる 定義 関係 ない インターネット 接続 場合 イントラネット エクストラネット インターネット 側 正しい 認証 なし アクセス 拒否 一般 イントラネット 単一 管理 主体 よる 管理 インター ネットワーク 複数 ネットワーク 相互 接続 もの 一般 外部 対する 閉じる 特定 ユーザー アクセス 企業 内 ネットワーク これ 当たる エクストラネット 複数 イントラネット 相互 接続 インター ネットワーク イントラネット 小 規模 単一 LAN 相当 こと ある エクストラネット 単一 LAN 構築 地球 上 多数 政府 学界 公共 私用 ネットワーク 相互 接続 インター ネットワーク アメリカ 国防 総省 ARPA 開発 arpanet 母体 なる World Wide Web 基盤 ある 他 インター ネットワーク 区別 ため 欧米 I 大 文字 する Internet 記す インターネット 上 IP アドレス 地域 インターネット レジストリ 管理 サービス プロバイダ 大 企業 ボーダ ゲートウェイ プロトコル bgp 通す アドレス 範囲 到達 可能 性 つく 情報 交換 コンピュータ ネットワーク 個々 機器 ネットワーク 物理 接続 技術 よる 分類 それ 光 ファイバー イーサネット 無線 LAN homepna 電力 線 搬送 通信 イーサネット 機器 接続 物理 配線 要する また 関連 機器 する ハブ スイッチ ブリッジ ルーター ある 無線 LAN 技術 配線 なし 機器 接続 機器 無線 通信 よる 接続 ネットワーク 様々 機器 ハードウェア 相互 接続 構成 接続 一般 何 ら 配線 必要 ケーブル カテゴリー 5 ケーブル 使う こと 多い ほか 無線 よる 接続 IEEE 802.11 光 ケーブル 光 ファイバー よる 接続 ある ネットワーク カード ネットワーク アダプタ あるいは NIC とも コンピュータ ネットワーク 接続 ため ハードウェア ネットワーク 媒体 物理 アクセス 提供 MAC アドレス 使う 低 レベル アドレス 指定 機構 提供 こと 多い コンピュータ ネットワーク カード 経由 ケーブル 無線 よる 他 コンピュータ 相互 接続 リピータ 伝送 路上 電子 機器 一種 信号 受信 それ 増幅 する 上 送出 これ よる 信号 より 長い 距離 到達 可能 なる リピータ 物理 信号 扱う もの 中身 解釈 こと ない 従う OSI 参照 モデル 言う 物理 層 動作 機器 ハブ 複数 ポート ある スイッチ 機能 ない ハブ ひと つ ポート パケット 到着 全 ポート それ コピー パケット コピー 際 送信 先 アドレス 変更 単に まま コピー 全 ポート 送る 3 ブリッジ OSI 参照 モデル データ リンク 層 第 2 層 ネットワーク 同士 接続 機器 ブリッジ パケット 送信 元 MAC アドレス 見る MAC アドレス ポート 対応 関係 学習 パケット 送信 先 アドレス 初めて 見る もの 場合 パケット 送信 元 ポート 以外 全 ポート コピー 転送 ブリッジ 以下 3 種類 分類 スイッチ マーケティング 要素 強い 用語 ルーター ブリッジ 負荷 分散 機能 ある 機器 包含 OSI 参照 モデル 様々 層 対応 スイッチ ある 物理 層 データ リンク 層 スイッチング ハブ ネットワーク 層 レイヤ 3 スイッチ トランスポート 層 レイヤ 4 スイッチ ある 複数 層 同時 対応 スイッチ 多層 スイッチ 呼ぶ スイッチ 意味 もの 多岐 わたる ため ネットワーク 理解 する とき そこ 最初 躓く こと 多い 特に 多層 スイッチ よく 理解 使う こと 困難 ルーター パケット ヘッダ 部  ...
# 通信プロトコル 通信 プロトコル つうしん プロトコル communications Protocol 通信 関する 規約 定める もの 通信 規約 通信 手順 訳す 場合 ある 通信 行う ため 通信 参加 もの 同士 間 あらかじめ 通信 関する 規約 定める たとえば 中世 おく 丘 上 狼煙 上げる それ 複数 丘 リレー こと 通信 行う 狼煙 上げる タイミング 意味 つく 事前 打つ 合わせる 決める 意味 成す 例えば 敵 500 人 現れる 危険 状況 黒い 狼煙 2 本 等 プロトコル 定める それ 従う こと 通信 成立 ため 基本 原理 言える プロトコル 異なる 機器 同士 通信 行う 場合 プロトコル コンバータ 英語 Protocol converter よう 機器 使用 一 つ 通信 役割 異なる 複数 プロトコル 成る 立つ こと 多い それ ら まとめる もの プロトコル スタック プロトコル ファミリー プロトコル スイート 呼ぶ これ ネットワーク プロトコル 階層 定義 対応 それ 実装 ソフトウェア 階層 構築 ため また こと プロトコル プロトコル スタック しばしば それ ら ソフトウェア 実装 指す こと ある 現在 広い 普及 プロトコル スイート する インターネット プロトコル スイート TCP IP 挙げる インターネット 通信 関する プロトコル コンピュータ 上 動く ソフトウェア 関する 取り決め 中心 伝送 路 ハードウェア つく 取り決め 含む ほとんど IETF よる 定める 他 もの つく IEEE iso 組織 よる 定める ITU t 電気 通信 関する プロトコル 策定 行う 通信 プロトコル 伝送 路 物理 条件 伝達 相手 特定 情報 表現 4 つ 基本 要素 成る 立つ 以下 各種 通信 プロトコル つく OSI 参照 モデル 7 層 うち 最も 近い 層 分類 もの なる HTTP Over tls https 使う SMTP Over SSL starttls 上記 プロトコル おく セキュリティ 上 欠点 補う もの ある 通信 関する 最初 Protocol プロトコル いう 用語 使う 1968 年 稼動 開始 arpanet アーパネット arpanet 世界 最初 コンピュータ ネットワーク する また 現在 インターネット 母体 なる ネットワーク する 知る 後 arpanet 手本 さらに 良い ネットワーク 構築 ため 生む x 25 いう 通信 手順 登場 プロトコル いう 用語 広まる 定着 1 can Controller AREA Network lin Local interconnect Network flexray よう 車載 機器 通信 規格 ある echonet echonet lite よう 家電 用 通信 規格 ある arcnet attached resource Computer Network よう 機器 間 通信 規約 ある spacewire よう 航空 宇宙 用 通信 規約 ある 暗号 通貨 多種 多様 現存 トークン 特異 性 かつ 暗号 通貨 間 チャネリング 交信 指す こと ある
# インタプリタ 記事 複数 問題 ある 改善 ノート ページ 議論 ご 協力 インタプリタ 英 interpreter 日 解釈 系 1 プログラミング 言語 書く ソース コード ないし 中間 表現 逐次 解釈 実行 英語 版 プログラム こと インタープリタ インタープリター 表記 こと ある インタプリタ およそ 次 いずれ 動作 する プログラム いずれ する インタプリタ 言語 いう 分類 本来 存在 単に それぞれ 言語 代表 処理 系 実装 インタプリタ いう いずれ 言語 つく コンパイラ 作る こと できる プログラミング 言語 処理 系 実装 インタプリタ コンパイラ 2 つ ある する インタプリタ 実行 英語 版 行う コンパイラ 実行 英語 版 行う いう 差 ある インタプリタ インタプリタ 提供 言語 プログラム 文 1 文 インタプリタ 実装 言語 機能 呼ぶ 単純 方式 一般 コマンド ライン インタプリタ これ 加える 別 プログラム 処理 委ねる 一 つ 機能 実現 時代 インタプリタ 長所 欠点 つく およそ 次 よう 解説 する こと 一般 後 そう する 欠点 解消 1990 年 代 ころ なる 毎回 毎回 高級 言語 機械 語 変換 ない 中間 言語 変換 こと 高速 化 はかる インタプリタ 作る 改良 結果 古典 意味 インタプリタ コンパイラ 双方 性質 備える インタプリタ 登場 複雑 化 近年 インタプリタ おこなう 旧来 コンパイラ 行く 変換 ひと つ する 高速 化 目的 する 実行 時 コンパイラ よる 動的 コンパイル 挙げる こと できる 3 インタプリタ いう 手法 すなわち ハードウェア 直接 解釈 ない プログラム 受ける 取る プログラム 実装 抽象 あるいは 仮想 上 コンピュータ 解釈 実行 いう プログラム 実行 法 コンピュータ 登場 時 ないし それ 以前 ある 万能 チューリング マシン どんな チューリング マシン つく それ 模擬 チューリング マシン いう もの ある 種 エミュレータ ないし インタプリタ 考察 電子 式 コンピュータ 誕生 以前 edsac 実用 機能 持つ プログラム 内蔵 方式 世界 初 電子 計算 機 する おく 既に ある 種 インタプリタ 実装 こと 記録 残る 同機 おく プログラミング 技法 書く THE preparation of Programs for AN Electronic DIGITAL Computer CHAPTER 2 2 22 interpretive subroutines で 説明 複 素数 演算 サブルーチン 明示 サブルーチン する 呼ぶ ない 通常 加減算 同様 形式 プログラム インタプリタ 解釈 それ ら サブルーチン 利用 いう もの また 日本 おく パンチ カード 入力 する パッチ パネル 配線 よる プログラミング 処理 機械 配線 よる 種 インタプリタ よう もの 実装 パンチ カード 内容 データ する ない プログラム よう 扱う いう 例 ある 言う 4 最初 LISP インタプリタ スティーブ ラッセル IBM 704 上 実装 これ エピソード ある ジョン マッカーシー LISP 論文 5 数学 示す もの マッカーシー 自身 実装 もの 考える それ 論文 読む 院生 ラッセル 実装 可能 言う 数学 記述 変換 機械 語 実装 いう 6 7 1960 年 代 現在 Java 同様 プログラミング 言語 中間 表現 コンパイル それ インタプリタ 実行 いう 手法 一般 p コード マシン 参照 初期 インタプリタ 最近 インタプリタ 長所 短所 異なる 短所 なくす 減らす しくみ 変える 歴史 ある ため プログラム 開発 中 プログラマ 頻繁 ソース コード 手 加える コンパイラ 場合 ソース コード 変更 たび コンパイル リンク 実行 ファイル 完成 プログラム 実行 プログラム 大きい なる ビルド 完了 待つ 時間 長い なる 一方 インタプリタ ソース コード まま 実行 中間 表現 変換 ほとんど 待つ 必要 ない 修正 うまい いく どう テスト より 素早い 確認 特性 利用 プログラム する repl ある 入力 受ける 取る READ 入力 評価 eval 評価 結果 提示 Print 繰る 返す loop テスト 環境 一 つ 評価 インタプリタ 限る コンパイラ 行なう しれる ユーザ 入力 常 ソース コード 断片 それ 逐次 実行 いう 点 一種 インタプリタ いう こと できる 実際 挙動 ソース コード 指定 起動 BASIC それ よく 似る しかし テスト 環境 兼ねる ため エラー 起きる 場合 メッセージ 詳細 こと 多い 関数 型 言語 論理 型 言語 通常 機械 語 コンパイル 処理 系 用意 コンパイラ 一般 ソース コード 特定 プロセッサ アーキテクチャ 機械 語 命令 列 変換 生成 プログラム 特定 アーキテクチャ プロセッサ 動く 変換 開発 者 環境 一度 行う バイナリ 配布 ユーザー 側 変換 行う 必要 ない クロス コンパイラ 使う 他 プロセッサ アーキテクチャ 向け バイナリ 生成 こと できる インタプリタ 場合 ソース コード 配布 変換 ユーザー 側 行う 必要 ある 特定 アーキテクチャ 依存 プログラム 配布 可能 ただし 場合 ユーザー マシン 上 適当 インタプリタ 実装 インタプリタ ソース コード 同時 提供 必要 ある 単に 実行 ファイル 配布 場合 インストール 全体 する 複雑 化 こと ある インタプリタ 用 コード 人間 容易 読む こと できる ため 著作 権 保護 観点 問題 ある する 方 ある しかし ため 様々 暗号 化 難読 化 システム 存在 バイト コード よう 中間 コード 配布 場合 ある 程度 難読 化 同様 効果 ある バイト コード 逆 コンパイラ あるいは 逆 アセンブラ デコード こと 可能 抗 逆 コンパイル 性 ある 難読 化 考慮 バイト コード する 設計 ある インタプリタ 最大 短所 コンパイラ 実行 時 性能 低い こと 性能 差 様々 時 桁違い なる こと ある プログラム 実行 時間 コンパイラ インタプリタ 方 長い コンパイル 時間 実行 時間 合計 インタプリタ 実行 時間 長い なる こと ある プロトタイピング テスト おく 差 重要 なる コンパイラ プログラム 内 文 解析 実行 前 1 回 行う 単純 実装 インタプリタ それ 文 ごと 実行 時 毎回 行う ため 実行 性能 低い なる 単純 実装 インタプリタ 変数 アクセス 際 識別 子 メモリ 上 位置 マッピング 確認 しかも それ 実行 中 何 度 行う 遅い なる 単純 実装 インタプリタ 方式 速度 遅い なる 最大 原因 一 命令 ごと switch 文 実行 こと ある 現代 CPU パイプライン 方式 採用 命令 先読み 可能 ない 実行 速度 著しい 低下 switch 文 場所 命令 先読み 不 可能 ため 単純 実装 インタプリタ 方式 遅い なる 単純 実装 インタプリタ 方式 実装 処理 系 高速 化 最適 化 ため 最初 とる ステップ switch 文 廃止 コンパイラ 方式 切る 替える こと それ ゆえ 実装 不 可能 いう わけ ない 効果 薄い ため インタプリタ 方式 実装 場合 一般 制御 フロー 解析 静的 単一 代入 使う 複数 命令 超える 最適 化 実装 こと 多い インタプリタ よる 開発 速い コンパイラ よる 実行 速い 間 様々 妥協 案 考案 一部 LISP 処理 系 インタプリタ コード コンパイル コード 相互 呼ぶ こと できる 変数 共有 ため ある ルーチン インタプリタ 評価 デバッグ 後 先行 コンパイル 実行 性能 高める 他 ルーチン 開発 こと できる 多く インタプリタ ソース コード まま 実行 わけ ない より コンパクト 内部 形式 変換 多く Basic インタプリタ 予約 語 1 バイト トークン 置換 それ ジャンプ テーブル インデックス する 使用 pbasic 一部 インタプリタ バイト 単位 ない ビット 単位 プログラム 短縮 行う 例えば コマンド 5 ビット 表す 一般 16 ビット 表す 定数 数値 大きい 対応 可変 長 3 6 10 18 ビット 表す アドレス オペランド する ビット オフセット 用意 多く Basic インタプリタ 独自 トークン 化 内部 表現 保存 読む こと できる インタプリタ コンパイラ 同様 字句 解析 構文 解析 行う 結果 生成 抽象 構文 木 解釈 こと ある それ 自体 インタプリタ 手法 言える コンパイラ 手法 言える どちら 言う 中間 表現 1 種類 いう しれる 仮想 関数 テーブル テーブル ジャンプ よる フロー 制御 似る ない スレッデッドコード 呼ぶ サブルーチン アドレス 順番 羅列 もの 直接 スレッディング 場合 アドレス 指す 先 機械 語 サブルーチン 他 いく つ バリエーション ある サブルーチン スレッディング 最も 違う タイプ バリエーション ...
# ミドルウェア ミドルウェア 英 middleware コンピュータ 分野 コンピュータ 基本 制御 行う オペレーティング システム OS 各 業務 処理 行う アプリケーション ソフトウェア 中間 入る ソフトウェア こと 通常 オペレーティング システム 機能 拡張 あるいは アプリケーション ソフトウェア 汎用 共通 機能 集める もの アプリケーション ソフトウェア ミドルウェア 要求 出す ミドルウェア オペレーティング システム 必要 要求 出す 結果 アプリケーション ソフトウェア 返す あるいは ミドルウェア 自体 各 アプリケーション ソフトウェア 起動 停止 監視 含める 制御 行う 代表 ミドルウェア データベース 管理 システム DBMS トランザクション モニター ある アプリケーション プログラム 動作 あたる ネットワーク 上 他 サーバ データベース やり取り 普遍 面倒 手続き 要する もの ある これ ら やり取り 手順 管理 種別 単位 まとめる ひと つ 機能 管理 パッケージ ソフトウェア する まとめる もの ミドルウェア 企業 システム 社会 インフラ システム エンタープライズ 領域 システム 構築 分散 ソフトウェア アプリケーション ソフトウェア 間 データ やり取り 司る ミドルウェア する それぞれ 管理 分野 専用 ソフトウェア 用いる 事 多い カスタマイズ 幅 大きい それぞれ システム 特性 合わせる 最適 化 設定 必要 なる 最近 システム 構築 おく オペレーティング システム ミドルウェア システム プラットフォーム また システム 基盤 呼ぶ する ひと つ 管理 単位 する 定義 専用 エンジニア IT コンサルタント 設計 構築 依頼 事 多い なお 以上 全く 説明 個人 レベル 使用 ミドルウェア 数 多い 1960 年 代 後半 ims データベース 管理 システム トランザクション モニター 登場 これ ら 主に メインフレーム ミニコンピュータ 中心 発達 特に 重要 基幹 業務 性能 信頼 性 確保 ため 使用 1990 年 代 ダウンサイジング 潮流 よる 分散 システム 中心 する システム 普及 ミドルウェア 使用 一般 化 特に UNIX Windows OS 標準 ごく 単純 ファイル システム 管理 権限 設定 持つ こと 標準 化 潮流 ある ミドルウェア 併用 システム 構築 普及 システム よる 必要 する 機能 異なる ため より 少ない リソース 動作 ため OS 基本 機能 他 機能 ごと オプション なる 製品 商品 化
# 仮想マシン 仮想 機械 そう きかい 仮想 マシン バーチャル マシン 英語 Virtual machine VM コンピュータ 動作 エミュレート ソフトウェア フレームワーク また エミュレート 仮想 コンピュータ もの 仮想 機械 いう 仮想 機械 よる 1 つ コンピュータ 上 複数 コンピュータ OS 動作 別 アーキテクチャ 用 ソフトウェア 動作 こと できる アプリケーション 互い 干渉 防げる 1 システム 仮想 機械 システム 全体 再現 上 OS 動かす こと 可能 動作 OS いくら 変更 加える こと 必要 場合 準 仮想 化 ある システム 仮想 機械 複数 仮想 機械 計算 資源 メモリ 資源 ディスク 資源 効率 配分 スケジュール ハードウェア 割る 伝達 必要 ある これ ら 制御 プログラム ハイパーバイザ 呼ぶ システム 仮想 機械 ユーザー プログラム 別 コンピュータ 見える もの OS 環境 実現 もの 指す コンピュータ 初期 仮想 記憶 マルチタスク マルチ ユーザー タイム シェアリング 現在 OS 機能 なる 技術 含める 場合 ある 仮想 機械 技術 メイン フレーム 使う 現在 コンピュータ よる サービス 提供 分野 一般 技術 なる クラウド コンピューティング おく ハードウェア 依存 仮想 実行 環境 構築 基盤 技術 iaas する 利用 1940 年 代 1950 年 代 コンピュータ 機種 ごと アーキテクチャ 異なる あたりまえ 既存 設計 参考 する こと 新規 設計 リスク 避ける よそ コンピュータ 既存 プログラム ライブラリ 流用 ため 目的 既存 機 命令 セット 互換 性 持つ 論理 設計 共通 する 一種 互換 機 言える マシン 存在 たとえば edsac よく 参考 する 1958 年 IBM 709 既存 IBM 704 命令 セット マイクロ コード エミュレーション 上位 互換 性 提供 1964 年 IBM System 360 同様 既存 IBM 1401 IBM 1620 命令 セット マイクロ コード エミュレーション また コンピュータ アーキテクチャ 定義 標準 化 以後 互換 性 提供 通常 仮想 化 呼ぶ プログラム 見る 一種 仮想 機械 言える 効果 する メインフレーム アセンブリ 言語 バイナリ 40 年 以上 経過 現在 互換 続く 1973 年 IBM System 370 モデル 158 および モデル 168 よる 物理 分割 ppar サポート 単一 コンピュータ する 複数 コンピュータ する 使用 可能 ただし 細かい リソース 割り当て できる 変更 コンピュータ 全体 再 起動 必要 1987 年 IBM 3090 PR SM よる 多数 論理 区画 lpar 作成 コンピュータ 全体 停止 伴う より 柔軟 リソース 割り当て 可能 なる IBM PR SM 相当 機能 日立 製作 所 prmf ある 1964 年 IBM System 360 商用 初 仮想 化 OS CP 40 CP 67 よる ひと つ コンピュータ 複数 仮想 コンピュータ 作成 それぞれ ゲスト OS mvs CMS 稼動 事 できる 仮想 化 OS VM CMS なる 現在 z VM する 多数 ゲスト OS Linux 同時 稼動 用途 使う IBM z VM 相当 製品 富士通 AVM 日立 製作 所 vms ある OS 機能 よる 各種 リソース 仮想 化 仮想 記憶 マルチタスク マルチ ユーザー タイム シェアリング ある 主 記憶 装置 仮想 化 仮想 記憶 商用 1961 年 バロース b 5000 登場 1970 年 IBM System 370 広い 普及 マルチタスク アプリケーション よる マルチ プログラミング ない OS 機能 よる マルチタスク 商用 OS 360 バリエーション ひと つ mvt 後継 mvs 登場 広い 普及 入出力 待ち CPU 他 処理 行える ため 処理 応答 時間 短縮 全体 スループット 向上 もたらす なお メインフレーム おく これ ら マルチタスク 単に 複数 プログラム 同時 動かせる いう ない 複数 独立 アドレス 空間 リージョン 作成 ハードウェア 機能 使用 完全 分離 同時 稼働 プログラム 同士 直接 見える バグ 悪意 プログラム 相互 干渉 もの 点 後 各種 UNIX Windows マルチタスク 比較 仮想 機械 近い レベル もの 可用 性 セキュリティ 向上 同様 仕組み 2009 年 現在 mvs 後継 z OS 他 IBM z vse 富士通 MSP xsp 日立 製作 所 vos 3 採用 タイム シェアリング 時分 割 多重 よる 並列 処理 マルチ ユーザー アプリケーション プログラム ユーザー 複数 コンピュータ 同時 使用 イメージ もたらす オンライン リアル タイム 処理 普及 もたらす なお マルチタスク タイム シェアリング 別 技術 現在 組む 合わせる 使用 上記 mvs マルチタスク 環境 一部 タイム シェアリング 環境 稼働 それ よる マルチ ユーザー 実現 また マルチタスク 自体 初期 入出力 待ち よる 割り込み 基本 現在 タイムシェリング よる 割り込み 併用 1979 年 IBM System 38 timi Technology Independent machine interface 技術 依存 マシン インターフェイス 採用 timi メインフレーム 採用 マイクロ コード よる 互換 性 確保 更に 進める もの 主に 水平 型 レベル マイクロ コード よる 実現 ハードウェア アーキテクチャ CPU 命令 セット 等 プログラム 分離 プログラム 配布 中間 コード バイト コード 行う インストール 時 ハードウェア 命令 セット 展開 ため ソース プログラム 配布 こと 無い 実行 時 性能 犠牲 する こと ない 別 アーキテクチャ ハードウェア 移行 容易 実際 CPU アーキテクチャ 移行 独自 cisc Power 容易 行える する timi System 38 後継 AS 400 iseries System I Power systems I Edition 現在 使用 また 現在 lpar 併用 後述 powervm 参照 各社 商用 ミッド レンジ コンピュータ オフィス コンピュータ ミニコンピュータ timi 同等 機能 持つ シリーズ 過去 現在 存在 商用 UNIX ベンダー よる 仮想 化 技術 以下 ある 現在 仮想 化 技術 各種 ハードウェア ソフトウェア 密接 連携 また ベンダー よる 各 技術 範囲 異なる ため ベンダー 単位 記載 UNIX Linux Windows 上 動作 仮想 マシン VMware xen Oracle VM ベース xen hyper V ある 物理 資源 区分け 特定 ワーク ロード システム 全体 独占 機構 仮想 マシン モニタ 持つ 一 台 コンピュータ 複数 コンピュータ する 使う こと できる オペレーティング システム 変更 なし 複数 ゲスト オペレーティング システム 稼働 稼働 複数 ゲスト オペレーティング システム 全く 別 種類 オペレーティング システム こと 可能 元々 仮想 マシン モニタ メインフレーム おく 資源 各 ワーク ロード 負荷 応ずる 動的 分割 システム 全体 利用 効率 上げる ため 用いる 計算 機 高 性能 化 現在 小 規模 web ホスティング よう 処理 それ ら 仮想 マシン モニタ 用いる 並列 実行 こと 行う 1985 年 インテル 80386 採用 仮想 86 モード 保護 モード 導入 以前 x 86 アーキテクチャ 則る タスク 保護 モード 上 実行 仮想 機械 提供 OS 2 2.0 Windows 3.0 DOS 互換 環境 仮想 DOS マシン 使用 現在 CPU アーキテクチャ sparc Power IA 64 それぞれ 仮想 マシン ソフトウェア OS よる 仮想 化 支援 命令 セット 持つ いく つ アプリケーション プログラム 動作 ため 仮想 機械 いく つ プログラミング 言語 実装 理論 上 機械 よる 実行 こと 想定 機械 エミュレート 場合 多い ソフトウェア よる 仮想 CPU バイト コード 実行 形式 一般 バイト コード 実行 方法 インタプリタ 方式 実行 前 全 バイト コード ネイティブ 変換 事前 コンパイル 方式 実行 時 コンパイル 方式 ある 現在 性能 観点 実行 時 コンパイル 方式 主流 ハードウェア 制約 ない 特徴 型 つき 演算 サポート 仮想 機械 ある これ ら 仮想 機械 理論 設計 もの 実行 最適 化 ため 対応 ハードウェア 製造 場合 ある
# オペレーティングシステム オペレーティング システム 英 Operating System 略称 OS オーエス コンピュータ オペレーション 操作 運用 運転 司る システム ソフトウェア OS 通常 ユーザー アプリケーション プログラム ハードウェア 中間 位置 ユーザー アプリケーション プログラム 対する 標準 インターフェース 提供 同時 ハードウェア 各 リソース 対する 効率 管理 行う 現代 OS 機能 ファイル システム 補助 記憶 装置 管理 仮想 記憶 メモリ 管理 マルチタスク プロセス 管理 更に GUI ユーザ インタフェース TCP IP ネットワーク ある OS パーソナル コンピュータ スーパー コンピュータ 各種 コンピュータ 更に スマートフォン ゲーム 機 含む 各種 組み込み システム 内部 使用 商品 する ないし 製品 する OS デスクトップ 環境 ウィンドウ システム あるいは データベース 管理 システム DBMS ミドルウェア ファイル 管理 ソフトウェア エディタ 各種 設定 ツール ユーティリティ ウェブ ブラウザ 時計 アクセサリ マーケティング 上 理由 一緒 含める こと ある 現代 OS Microsoft Windows Windows phone IBM z OS Android macos 旧 Mac OS x OS x ios 旧 OS x iPhone iPhone OS ipados Linux freebsd ある 1 2 OS 目的 ハードウェア 抽象 化 リソース 管理 そして コンピュータ 利用 効率 向上 3 4 OS アプリケーション ソフトウェア 動作 第 一 目的 ため インターフェース API アプリケーション プログラミング インタフェース abi アプリケーション バイナリ インタフェース カーネル システム コール よる アプリケーション サービス 提供 さらに 基本 ライブラリ 含める 形 アプリケーション 対する API abi 提供 アプリケーション よる OS 上 ミドルウェア アプリケーション フレームワーク API する 使用 場合 ある API プログラミング ため インターフェース プログラム 作成 際 規則 構成 例えば c 言語 関数 FORTRAN PASCAL ライブラリ 呼び出し 仕様 いう もの それ あたる 一方 abi コンパイル ソフトウェア OS 機能 呼ぶ 際 インタフェース プロセス 動作 際 規則 構成 例えば UNIX 系 OS API ほとんど 共通 abi OS よる 異なる したがう CPU 使う システム abi 異なる 実行 ファイル 異なる abi 呼出 規約 システム コール 方法 含む なお OS 垣根 越える abi いく つ 存在 例えば ocmp Open computing Environment for mips platform いう mips 系 チップ 使用 UNIX 機 よる バイナリ 共通 インタフェース 日本 電気 ソニー 住友 電気 工業 日本 タンデムコンピューターズ よる 定義 定義 沿う UNIX OS 複数 販売 ファームウェア デバイス ドライバ 助け 借りる カーネル コンピュータ 全 ハードウェア デバイス 基本 制御 提供 RAM 上 プログラム メモリ アクセス 管理 プログラム ハードウェア 資源 アクセス 得る 決定 常 運用 最適 化 CPU 状態 設定 ファイル システム 共 ディスク 磁気 テープ フラッシュ メモリ いう 長期 不 揮発 性 記憶 装置 データ 編成 行う OS アプリケーション プログラム コンピュータ ハードウェア 間 インタフェース 提供 OS 組む 規則 手続き 従う こと よる アプリケーション プログラム ハードウェア やりとり OS また アプリケーション プログラム 開発 実行 簡素 化 サービス 群 提供 アプリケーション プログラム 実行 あたる OS カーネル プロセス 生成 プロセス 生成 メモリ 空間 資源 割る 当てる マルチタスク システム プロセス 優先 度 割る 当てる プログラム バイナリ コード メモリ ロード アプリケーション プログラム 実行 開始 いう 仕事 含む そう する 初めて ユーザー ハードウェア デバイス やりとり 開始 割る OS 要 OS 周囲 環境 相互 作用 反応 ため 効率 手段 なる 非常 スタック 50 バイト 60 バイト 持つ 古い システム OS 対応 イベント 発生 源 監視 ポーリング 方式 採用 現代 スタック 持つ システム 一般 ない 現代 多く CPU 割り込み ベース する プログラミング 直接 サポート 割り込み 発生 時点 レジスタ コンテキスト 退避 イベント 対応 特定 コード 実行 非常 基本 コンピュータ ハードウェア 割る 機能 ある プログラマ 特定 割り込み 発生 とき 実行 コード 設定 こと できる 割り込み 受信 コンピュータ ハードウェア 実行 中 プログラム 自動 一時 停止 状態 退避 割る 事前 割る 当てる コード 実行 これ 例えば 読書 中 電話 鳴る とき 本 しおり 挟む 電話 出る 似る 現代 OS 割る OS カーネル 扱う 割る コンピュータ ハードウェア 発生 場合 ある 実行 中 プログラム 発生 場合 ある ハードウェア 割り込み 発生 場合 OS カーネル イベント どう 対応 一般 何 ら 処理 コード 実行 決定 割る 優先 順位 ある それ 従う 実行 コード 決定 再び 人間 たとえる 電話 鳴る 同時 火災 知る 火災 報知 器 非常 ベル 鳴る 電話 出る 避難 ハードウェア 割り込み 処理 通常 デバイス ドライバ 呼ぶ ソフトウェア 委任 デバイス ドライバ OS カーネル 一部 いう 場合 ある 別 プログラム いう 場合 ある 混在 場合 ある デバイス ドライバ 割る よる 情報 各種 手段 通ずる 動作 中 プログラム 中継 実行 中 プログラム OS 対する 割り込み 発生 場合 ある 例えば ある プログラム ハードウェア アクセス 場合 OS カーネル 対する 割り込み 発生 結果 する 制御 カーネル 移す カーネル 必要 処理 行う また プログラム メモリ 資源 追加 要求 場合 割り込み 発生 カーネル 知る ただし それ ら 一般 システム コール 呼ぶ ハードウェア 割る 実装 異なる こと ある 現代 CPU 複数 運用 モード ある 場合 少ない ユーザー モード スーパー バイザ モード 2 つ 存在 スーパー バイザ モード OS カーネル 使用 モード ハードウェア 無 制限 アクセス メモリ 読み書き 方法 制御 グラフィックス カード デバイス やりとり 一方 ユーザー モード カーネル 以外 ほぼ 全て 使用 アプリケーション ユーザー モード 動作 ハードウェア やりとり カーネル 通す 必要 ある CPU 2 つ 以上 モード 持つ こと ある 古い プロセッサ エミュレート 使う コンピュータ 起動 際 自動 スーパー バイザ モード 動作 BIOS efi ブート ローダー OS カーネル いう ごく 一部 プログラム スーパー バイザ モード 動作 ユーザー モード 環境 初期 化 外側 ある プログラム ない 行える ため しかし OS 他 プログラム 制御 渡す 際 CPU ユーザー モード 設定 ユーザー モード プログラム 使用 CPU 命令 セット 制限 ユーザー プログラム ユーザー モード 抜ける 割り込み 発生 カーネル 制御 戻す ハードウェア メモリ アクセス いう こと 独占 制御 OS 保持 パーキンソン 法則 よる メモリ 拡張 プログラム それ 伴う 拡大 いう プログラマー 無限 容量 無限 速度 メモリ 理想 する コンピュータ メモリ 階層 構造 なる 最も 高速 レジスタ キャッシュ メモリ RAM 最も 低速 ディスク 装置 ある OS 内 メモリ 管理 部 メモリ 管理 もの 利用 可能 部分 割り当て 解放 主 記憶 二 次 記憶 間 スワップ 制御 マルチ プログラミング OS カーネル プログラム 使用 中 全 システム メモリ 管理 責任 負う それ よる プログラム 既に 別 プログラム 使用 メモリ 誤る 使用 プログラム 群 時分 割 動作 それぞれ プログラム 独立 メモリ アクセス 可能 なる 協調 メモリ 管理 初期 OS よく 使う 方式 全 プログラム 自発 カーネル メモリ 管理 機構 使う 割る 当てる メモリ はむ 動作 こと 前提 する プログラム バグ つきもの ため 割る 当てる メモリ はむ こと ある ため メモリ 管理 今 見る プログラム 異常 動作 他 プログラム 使用 中 メモリ 書く 換える こと ある 悪意 プログラム ウイルス 意図 他 プログラム メモリ 書く 換える OS 自体 動作 妨げる こと 可能 協調 メモリ 管理 たった 1 つ プログラム 動作 する システム 全体 クラッシュ カーネル よる メモリ 保護 よる プロセス メモリ アクセス 制限 メモリ 保護 様々 技法 ある セグメント 方式 ペー ...
# ソフトウェア品質 ソフトウェア 品質 ソフトウェア ひんしつ 英 Software Quality ソフトウェア 品質 指す プログラマ 観点 ソース コード 品質 エンド ユーザー 観点 アプリケーション ソフトウェア 品質 意味 ソフトウェア 品質 定義 様々 ジェラルド ワインバーグ 著書 Quality Software MANAGEMENT systems thinking V 1 で 品質 誰 とる 価値 書く 定義 品質 本来 主観 もの こと 強調 ソフトウェア 人 よる 品質 感ずる 方 全く 異なる 定義 利点 ソフトウェア 開発 チーム ソフトウェア 誰 ため 作る 彼 ら とる 価値 何 いう 疑問 抱く 点 ある 品質 目的 適合 性 定義 場合 品質 測定 使う 尺度 属性 決定 際 ソフトウェア 目的 考慮 必要 ある こと 意味 コンピュータ とる きれい 書く ソース コード いう 概念 意味 無い しかし 人間 とる プログラム どう 書く それ 保守 際 重要 意味 持つ 様々 プログラミング 作法 可読 性 言語 固有 規約 強調 ソース コード 保守 性 向上 デバッグ 修正 容易 他 うまい 書く コード いう 概念 コード 管理 可能 部分 論理 分割 こと 含む 品質 向上 手法 リファクタリング ソフトウェア 信頼 性 reliability ソフトウェア 品質 測る 重要 尺度 観点 品質 Quality いう 用語 主観 定性 要素 含む ソフトウェア 信頼 性 客観 基準 測定 可能 測定 基準 一般 ソフトウェア メトリック 呼ぶ ソフトウェア 信頼 性 改善 実際 作業 ソフトウェア 開発 扱う 理解 可能 もの する いう 圧力 よる なす もの 収益 求める もの ない しかし ソフトウェア 産業 成熟 共 ユーザー ソフトウェア 製品 期待 品質 レベル 高い なる 信頼 性 確保 収益 繋がる いう 状況 できる 組み込み システム ソフトウェア 問題 不便 以上 問題 生じる 場合 よる 人命 関わる 原因 ユーザ インタフェース 貧弱 さ 直接 バグ 様々 多く 人命 関わる プログラム バグ つく levenson 論文 Medical devices THE therac 25 PDF 詳しい 結果 する ソフトウェア 信頼 性 関する 要求 仕様 生まれる アメリカ 合衆 国 アメリカ 食品 医薬 品 局 FDA 連邦 航空 局 FAA ソフトウェア 開発 つく 種 要求 仕様 策定 現代 工学 分野 技術 ソフトウェア 開発 適用 ため ソフトウェア 品質 客観 判断 方法 必要 する これ 誰 見る コンピュータ ソフトウェア 予定 通り 動作 する いう 一般 観測 結果 基づく 動機 言う 換える ソフトウェア 何 ら 問題 抱える 不 適当 動作 見せる 原因 処理 中 データ 問題 ソフトウェア 動作 ハードウェア 問題 操作 者 マシン 悪 影響 及ぼす ため 経済 活動 生産 プロセス 生命 維持 直接 関わる システム より 重要 ソフトウェア ソフトウェア 信頼 性 評価 必要 性 大きい なる ある ソフトウェア アプリケーション 重要 さ 度合い よる ソフトウェア 我々 生活 あらゆる 面 深い 浸透 我々 社会 基盤 ソフトウェア 依存 限り 浸透 続く 予想 社会 基盤 ソフトウェア 依存 強める つれる ソフトウェア 信頼 性 レベル 向上 求める すなわち ソフトウェア 意図 動作 常 改良 求める 前節 循環 文章 偶然 ない これ ソフトウェア 信頼 性 測定 関する 基本 問題 表す 信頼 性 判断 難しい 特に 事前 ソフトウェア どう 使う 正確 想定 こと 難しい 問題 従来 人間 担う 役割 ソフトウェア 代替 いう 共通 概念 錯覚 生じる 問題 2 つ レベル 分ける 第 一 最新 ソフトウェア 人間 できる こと 実行 特に 人間 比較 信頼 性 非常 高い 第 二 ソフトウェア 人間 精神 面 代替 こと できる つまり 融通 利く 常識 働く 概念 こと 理解 能力 ない それ かかわる 多く ソフトウェア プログラム 何 ら 目的 持つ 見なす こと できる 目的 明確 定義 ソフトウェア ある 環境 データ 与える とき 予測 結果 実際 結果 比較 こと 信頼 性 客観 判断 こと できる こと 期待 しかし 今 ところ プログラム 環境 データ 与える とき 予測 結果 実際 結果 正確 求める こと 可能 どう 定か ない そして 手段 ない プログラム 信頼 性 確実 性 もつ 決定 こと できる しかし 実際 プログラム プログラム 理論 記述 つく 環境 入力 よる 振る舞い 明らか いう 試み これ 数多く なす ソフトウェア 信頼 性 改善 ため 種 試み 実際 ソフトウェア 開発 様々 工程 要求 仕様 設計 プログラミング テスト 実行 時 評価 適用 ソフトウェア 理論 信頼 性 研究 主に 正当 性 概念 扱う 形式 言語 オートマトン いう 計算 機 科学 数学 分野 派生 プログラム 開発 者 どう 動作 事前 また 開発 中 詳細 把握 それ 望ましい 動作 する こと 期待 程度 詳細 把握 議論 余地 ある 完璧 詳細 さ いう 考える 方 魅力 実際 問題 する 現実 ない なぜ こう ある いう 要求 仕様 試行 錯誤 変化 もの 事前 要求 仕様 うまい 記述 どう 信頼 性 分かれ目 要求 仕様 形式 化 モデリング 言語 利用 採用 ため また プログラマ 以外 専門 家 ない 人々 ソフトウェア 振る舞い 正しい 伝達 手段 ある 実際 プログラマ どう 動作 事前 把握 こと 多い それ 要求 仕様 関する 議論 困難 要求 仕様 プログラム す こと 記述 対する ソフトウェア 設計 プログラム それ 記述 設計 工程 有用 性 異論 ある 信頼 性 観点 ソフトウェア 設計 工程 重要 性 指摘 ソフトウェア 設計 ソフトウェア 部品 わけ それ ら す こと 記述 プログラム 細分 化 部品 群 全体 する 正しい 機能 高 レベル 設計 目的 次 よう アーキテクチャ 上 問題 プログラム 概念 構造 関する 問題 実際 データ 処理 関わる コード 上 問題 分離 ソフトウェア コンポーネント 細分 化 こと 個々 コンポーネント 開発 関わる もの 制約 与える 結果 する バグ 作る コンポーネント 間 インタフェース 定義 こと 複数 チーム それぞれ 別 コンポーネント 並行 開発 各 チーム 役割 認識 また 実装 言語 指定 プログラム 機能 記述 こと 言語 依存 偏向 排除 プログラミング 言語 開発 史 プログラム 複雑 さ 克服 試み 歴史 言語 発展 ない プログラム 規模 対する 指数 関数 理解 困難 プログラミング 言語 コンピュータ よる 多く 仕事 する 進化 言う 事 できる これ こと 別 観点 言う プログラム 全体 構造 機能 見る 失う バグ 見る 逃す こと 多い なる 従う よい 言語 使う 理解 容易 バグ 減らせる 言語 ソフトウェア 設計 意図 こと なるべく 簡単 記述 進化 文 サブルーチン ファイル クラス テンプレート ライブラリ コンポーネント いう 概念 導入 よる プログラム 記述 抽象 化 階層 化 モジュール 化 コード 理解 容易 さらに 言語 進化 よる データ 構造 利用 関する 正確 制御 可能 なる プログラム 要求 仕様 通り 動作 判定 ソフトウェア テスト 単体 テスト プログラム ごく 一部 多く 場合 1 つ サブルーチン 毎 対象 仕様 通り 動作 こと 確認 結合 テスト より モジュール 単位 動作 確認 実行 時 信頼 性 判定 テスト 似る 観点 より 単純 性能 他 コード 相互 運用 性 特定 ハードウェア 構成 動作 可能 いう 点 評価 ソフトウェア 品質 要因 機能 面 以外 要求 仕様 考える 顧客 契約 明記 こと 少ない しかし ソフトウェア 品質 強化 こと 望ましい 以下 ソフトウェア 品質 要因 列挙 ソフトウェア 品質 測定 様々 観点 ある しかし 万人 納得 測定 観点 珍しい 人 よる ソフトウェア 品質 定量 測定 必須 する 他 人 定量 測定 有効 場面 限る 考える ため 定性 測定 好む 真 望ましい 測定 行う こと 難しい ソフトウェア テスト 分野 権威 何 人 書く 例えば cem kaner 英語 版 Software engineering metrics what do they measure AND how do we know 1 Douglass hoffman THE darker SIDE of metrics 2 ある よく 使う メトリック 例 する 検出 バグ 数 ある バグ 少ない ソフトウェア バグ 多い ソフトウェア 比べる 品質 高い する 以下 よう 質問 回答 考える こと メトリック 特定 場面 役立つ どう 考える こと できる 最後 質問 特に 管理 上 難しい 示す ソフトウェア 人間 作る もの ため ソフトウェア 品質 メトリック ある 意味 人間 振る舞い 測 ...
# ツール プログラミング ツール コンピュータ プログラミング 使う ツール 呼ぶ コンピュータ プログラム 類 こと 記事 もっぱら コンピュータ プログラミング 用 ツール つく 扱う プログラマブル コンピュータ 登場 同時 プログラミング 支援 コンピュータ プログラム いう もの 作る コンパイラ インタプリタ いう プログラミング 言語 処理 系 ツール 含める こと ある 言語 処理 系 以外 専ら 支援 ツール 指す こと ある ごく 原始 もの 例 する 紙 テープ パンチ カード 2 組 用意 それぞれ 内容 同じ こと 確認 こと 入力 ミス ない どう チェック いう もの ある これ ごく 単純 ため ハードウェア よる もの ある 1970 年 代 初期 UNIX grep AWK いう ツール 多用 それ ら パイプ 連結 使う こと よく 知る ソフトウェア ツール いう 言葉 ブライアン カーニハン ら 同名 著書 日本 語 版 ソフトウェア 作法 由来 しかし これ ら プログラミング ツール いう 本来 あらゆる データ 処理 対象 使える もの ため プログラミング 使える 言う ほう 正しい そもそも UNIX 開発 動機 いく つ うち 一 つ ベル 研 内 特許 はじめ する 書類 データ 処理 ため roff UNIX 標準 ツール そう いう 由来 よる こう いう ツール 単純 軽量 もの 組む 合せる 使う いう 所 本領 ある 一方 UNIX また 異なる 文化 する LISP Smalltalk 文化 ある 特に Smalltalk クラス ブラウザ よる クラス ライブラリ 簡単 追う こと できる こと 場 環境 プログラム 書く 換える いう こと できる GUI 環境 表面 後 Macintosh 引く 継ぐ 自由 環境 いう 精神 むしろ 引く 継ぐ 統合 開発 環境 IDE 元々 シングル タスク 環境 パーソナル コンピュータ おく 1 個 アプリケーション 編集 コンパイル フロント エンド デバッガ 等 各種 作業 行える もの 始まる 前述 Smalltalk よう 環境 パーソナル コンピュータ なん 実現 する もの 見る こと できる 後 パーソナル コンピュータ Windows あるいは UNIX ライク OS Linux 使える 例えば eclipse より 洗練 Smalltalk それ 近い 環境 現れる MS-DOS 以来 伝統 残す Visual studio まだ 使う しかし 近年 Windows 以外 バージョン 中心 中身 xamarin studio 置く 換わる とりあえず 適当 例 挙げる ソフトウェア ツール 様々 形態 ある 統合 開発 環境 IDE 多数 ツール 機能 組む 合わせる 1 つ パッケージ する もの 一般 ある プロジェクト 内 ファイル 群 内容 検索 いう 単純 作業 より 簡単 IDE 企業 レベル アプリケーション 開発 よく 使う 以下 IDE 挙げる
# プログラミングパラダイム プログラミング パラダイム 英 programming paradigm プログラミング おく パラダイム プログラミング パラダイム プログラマ プログラム 見る 方 与える もの 言える たとえば オブジェクト 指向 プログラミング おく プログラム オブジェクト つくる それ 管理 もの 関数 型 プログラミング おく 状態 持つ 関数 評価 連続 プログラミング 言語 異なる 対応 パラダイム 異なる Smalltalk Java 手続き 型 オブジェクト 指向 haskell 関数 プログラミング いう 比較 少数 パラダイム 対応 一方 竹内 ら tao よう 多数 パラダイム 対応 言語 マルチ パラダイム プログラミング 言語 存在 多く プログラミング パラダイム いける こと 禁じ手 存在 たとえば 純粋 関数 型 プログラミング 副 作用 ある なる 構造 化 プログラミング GOTO 無 制限 利用 戒める 特に 理由 よる 古い スタイル 慣れる 人々 非 現実 また 過剰 厳密 もの する よく 見なす しかし こう する 特定 テクニック 避ける いう こと プログラミング 言語 一般 法則 制約 こと ない プログラム 正確 さ あるいは 単に 動作 理解 こと つく 法則 証明 マルチ パラダイム プログラミング 言語 登場 プログラミング パラダイム プログラミング 言語 関連 複雑 たとえば c 手続き 型 プログラミング ジェネリック プログラミング オブジェクト 指向 プログラミング 対応 設計 設計 時 個々 部分 毎 パラダイム 使う 選ぶ 必要 迫る ある プログラム 全て 手続き 型 プログラミング 作る また ある プログラム 全て オブジェクト 指向 作る また 別 プログラム 両方 混在 作る いう 具合 比較 もの 横 並べる 括弧 内 それ 用いる 例
# ...
# コンピュータゲーム コンピュータ ゲーム 表記 揺れ 多数 あり 後述 英 Computer game コンピュータ 機能 使う 動作 ゲーム 日本 語 おく 総称 1 2 あるいは コンピュータ 上 動作 コンピュータ 人間 間 行なう ゲーム こと 3 もしくは コンピュータ 利用 ゲーム および プログラム 4 語 する 成り立ち 異なる ビデオ ゲーム 英 video game 多く 点 結果 同義 区別 ない 用いる 区別 名称 つく 名称 節 詳説 日本 語 コンピュータ ゲーム 表記 揺れ コンピュータ ゲーム 3 4 コンピューター ゲーム 1 2 コンピューター ゲーム 使用 機器 ディスプレイ 装置 および ゲーム ソフト 供給 媒体 違い 以下 5 種類 分類 4 また 電子 ゲーム いう 語 広義 コンピュータ ゲーム LSI ゲーム 電子 LSI ゲーム 比較 機能 低い 総称 狭義 LSI ゲーム 別名 日本 語 コンピュータ 化 もの いう 意味 合い コンピュータ ゲーム デジタル ゲーム 呼ぶ コンピュータ ゲーム 以外 ゲーム 非 電源 ゲーム これ 対比 アナログ ゲーム 呼ぶ 5 向き ある なお ここ デジタル および アナログ いう 用語 本義 離れる 日本 語 独自 俗用 CF アナログ 俗用 誤用 英語 事実 上 国際 共通 語 コンピュータ 信号 ビデオ モニター 出力 表示 時代 長い こと video game いう 語 用いる 通例 日本 語 英語 差 つく コンピュータ ゲーム video game 語義 近い 一方 Computer game PC game 近い 日本 語 パソコン ゲーム PC ゲーム また 広義 電子 ゲーム Electronic game 同義 日本 語 漢字 表記 日本 語 漢字 文化 圏 中国 語 電子 遊戲 簡体 字 以下 同様 电子 游 戏 6 電 玩 遊戲 电玩 游 戏 略語 電 玩 电玩 および 英語 video game 漢訳 影像 遊戲 影像 游 戏 視 頻 遊戲 视频 游 戏 電動 遊戲 電動 游 戏 英語 video game 相当 したがう これ ら いずれ 日本 語 コンピュータ ゲーム ほぼ 同義 言える 現代 日本 語 用字 新 字体 変換 前者 順 電子 遊戯 電 玩遊 戯 電 玩 影像 遊戯 視 頻 遊戯 電動 遊戯 ゲーム 機 電子 遊戲 機 电子 游 戏机 7 史上 初 コンピュータ ゲーム する もの 1947 年 コーネル 大学 卒業 生 アメリカ 人 トーマス t ゴールドスミス 英語 版 および エストル レイ マン estle ray mann よる 開発 陰極 線 管 娯楽 装置 cathode ray tube amusement device で ある 8 次いで 1952 年 edsac 上 プログラム oxo 開発 9 1961 年 開発 スペース ウォー ミニコンピュータ 開発 遊ぶ 初 汎用 コンピュータ 用 ゲーム ここ コンピュータ ゲーム 好事 家 よる 趣味 域 脱する 1971 年 ノーラン ブッシュネル スペース ウォー 改良 コンピューター スペース 開発 これ 世界 初 コンピュータ 式 アーケード ゲーム なる こと 産業 化 始まる 10 翌 1972 年 ラルフ ベア よる 世界 初 家庭 用 ゲーム 機 オデッセイ 開発 11 日本 おく 1970 年 代 末 広まる アーケード ゲーム おく LSI ゲーム 電子 ゲーム コンピュータ ゲーム 産業 化 はしり 言う 12 1978 年 スペース インベーダー 登場 こと 一大 ブーム 巻く 起こす 13 家庭 用 ゲーム 機 1980 年 代 入る いく つ 登場 なか 1983 年 発売 ファミリー コンピュータ 社会 現象 なる 爆発 売れ行き 記録 ほか ハード 圧倒 家庭 用 ゲーム 機 代 名詞 なる 後 コンシューマー ゲーム 成長 続く プレイ ステーション セガサターン nintendo 64 いう 新 ハード 発売 進む 1996 年 日本 国内 家庭 用 ゲーム 市場 規模 最大 なる 14 しかし 後 家庭 用 ゲーム 販売 減少 傾向 なる 2006 年 携帯 用 ゲーム ソフト 販売 据える 用 それ 上回る 15 しかし ころ すでに モバイル ゲーム 急速 躍進 始まる 2009 年 2011 年 かける フィーチャー フォン 向け ソーシャル ゲーム 急 成長 遂げる 16 後 2011 年 以降 スマートフォン 向け ゲーム 切る 替わる 17 日本 おく 国立 国会 図書 館 法 一部 改正 法律 2000 年 10 月 1日 施行 コンピュータ ゲーム ソフト 含む パッケージ 系 電子 出版 物 納本 義務 課する 日本 標準 産業 分類 おく コンピュータ ゲーム ソフトウェア 産業 情報 通信 業 分類 なか 情報 サービス 業 区分 18 ゲーム 産業 テクノロジー ビジネス モデル コンテンツ デザイン よる 変質 成長 巨大 森 いう 19 コンピュータ ゲーム 市場 成立 以降 急速 拡大 続ける 一大 産業 成長 2018 年 コンピュータ ゲーム 総 売上 13兆1774億 円 推定 20 うち 90 ％ 以上 デジタル 配信 ゲーム パッケージ ゲーム 売り上げ 1 割 以下 なる また 売り上げ アジア 北 アメリカ ヨーロッパ 順 多い 3 地域 売り上げ 95 ％ 近く のぼる 21 日本 国内 コンピュータ ゲーム 売上 2018 年 1兆6704億 円 なる うち スマホ ゲーム 1兆1660億 円 家庭 用 ゲーム 4343億 円 占める 20 ゲーム 企業 売り上げ 年 較差 激しい 2017 年 ゲーム 事業 売り上げ データ 中国 テンセント 1 位 以下 ソニー アップル マイクロ ソフト アクティ ビジョン ブリザード 順 なる また 年 任天堂 9 位 バンダイ ナムコ 10 位 なる 22 また コンピュータ ゲーム スポーツ 競技 する 捉える エレクトロニック スポーツ e スポーツ 盛ん なる 一般 ゲーム 全く 同様 コンピュータ ゲーム 関する 理論 人数 非 ゼロ 和 無 有 限 不 確定 不 完全 情報 いう 分類 応用 コンピュータ ゲーム 特殊 性 する プログラム 等 提供 者 信じる 限り おく 第 3 者 する 対戦 ゲーム 信用 判定 者 する コンピュータ 利用 ゲーム 性 点 疑問 ある しれる プレイヤー 眺める いう 0 人 ゲーム いう もの 非 電源 ゲーム 比較 割 ある いう 点 ある 以下 より コンピュータ ゲーム 固有 事情 観点 分類 ここ ビデオ ゲーム デジタル ゲーム 特徴 する 非 電源 ゲーム ボード ゲーム テーブル ゲーム カード ゲーム 対比 述べる コンピュータ ゲーム プラットフォーム よる いく つ 分類 ゲーム 専用 機 よる プレイ ゲーム アーケード ゲーム コンシューマー ゲーム 2 つ 区分 ある アーケード ゲーム 業務 用 ゲーム 機 よる 提供 ゲーム 個人 向け ない 企業 向け プラットフォーム ゲーム センター 遊園 地 設置 こと 多い 大型 専用 筐体 用いる 大型 筐体 ゲーム 存在 コンシューマー ゲーム 家庭 用 ゲーム 専用 機 よる 提供 もの 指す 据え置き 型 ゲーム 機 よる テレビ ゲーム 小型 持ち運び 携帯 型 ゲーム 2 種類 存在 27 また コンシューマー ゲーム 任天堂 ソニー よう ゲーム 機 ハード 製造 企業 ゲーム ソフト 製造 ハード プラットフォーム する 使用 企業 2 種類 存在 こう する ソフト 専業 企業 ゲーム 業 界 サード パーティー 呼ぶ 27 ゲーム 専用 機 以外 ハードウェア よる プレイ ゲーム パーソナル コンピュータ 利用 プレイ パソコン ゲーム 携帯 電話 スマートフォン スマート デバイス 使用 モバイル ゲーム 分かれる 27 また DVD 再生 機能 つき ゲーム 機 プレイ こと できる DVD プレイヤーズ ゲーム umd プレイヤーズ ゲーム BD プレイヤーズ ゲーム いう もの 存在 古く vhd ゲーム LD ゲーム いう もの ある 特に 後者 LD ROM 2 mega LD いう ハード ある アーケード ゲーム ビジネス コンピュータ ゲーム 以前 存在 それ ら ゲーム 機 特に ビデオ ゲーム コンピュータ 化 1970 年 代 コンピュータ ゲーム ビジネス ルーツ 一 つ pong ビデオ ゲーム 最初 製品 時代 コンピュータ 使う 1970 年 代 コンピュータ ゲーム する メインフレーム ミニコンピュータ 上 作る 遊ぶ もの ある 前者 デモンストレーション 用 いう 位置 付け 強い 後者 スペース ウォー よう アーケード ゲーム 発展 もの ある 10 しかし 最も 多い スタート レック よう 次 述べる マイコン ゲーム なる パターン 1970 年 代 後半 急速 発展 パソコン 当時 呼称 マイコン 当初 自作 公開 プログラム リスト よる 自由 流通 プログラム 中 1 ジャンル する ゲーム 人気 ある 分野 ビル ...
# ワードプロセッサー ワード プロセッサ 英 word processor また 文書 作成 編集 機 ぶん しょ さく せい へん しゅう コンピュータ 文章 入力 編集 印刷 システム 一般 略称 ワープロ ワープロ 機能 ROM 化 組む ワープロ 専用 機 汎用 パーソナル コンピュータ 動作 ワープロ ソフト Microsoft Word 一太郎 ある 記事 主に 前者 ワープロ 専用 機 扱う 文章 入力 活字 印字 システム する 欧文 用いる 地域 タイプライター 利用 日本 語 アルファベット 漢字 使う ため 欧文 タイプライター よう 個別 キー 押下 印字 ヘッド 運動 変換 機構 文字 数 不足 日本 語用 和文 タイプライター 存在 1000 以上 文字 並ぶ 盤面 目的 文字 ひと つ 検索 拾う 必要 ある 操作 方法 煩雑 熟練 技能 必要 する 日本 技術 発展 市場 普及 時期 関係 ワープロ 専用 機 時代 経る パソコン ワープロ ソフト 利用 移行 経過 経る ため 装置 する ワープロ 称する 場合 前者 ワープロ 専用 機 指す こと 多い 一方 欧米 諸国 アルファベット 文字 使用 タイプライター 普及 ため ワープロ 専用 機 必要 性 少ない タイプライター コンピュータ ワープロ ソフト 短 期間 移行 ため ワープロ 専用 機 普及 20 世紀 半ば コンピュータ 発明 小型 化 低 価格 化 進む 過程 文章 作成 応用 行う 紙 文字 記入 比べる コンピュータ 修正 推敲 容易 こと 利点 欧文 圏 使用 文字 英数字 若干 記号 加える 程度 処理 可能 ため 比較 容易 ワード プロセッサ 作る 世界 初 ワード プロセッサ 1964 年 昭和 39 年 IBM MT ST 後 ワング ラボラトリーズ 社 いく つ 英文 ワープロ 専用 機 登場 一方 日本 漢字 入力 方式 いう 非常 困難 課題 他 アルファベット 複雑 字 形 印刷 いう 課題 ある ため なかなか 製品 登場 1977 年 昭和 52 年 シャープ 試作 機 開発 5 月 ビジネス シヨウ 出品 1 2 なお 後 商品 化 モデル WD － 3000 かな 漢字 変換 実装 1978 年 昭和 53 年 東芝 初 日本 語 ワード プロセッサ jw 10 発表 3 これ ワープロ 専用 機 価格 630万 円 これ IEEE マイルストーン 選定 4 時代 画する もの 日本 語 版 実現 かな 文字 入力 読み 候補 なる 漢字 選択 コンピュータ よる かな 漢字 変換 仕組み 開発 こと ある 5 当初 構文 解析 行う 文節 単位 熟語 単位 変換 可能 なる 同音 語 学習 機能 備える 6 7 かな 漢字 変換 機構 単に 日本 語 ワード プロセッサ 専用 機 実用 化 ない 汎用 コンピュータ 限る 電子 手帳 携帯 電話 等 電子 機器 含める 広い 意味 コンピュータ よる 日本 語 利用 普及 ため 核心 なる 技術 1979 年 昭和 54 年 3 月 沖 電気 OKI Word Editor 200 発表 キーボード 入力 採用 漢字 入力 1 字 ごと 変換 方式 音読み 入力 読み 漢字 リスト 表示 中 入力 文字 選択 かたち 8 9 同年 9 月 シャープ 書院 WD － 3000 発表 キーボード 入力 かな 漢字 変換 ない タッチペン 方式 10 キーボード 方 能率 いい わかる キーボード アレルギー 対策 こと 11 翌 1980 年 昭和 55 年 電機 メーカー 事務 機 メーカー 次々 日本 語 ワープロ 市場 参入 競争 よる 価格 下がる 大手 企業 導入 進む 同年 平均 単価 200万 円 ワープロ 価格 1985 年 昭和 60 年 16.4万 円 劇的 下がる 12 1980 年 代 後半 ワープロ 専用 機 持ち運び 可能 大きい 小型 化 パーソナル ワープロ する 中小 企業 個人 導入 始まる 13 この頃 個人 向け パーソナル ワープロ 本体 キーボード 一体 化 プリンタ 数 行 程度 液晶 表示 パネル 備える 専用 機 文章 作成 校正 編集 印刷 機能 持つ 機械 性能 向上 連れる 液晶 表示 パネル 表示 行数 増加 文書 全体 レイアウト 把握 また 印字 機能 発達 よる 明朝 体 印刷 フォント ゴシック 体 毛筆 体 種類 増える 写植 匹敵 高 精細 印字 可能 なる さらに 図形 描画 絵 文字 はがき 印刷 表面 裏面 カード 型 データベース 住所 録 表 計算 パソコン 通信 付加 機能 搭載 もの 増える テキスト 処理 関する 当時 パーソナル コンピュータ パソコン 同等 以上 高 機能 なる 一方 パーソナル コンピュータ 漢字 ROM 搭載 BASIC 当時 オペレーティング システム OS 兼ねる 漢字 使用 こと できる ソフトウエア ベース する ワープロ 登場 簡易 ワープロ ソフト 安価 漢字 プリンタ 登場 至る 後 パソコン 代表 オペレーティング システム MS-DOS 上 漢字 処理 できる パソコン 普及 市場 拡大 とも 安価 ワープロ ソフト 誕生 至る また 1980 年 代 これ ら 個人 向け 製品 流れ 別 ビジネス 用途 する ワークステーション 漢字 処理 機能 搭載 パーソナル ワープロ 同様 機能 加える 様々 組版 機能 盛る 物 登場 これ ら 多く 企業 内 文書 作成 写植 システム する 活用 パーソナル ワープロ 別 道 歩む こと なる 1990 年 代 入る 画面 白黒 カラー 液晶 進化 見せる 部分 ある もの パソコン ワープロ ソフト 低 価格 化 安価 パソコン 用 高 性能 プリンター 登場 よる シェア 奪う 普及 インターネット アクセス 悪い ため 売れ行き 落ちる 出荷 台数 1989 年 平成 元年 出荷 金額 1991 年 平成 3 年 ピーク 漸減 ワープロ 専用 機 世帯 普及 率 1998 年 平成 10 年 ピーク 急 低下 1999 年 平成 11 年 ついに パソコン 売上 ワープロ 専用 機 売上 逆転 2000 年 平成 12 年 2 月 シャープ 書院 シリーズ WD CP 2 発表 最後 新 機種 出る 2003 年 平成 15 年 9 月 末 同 機種 WD － VP 3 WD MF 01 3 機種 生産 中止 なる こと よる ワープロ 専用 機 全社 製造 終了 企業 内 文書 作成 一般 ビジネス ソフト 市販 プリンタ 代替 姿 消す 　 生産 終了 後 ワープロ 専用 機 作る 多く 文書 資産 どう パソコン 移行 多く 企業 とる 悩み 種 とりわけ 専用 機 罫線 振り仮名 各社 独自 工夫 データ 処理 パソコン 側 ソフトウェア 変換 機能 搭載 もの ある 罫線 各社 絵 文字 記号 変換 こと できる また メーカー 機能 多様 化 処理 方法 変化 本文 テキスト 化 せいぜい いう 程度 ため 各社 とも ワープロ 終焉 とも パソコン 再現 性 高める データ 移行 ため ソフトウェア 開発 求める それ 必ず 完全 復元 約束 もの ない それ なり 再現 一定 役割 果たす Power 書院 14 15 rupo Writer 16 キヤノワード j for Windows 17 また IME する rupo ACE 18 発売 いずれ 販売 終了 2018 年 時点 開発 販売 続ける oasys V 10 19 2000 年 代 後半 スマートフォン タブレット 技術 応用 作る 年賀 状 印刷 特化 液晶 キーボード 付き フォト プリンタ CASIO 　 プリン 写 ル EPSON 　 年賀 状 宛名 達人 等 プレーン テキスト 入力 特化 ポメラ ワープロ コンセプト 取る 入れる 製品 発売 リコー 2009 年 ワープロ 専用 機 システム FD コピー および 文書 コンバート サービス さらに 2017 年 お 問い合わせ 窓口 対応 終了 2018 年 現在 パソコン スマートフォン 代替 書く 文書 場 すぐ サーマル プリンター 印刷 利用 場所 選ぶ 印刷 相手 手渡 推敲 できる ラベル シール プリンター する 手軽 使用 部分 ある ため 未だ オークション 連日 よう 状態 問う 取引 反面 ワープロ 専用 機 利用 者 積極 インターネット 情報 交換 行う 傾向 強い また レトロ ゲーム 万年 筆 よう 文化 する 再 評価 行う 動き 未だ ない 既に 動態 状態 かつ 付属 品 全て 揃う 資料 価値 高い もの 絶滅 思う 機種 出る また ワープロ 専用 機 支持 熱心 ユーザー 多い 中古 機 市場 相場 上昇 こと ある 理由 50 歳 代 以上 年代 慣れる 親しむ ワープロ 専用 機 愛着 強い こと 小説 家 翻訳 家 文筆 業 連続 稼働 する クラッシュ 起こす 作業 環境 高い 安定 性 快適 さ キーボード 品質 高い 冷却 用 ファン 常時 騒音 発生 部品 ない 現代 PC 比較 廃熱 少ない ため 室温 影響 少ない 求める 層 一部 法律 事務 所 ネットワーク 経由 情報 漏洩 懸 ...
# オペレーションズ・リサーチ オペレーションズ リサーチ 英語 operations research 米 オペレーショナル リサーチ 英語 operational Research 英 1 略称 or 数学 統計 モデル アルゴリズム 利用 よる さまざま 計画 際する 最も 効率 決定 科学 技法 複雑 システム 分析 おく 意思 決定 支援 また 意思 決定 根拠 他人 説明 ため ツール また ゲーム 理論 金融 工学 or 応用 する 誕生 もの or 政府 軍隊 国際 機関 企業 非 営利 法人 さまざま 組織 意思 決定 ため 数学 技術 する 使用 or 研究 線形 計画 法 LINEAR programing 動的 計画 法 順列 組み合わせ 確率 最適 化 および 待つ 行列 理論 微分 方程 式 線形 代数 学 数学 研究 踏まえる 現実 問題 数理 モデル 置く 換える こと 合理 化 意思 決定 可能 なる ない 定量 問題 つく 最適 化 行う こと できる 近年 計算 機 用いる 煩雑 計算 実行 方法 研究 こと 多い また or 特定 領域 問題 ない 幅広い 領域 応用 こと 可能 学際 研究 分野 言える 現代 or 研究 軍事 関心 経済 関心 行う 歴史 or 初期 頃 研究 者 軍事 関心 研究 進める イギリス フレデリック ランチェスター 第 一 次 世界 大戦 中 両軍 戦闘 部隊 戦力 戦闘 結果 関係 研究 ランチェスター 方程 式 確立 同 時期 ロシア m オシポフ 独自 研究 よる オシポフ 方程 式 研究 しかし これ ら 研究 先駆 研究 ある もの 価値 見出す 本格 研究 第 二 次 世界 大戦 戦間 期 おく イギリス or 発展 見る ルイス フライ リチャードソン 線型 方程 式 第 一 次 世界 大戦 軍備 拡張 競争 応用 研究 成果 挙げる これ 彼 著作 1950 年 再 出版 広い 知る こと ない また ロシア レオニード カントロヴィッチ 工場 生産 性 増大 ため 多種 多様 原 材料 配分 個々 機械 作業 供給 者 発注 数学 解く こと できる いう 革新 or 研究 方法 示す 研究 受ける 継ぐ こと ない 第 二 次 世界 大戦 勃発 or アメリカ イギリス 科学 者 たち よる 組織 研究 イギリス パトリック ブラケット ドイツ 海軍 潜水 艦 u ボート 実施 群 狼 作戦 脅威 対処 また イギリス 本土 防空 戦術 確立 ため or 研究 1941 年 ブラケット ロイヤル エア クラフト エスタブリッシュメント rae 海軍 移籍 最初 イギリス 空軍 沿岸 司令 部 coastal command 研究 のち 1942 年 イギリス 海軍 本部 研究 2 沿岸 司令 部 オペレーショナル リサーチ セクション cc ors おく ブラケット チーム 後 ノーベル 賞 受賞 こと なる 学者 二人 含む 他 メンバー 後 それぞれ 分野 第 一 人 者 なる こと なる 優秀 面々 そろう 3 彼 ら 戦争 遂行 かかわる 数多く 重要 分析 業務 携わる たとえば 当時 イギリス 輸送 船 損害 抑える ため 護送 船団 方式 採用 これ つく 商船 軍艦 随伴 いう 原則 つく だいたい 意見 一致 船団 規模 大小 つく 意見 一致 ない 船団 いちばん 遅い 船 合わせる 移動 船団 方 速力 速い また 船団 方 ドイツ 海軍 u ボート 発見 はず いう 意見 ある 一方 多数 船団 まとめる 護送 船団 組む それ 多く 軍艦 護衛 付ける こと 出来る ブラケット スタッフ 船団 被害 全 船舶 数 むしろ 護衛 艦 数 大きい 依存 事 示す したがう 護送 船団 組む 船団 数 減らす 方 護送 船団 何 度 出す 護衛 いう 彼 ら 結論 4 また イギリス 空軍 沿岸 司令 部 敵 潜水 艦 捜索 撃沈 際 用いる 方法 解析 際 アナリスト 一人 航空 機 色 何色 尋ねる 対潜 任務 あたる 航空 機 ほとんど 爆撃 司令 部 所属 夜間 作戦 用 黒 色 塗装 なる cc ors 提言 よる 昼間 作戦 おく 黒色 塗装 北 大西洋 灰 色 空 背景 する カモフラージュ 効果 点 最適 どう 確かめる 実験 行う 実験 よる 白色 塗装 航空 機 平均 黒 色 塗装 航空 機 20 ％ 近い 位置 来る 発見 事 示す 変更 行う 敵 潜水 艦 発見 回数 当たり 攻撃 撃沈 数 これ 30 ％ 増 なる はず 5 cc ors 手がける 他 仕事 する 航空 機 投下 型 爆雷 爆発 深度 平均 100 フィート 25 フィート 変更 撃沈 率 向上 提言 もの ある 理由 イギリス 軍 機 u ボート 到達 直前 なる u ボート 側 英軍 機 発見 場合 100 フィート 爆発 深度 u ボート 損害 与える 考える u ボート 100 フィート 潜航 十分 時間 ない はず また u ボート 側 かなり 遠く 英軍 機 発見 場合 u ボート 潜航 針路 変更 十分 時間 ある 爆雷 有効 半径 20 フィート 内 u ボート いる 可能 性 低い 考える したがう 標的 位置 推測 ない 深い 所 撃沈 試みる 標的 位置 よく 分かる 水面 近く 潜水 艦 攻撃 方 有効 爆発 深度 設定 100 フィート 25 フィート 変更 潜航 u ボート 1 ％ 撃沈 14 ％ 損傷 受ける 変更 後 7 ％ 撃沈 11 ％ 損傷 受ける 特に 潜水 艦 浮上 時 発見 場合 攻撃 前 潜航 する 成績 11 ％ 撃沈 15 ％ 損傷 向上 ブラケット 感想 する 些細 単純 戦術 変更 よる これ 作戦 オペレーション 上 利益 あがる 例 数える ない 述べる 6 イギリス 空軍 爆撃 司令 部 bomber command オペレーショナル リサーチ セクション BC － ors 爆撃 司令 部 行う 調査 報告 分析 要 出典 調査 爆撃 司令 部 ある 期間 中 ドイツ 爆撃 任務 帰還 全て 爆撃 機 調査 ドイツ 防空 部隊 対 空砲 受ける 損傷 すべて 記録 上 機体 最も 損傷 ひどい 箇所 装甲 板 追加 勧告 勧告 採用 なぜ 箇所 損傷 受ける 生還 いう こと 箇所 たいして 重要 ない いう こと そんな 箇所 装甲 板 重量 加える 航空 機 運動 性 悪 影響 与える また 航空 機 乗員 一部 削減 航空 機 一 機 あたり 人的 被害 軽減 する 爆撃 司令 部 提案 空軍 司令 部 よる 却下 ブラケット チーム 帰還 爆撃 機 無傷 箇所 装甲 板 追加 いう 論理 勧告 行う 理由 爆撃 司令 部 調査 イギリス 生還 機体 調査 ため バイアス かかる 生還 機体 おく 無傷 箇所 おそらく 機体 重要 部分 つまり そこ 敵弾 当たる 撃墜 帰還 7 したがう 無傷 航空 機 生還 こと なる 作戦 行動 研究 部 員 する 働く フリーマン ダイソン 作戦 行動 数理 モデル 化 統計 研究 担当 爆撃 隊 員 安全 性 経験 出撃 回数 関連 無い 銃座 飛行 速度 鈍る 機 銃手 必要 なる ため 結果 無駄 調査 結果 提示 これ ら 軍 常識 合う ため 却下 費用 対 効果 オペレーションズ リサーチ 多用 指標 連合 軍 側 航空 機 飛行 時間 投入 費用 する ある 海域 発見 u ボート 数 得る 効果 する 比較 より 費用 対 効果 高い 地域 航空 機 振る 向ける こと できる 費用 対 効果 比較 よる 計画 有用 有効 比率 割る こと できる 例えば 撃沈 一 隻 あたり 機雷 敷設 数 60 個 いう 比率 さまざま 戦 例 おく 共通 イギリス 港 対する ドイツ 軍 機雷 ドイツ 海上 ルート おく イギリス 軍 機雷 日本 海上 ルート おく アメリカ 軍 機雷 8 また アメリカ 1942 年 アメリカ 海軍 オペレーションズ リサーチ グループ org 設置 特定 部隊 地域 派遣 部隊 訓練 計画 立案 膨大 部隊 補給 整備 計画 行う 問題 数学 研究 これ ら 研究 成果 する 対潜 戦 用いる 捜索 理論 戦略 爆撃 費用 分析 見る 沖縄 戦 沖縄 本島 近海 展開 連合 軍 艦隊 おく 特攻 対策 応用 アメリカ オペレーション リサーチ よる マリアナ 諸島 b 29 よる 日本 爆撃 おく 標的 命中 率 2 倍 なる これ 飛行 時間 中 訓練 比率 4 ％ 10 ％ 引く ため また 1 隻 潜水 艦 担当 哨戒 海域 発見 目標 他 すべて 潜水 艦 攻撃 ため もっとも 有効 編成 3 隻 チーム こと 解明 また 夜間 戦闘 機 それ ツヤ消し 迷彩 塗装 ツヤ ある エナメル 塗装 最も 有効 カモフラージュ なる 更に 表面 滑らか 仕上げ よる 表面 摩擦 下がる 対気 速度 増す 事 突く 止める 8 陸上 イギリス 軍需 省 陸軍 オペレーショナル リサーチ グループ aorg オペレーショナル リサーチ 分隊 複数 ノルマンディー 上陸 作戦 とも 上陸 ヨーロッパ 大陸 進軍 イギリス 軍 つく 歩く 彼 ら 砲撃 爆撃 対 戦車 射撃 有効 性 つく 解析 行う 戦 ...
# 教育工学 教育 工学 きょう いく こうがく 英語 educational Technology 教育 現場 改善 資する 教育 効果 高い アーティファクト 設計 開発 評価 学問 教育 工学 つく さまざま 立場 ある 教育 必要 道具 技術 生む こと 目的 する もの 工学 持つ 技術 思想 手法 教育 活動 応用 こと 目的 する もの ある 第 二 次 世界 大戦 後 活発 研究 行う 1980 年 代 比較 新しい 領域 いう 2000 年 代 以降 インターネット 普及 後押し かたち 急激 成長 研究 分野 従来 教育 工学 生産 業 見る ドキュメント 化 教育 現場 行く する 教育 技術 体系 集積 取る 組む しかし 現在 教育 技術 つく 同一 場面 おく 同一 もの 用いる いう 態度 教育 活動 上 おく 問題 ある こと 明らか 教育 工学 目的 従来 比較 変遷 みる いう 現代 おく 教育 工学 より 創造 効率 教育 行う ため 技術 研究 行う 学問 する 捉える 教育 活用 情報 つく 研究 教育 情報 学 情報 教育 つく 研究 情報 教育 論 基礎 論 する 捉える する 動き ある 現代 教育 工学 おく 情報 学 教育 方法 学 相 まつ 視聴覚 教育 する 使用 スライド プロジェクタ 映像 映画 放送 教育 OHP そして コンピュータ 教育 用いる こと できる メディア 教育 メディア 活用 つく 研究 教育 工学 おく これ ら 機器 基礎 側面 研究 こと ある しかし 基礎 論 応用 論 区分 厳格 もの ない 教育 工学 含む 具体 各 研究 おく 基礎 領域 応用 領域 適宜 扱う こと 多い 事情 背景 教育 工学 語 技術 教育 方面 応用 いう 意味 合い 強調 形 教育 関する 工学 要素 持つ 研究 総称 する 用いる 英語 おく 一般 工学 つく engineering 呼称 対する 教育 工学 つく educational Technology 呼称 一般 工学 おく 技術 者 養成 視点 含む 教育 工学 教育 技術 者 養成 意図 考える 背景 ある 日本 おく 工学 部 教育 工学 科 教育 工学 課程 いう もの 設ける 教育 工学 全般 つく 教育 学 部 扱う 学問 分野 考える こと 多い なお 情報 教育 つく 情報 工学 アプローチ ある 個別 研究 つく 工学 部 含む 多様 学部 扱う 産業 革命 以降 物作り 徐々 自動 化 道 歩む そして フォード 社 自社 車 生産 流れる 作業 よる 方式 考案 これ よる 従来 一人 職人 1 台 仕上げる 車 大量 人 しかも それぞれ 割る 当てる 仕事 ごく 簡単 素人 できる 用いる 効率 よい 大量 車 生産 こと できる 流れ 作業 図式 教育 応用 出現 教育 工学 すなわち いう 一連 プロセス テイラー システム 教育 置く 換える いう 考える 教員 いう 職業 職人 側面 強い 十分 教育 可能 レベル 達する 教員 職 つく さらに 10 年 必要 する 前述 流れ 作業 教育 行う ため 教職 技術 科学 方法 よる 検証 教授 技術 マニュアル 化 必要 ある 教育 プロセス 及び 教授 技術 マニュアル 化 行う ため 発生 学問 教育 工学
# 文書管理システム 文書 管理 システム 英 Document MANAGEMENT System dms 電子 文書 紙 文書 デジタイズ もの 格納 管理 コンピュータ 上 システム コンテンツ 管理 システム CMS 重複 部分 ある エンタープライズ コンテンツ 管理 システム 一部 する こと 多い デジタル 資産 管理 文書 画像 化 ワークフローシステム 記録 管理 システム 関連 文書 管理 手法 以下 よう 分類 文書 管理 管理 対象 よる 2 種類 分類 1980 年 代 複数 ベンダー 紙 文書 管理 システム 開発 それ ら システム 印刷 物 ない 写真 他 含める 紙 文書 管理 コンピュータ よる 管理 ため 紙 上 情報 デジタイズ 画像 ファイル 管理 もの 電子 文書 管理 edm システム 呼ぶ 後 別 種類 システム する 電子 文書 特化 システム 生まれる これ コンピュータ 上 作成 文書 ファイル 管理 もの 初期 システム 管理 ファイル フォーマット 独自 もの 限る これ ら 2 つ 系統 統合 管理 対象 ファイル フォーマット 多様 なる ネットワーク 上 文書 分散 配置 他 アプリケーション 連携 強化 セキュリティ 機能 強化 carzaniga Wolf 2001 年 論文 Content based networking a New Communication infrastructure おく 電子 文書 管理 つく 考察 そこ コミュニケーション 基盤 する コンテンツ ベース ネットワーク 提案 ユーザー 関心 ある こと 表明 それ ネットワーク メッセージ する 入力 そして ネットワーク 適切 人々 適切 情報 配信 Sprague 1995 年 より 詳細 文書 管理 方式 提案 それ 電子 文書 管理 Electric Document MANAGEMENT edm 称する 彼 定義 よる 文書 管理 組織 目的 適う 文書 生成 格納 構成 転送 検索 操作 更新 廃棄 PP 32 edm よる 人々 コミュニケーション 改善 する PP 42 43 edm コミュニケーション 関係 つく 他 例 ある Hansen HaaS 2001 年 電子 文書 つく 情報 提供 者 情報 利用 者 役割 観点 論ずる また thorpe Mead 2000 年 edm コミュニケーション 明確 関係 研究 彼 ら edm システム コミュニケーション パターン 変革 こと 示す 彼 ら 研究 3 つ プロジェクト うち 2 つ edm 中心 する 残る 1 つ 3 カ月 中止 なる howard pettersen 2001 年 研究 対象 なる ある プロジェクト コミュニケーション 手段 する edm 三 番 目 手段 する 上位 手段 電話 会議 下位 手段 電子 メール 紙 文書 ファックス rene brohm 2005 年 学位 論文 シアター モデル 提案 シアター モデル 文書 管理 システム 劇場 ステージ 対比 説明 もの すなわち ステージ 上 演劇 相互 作用 文書 管理 システム 機能 類似 性 論ずる marin poulter 2004 年 よる 全て データ 情報 集中 型 データベース あるいは イントラネット 置く それ 組織 全員 使う 場合 IT 情報 配布 明確 関係 生じる 彼 ら 情報 アクセス 容易 組織 内 流通 情報 量 増える する コミュニケーション ツール 改良 別 方法 ある Hansen HaaS 2001 年 edm 競争 ある 市場 見る 立てる それ よる 情報 提供 者 情報 共有 戦略 持つ ユーザー 従業 員 システム 使う 戦略 必要 する yan garcia molina 1999 年 PP 2 提案 方法 人々 必要 興味 ある 情報 表す クエリ 群 含む 長期 プロファイル 提示 いう もの これ よる 得る 情報 質 向上 する つまり 事前 明らか プロファイル 基づく 情報 配布 それ よる 検索 時間 コスト 削減 文書 管理 システム 格納 バージョン メタデータ セキュリティ 索引 検索 機能 いう 構成 要素 ある 以下 これ ら つく 解説

# %%
# 再利用するために、csvファイルとして保存しておく。

import pandas as pd

genre.append('人工知能')
corpus.append(doc_AI)

df = pd.DataFrame(list(zip(genre, corpus)), columns=['genre', 'text'])
print(df.head())
df.to_csv('cs_corpus.csv')
# Out:
#       genre                                               text
# 0  コンピュータ科学  計算 機 科学 けい さん かがく 英 computer science コンピュータ 科学...
# 1    ハードウェア  ハードウェア 英語 hardware システム 物理 構成 要素 指す 一般 用語 日本 語...
# 2    プリント基板  プリント 基板 プリント きばる 短縮 形 pwb PCB 基板 一種 以下 ふた つ まと...
# 3      周辺機器  周辺 機器 しゅうへん きく また ペリフェラル 英 peripheral コンピュータ ゲ...
# 4      集積回路  集積 回路 しゅう せき かいろ 英 integrated circuit IC 半 導体 ...

# %% [markdown]
# ## 課題の手順(3)

# %% [markdown]
# ### CountVectorizerで単語の出現頻度を要素とするベクトルを作成する。

# %%
# 先ほど作成したcsvファイルを読んで、textカラムをCountVectorizerのインスタンスでベクトル化する。
# ベクトルの要素は、各Wikipediaエントリにおける、各単語の出現回数になる。

from sklearn.feature_extraction.text import CountVectorizer

df = pd.read_csv('cs_corpus.csv')

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['text'])

# %%
# CountVectorizerで得られるのはsparse matrixである。
print(X)
# Out:
#   (0, 8809)	50
#   (0, 8240)	31
#   (0, 2551)	1
#   (0, 2590)	1
#   (0, 2510)	1
#   (0, 723)	7
#   (0, 2005)	5
#   (0, 3532)	18
#   (0, 6940)	7
#   (0, 8007)	7
#   (0, 6352)	1
#   (0, 6059)	1
#   (0, 6600)	1
#   (0, 6903)	4
#   (0, 9345)	1
#   (0, 8200)	4
#   (0, 5832)	12
#   (0, 7578)	2
#   (0, 2456)	12
#   (0, 3433)	2
#   (0, 2875)	4
#   (0, 5925)	1
#   (0, 9485)	5
#   (0, 6216)	2
#   (0, 7268)	5
#   :	:
#   (121, 7401)	1
#   (121, 9270)	1
#   (121, 8855)	1
#   (121, 5272)	1
#   (121, 5964)	1
#   (121, 8228)	1
#   (121, 5361)	1
#   (121, 77)	1
#   (121, 78)	1
#   (121, 134)	1
#   (121, 79)	1
#   (121, 80)	4
#   (121, 8299)	1
#   (121, 5495)	4
#   (121, 6236)	1
#   (121, 5408)	1
#   (121, 6730)	1
#   (121, 83)	1
#   (121, 84)	1
#   (121, 85)	1
#   (121, 6646)	1
#   (121, 2556)	1
#   (121, 2490)	1
#   (121, 7503)	1
#   (121, 86)	1

# %%
# sparse matrixから、通常のNumPyの配列へ変換する。
X = X.toarray()
print('文書数:{}; 語彙サイズ：{}'.format(*X.shape))
# Out:
# 文書数:122; 語彙サイズ：9564

# %%
# CountVectorizerによって作られた語彙を取得する。
vocab = vectorizer.get_feature_names()
print(vocab)
# Out:
# ['00', '000', '001', '00802', '01', '0160', '0161', '0625', '07', '096', '10', '100', '1000', '1000万', '1000億', '100万', '101', '1010', '1012', '102', '103', '104', '105', '1050億', '106', '107', '108', '1080', '109', '10万', '11', '110', '111', '112', '113', '114', '115', '115億', '116', '117', '118', '119', '12', '120', '1200', '121', '122', '12207', '123', '12345', '124', '125', '126', '127', '128', '129', '13', '130', '131', '132', '133', '134', '135', '136', '137', '138', '139', '13兆1774億', '14', '140', '1401', '141', '1411', '142', '143', '144', '145', '146', '147', '148', '149', '15', '150億', '151', '152', '153', '154', '15504', '1565927247', '158', '15846', '15億', '16', '16000', '1600億', '1620', '1623', '1642', '1662', '168', '17', '1700', '1715', '1741', '1742', '1748', '1749', '178', '1790', '18', '180', '1830', '1835', '1854', '1860', '1869', '1871', '1874', '1875', '1890', '19', '1901', '1902', '1906', '1908', '1909', '19100', '19123', '1919', '1920', '1922', '1924', '1928', '1930', '1931', '1933', '1935', '1936', '1939', '1940', '1941', '1942', '1943', '1944', '1945', '1947', '1948', '1949', '1950', '1951', '1952', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '197', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '1st', '1万5千', '1人', '1億', '1兆1660億', '1兆6704億', '1日', '20', '200', '2000', '2000万', '2001', '2002', '2003', '2004', '2005', '2006', '20060719054203', '2007', '2008', '2009', '200万', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2022', '2045', '20億', '21', '211', '215億', '216', '22', '220', '23', '232', '24', '25', '250', '2500', '25000', '256', '26', '261', '265', '27', '27000', '27001', '27002', '28', '29', '2人', '2兆', '30', '300', '3000', '3001', '300万', '3014', '3090', '30万', '31', '310万', '313', '32', '320', '33', '34', '35', '350', '350億', '36', '360', '3600', '37', '370', '3768', '38', '386', '39', '3m', '3万', '3万5千', '40', '400', '41', '41421', '42', '43', '4343億', '44', '45', '4553488', '46', '47', '48', '480', '485', '49', '4万', '4兆', '50', '500', '5000', '51', '512', '52', '53', '54', '55', '550', '5500億', '557', '56', '5603', '56592', '57', '570億', '58', '582', '59', '596', '5万', '60', '6001', '60194', '61', '62', '63', '630万', '64', '640', '65', '66', '67', '68', '69', '70', '700', '7000', '700万', '701', '7030', '704', '709', '71', '7100', '72', '7289', '73', '74', '743', '75', '750百万', '754', '76', '77', '777', '78', '7800', '79', '80', '8000', '801', '802', '80286', '80386', '81', '8115', '8152', '82', '8200', '825', '83', '830', '84', '85', '86', '87', '875', '877', '88', '89', '90', '9000', '909', '91', '92', '93', '94', '95', '96', '97', '978', '98', '9800', '9801', '981', '99', '9万', 'abaqus', 'abi', 'abramowitz', 'acars', 'acceleration', 'access', 'accessibility', 'ace', 'achieving', 'acm', 'acos', 'acrimsat', 'act', 'action', 'actions', 'activex', 'ad', 'ada', 'add', 'adobe', 'adpcm', 'affecting', 'age', 'agent', 'agi', 'agpl', 'ahmed', 'ai', 'aic', 'aid', 'aided', 'aimms', 'airbrushing', 'airep', 'aix', 'ajax', 'aks', 'al', 'alac', 'alan', 'alberti', 'aldrich', 'algebraic', 'algol', 'algorithm', 'algoritmi', 'all', 'allan', 'allen', 'alliance', 'alloy', 'alpha', 'alphabetic', 'alphago', 'alt', 'alte', 'am', 'amazon', 'amd', 'amdar', 'america', 'amigaos', 'aml', 'amortized', 'ampl', 'amsterdam', 'amusement', 'an', 'analysis', 'analytic', 'and', 'android', 'anim', 'animation', 'anomaly', 'anti', 'aorg', 'aot', 'apache', 'ape', 'api', 'apl', 'apple', 'application', 'approx', 'aps', 'apu', 'aqua', 'ar', 'architecture', 'archive', 'arcnet', 'area', 'arg', 'argmax', 'argmin', 'argo', 'arm', 'armad', 'arpa', 'arpanet', 'arpg', 'arrow', 'art', 'artifacts', 'artificial', 'as', 'asic', ...

# %%
# コーパス全体での出現頻度順で上位20単語を見てみる。

import numpy as np

vocab = np.array(vocab)
print(vocab[np.argsort(- X.sum(axis=0))][:20])
# Out:
# ['こと' 'する' 'ある' 'よる' 'いう' 'ソフトウェア' 'システム' 'コンピュータ' 'なる' 'もの' '言語' 'ため'
#  '計算' '問題' 'データ' '使う' '情報' '場合' '開発' 'ない']

# %%
# 「人工知能」エントリと他のエントリとの距離を求める。

from scipy.spatial import distance

genre = df['genre'].values.tolist()
index_AI = genre.index('人工知能')
print(f'「{genre[index_AI]}」と「{genre[10]}」との間での・・・')
print(f'ユークリッド距離: {np.linalg.norm(X[0] - X[index_AI])}')
print(f'内積: {np.dot(X[0], X[index_AI])}')
print(f'コサイン類似度: {distance.cosine(X[0], X[index_AI])}')
# Out:
# 「人工知能」と「組み込みシステム」との間での・・・
# ユークリッド距離: 198.4187491140895
# 内積: 8254
# コサイン類似度: 0.5478636045778883
